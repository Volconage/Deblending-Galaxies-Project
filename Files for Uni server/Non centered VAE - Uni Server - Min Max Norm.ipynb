# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn
import pandas as pd
import photutils

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

from photutils.detection import DAOStarFinder
from photutils.morphology import data_properties
from astropy.stats import mad_std

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Dense, Flatten, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

from tensorflow.config import list_logical_devices, list_physical_devices, set_visible_devices
from tensorflow.config.experimental import set_memory_growth

# %%
#Setup notebook so Tensorflow works in a friendly way in a shared multi GPU env

def setup_tensorflow(seed=None):
    try:
        import nvsmi

        gpu_mem_free = np.array([gpu.mem_free for gpu in nvsmi.get_gpus()])
        if len(gpu_mem_free) > 0 and (gpu_mem_free > 0).any():
            idx = np.argmax(gpu_mem_free)
            gpu = list_physical_devices("GPU")[idx]
            set_memory_growth(gpu, True)
            set_visible_devices(gpu, "GPU")
            gpus = list_logical_devices("GPU")
            print(f"Using GPU: {gpus}")
        else:
            raise Exception
    except:
        print(f"Tensorflow using CPU")
    tf.random.set_seed(seed)

# %%
setup_tensorflow()
# Out:
# Using GPU: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-04-28 23:09:19.061875: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-28 23:09:19.552016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9650 MB memory:  -> device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:17:00.0, compute capability: 7.5

# %%
#load the image arrays 

#Blends/Components 2 is where the blends have been made AFTER the galaxies have had noise and shift added to them not before

blends = np.load("blends2.npy")
components = np.load("components2.npy")

# %%
#Check the blends are the sum of their respective components 
print(np.sum(blends - (components[0] + components[1])))
# Out:
# 0.0

# %%
np.mean(blends), np.mean(components)
# Out:
# (0.30920145099287816, 0.15460072549643988)

# %%
#Min Max Norm

norm_max = np.max([ np.max(blends), np.max(components) ])
norm_min = np.min([ np.min(blends), np.min(components) ])


blends = (blends - norm_min) / (norm_max - norm_min) 

components = (components - norm_min) / (norm_max - norm_min)

# %%
blends.shape, components.shape
# Out:
# ((120000, 64, 64), (2, 120000, 64, 64))

# %%
np.mean(blends), np.mean(components)
# Out:
# (0.12583104449989554, 0.09147367489091629)

# %%
#Split into training and test set 

#Going to split training and test 80% and 20% respectively 

train_ngals = int(blends.shape[0] * 0.8)
test_ngals = int(blends.shape[0] * 0.2)

train_blends = blends[:train_ngals]
test_blends = blends[train_ngals:]

blends = []

a, b, c, d, test_components = np.split(components, 5, axis = 1)

components = []

train_components = np.concatenate((a, b, c, d), axis = 1)

# %%
np.amax(train_blends), np.amin(train_blends), np.amax(test_blends), np.amin(test_blends)
# Out:
# (1.0, 0.0, 0.9335352514229251, 0.0030096240571351363)

# %%
np.amax(test_components), np.amin(test_components), np.amax(test_blends), np.amin(test_blends)
# Out:
# (0.6313723013065796,
#  0.016003554881048085,
#  0.9335352514229251,
#  0.0030096240571351363)

# %%
height,width=64,64

train_blends = train_blends.reshape(train_ngals, height, width, 1).astype('float32')
train_components = train_components.reshape(2, train_ngals, height, width, 1).astype('float32')

test_blends = test_blends.reshape(test_ngals, height, width, 1).astype('float32')
test_components = test_components.reshape(2, test_ngals, height, width, 1).astype('float32')

# %%
batch_size = 32
latent_dimensions = 32

# %%
fig, ax = plt.subplots(2 + 1, 5, figsize=(15, 10))
for i in range(5):
    ax[0, i].imshow(train_blends[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
    ax[1, i].imshow(train_components[0, i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
    ax[2, i].imshow(train_components[1, i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)

# %%
#Will optimise encoder / decoder later
def encoder(x):
    x=Conv2D(32,3,activation='relu', strides = 2, padding='same')(x)
    x=Conv2D(64,3,activation='relu', strides = 2, padding='same')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    return x

# %%
def decoder(x):
    x=UpSampling2D(size=(2,2))(x)
    x=Conv2DTranspose(64,3,activation='relu', strides = 2 ,padding='same')(x)
    x=Conv2DTranspose(32,3,activation='relu', strides = 2 ,padding='same')(x)
    return x

# %%
def sampling(args):
    z_mean,z_log_sigma=args
    epsilon=tf.random.normal(shape=tf.shape(z_mean))
    z=z_mean+tf.exp(0.5*z_log_sigma)*epsilon
    return z

# %%
# encoder
input_blend=Input(shape=(height, width,1))

encoded=encoder(input_blend)
shape=encoded.get_shape()[1:]
encoded=Flatten()(encoded)

z_mean=Dense(latent_dimensions)(encoded)
z_log_sigma=Dense(latent_dimensions)(encoded)
z=Lambda(sampling)([z_mean,z_log_sigma])

# %%
# decoder
input_embed=Input(shape=latent_dimensions)

embed1=Dense(np.prod(shape),activation='relu')(input_embed)
embed1=Reshape(shape)(embed1)
decoded1=decoder(embed1)
output1=Conv2DTranspose(1,3,padding='same')(decoded1)

embed2=Dense(np.prod(shape),activation='relu')(input_embed)
embed2=Reshape(shape)(embed2)
decoded2=decoder(embed2)
output2=Conv2DTranspose(1,3,padding='same')(decoded2)

# %%
encode=Model(input_blend,z)
encode.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           131104      ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_component1 = Input(shape=(height, width, 1))
input_component2 = Input(shape=(height, width, 1))

decode=Model([input_embed, input_component1, input_component2], [output1, output2])
decode.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  dense_2 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  dense_3 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 64)     0           ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 64)     0           ['dense_3[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['reshape[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 64)  0           ['reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  36928       ['up_sampling2d[0][0]']
#  ose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 64)  36928       ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose_3[0][0]']
#  spose)
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_1[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_4[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 381,698
# Trainable params: 381,698
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoding = encode(input_blend)
re1, re2 = decode([encoding, input_component1, input_component2])

vae = Model([input_blend, input_component1, input_component2], [re1, re2])

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model (Functional)             (None, 32)           281024      ['input_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_1 (Functional)           [(None, 64, 64, 1),  381698      ['model[0][0]',
#                                  (None, 64, 64, 1)]               'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 662,722
# Trainable params: 662,722
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
mse_lossA = mse(input_component1, re1) + mse(input_component2, re2)
mse_lossA = tf.reduce_mean(mse_lossA / 2, axis=(1, 2))
mse_lossB = mse(input_component1, re2) + mse(input_component2, re1)
mse_lossB = tf.reduce_mean(mse_lossB / 2, axis=(1, 2))
mse_loss = tf.reduce_mean(tf.minimum(mse_lossA, mse_lossB)) * height * width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss, 'mse_loss')

kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma-tf.square(z_mean)-tf.exp(z_log_sigma)))*0.1
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')


train_together = [train_blends, train_components[0], train_components[1]]
test_together = [test_blends, test_components[0], test_components[1]]

vae.compile(optimizer=Adam())

# %%
history=vae.fit(train_together, verbose = 1, epochs = 100, batch_size = batch_size, validation_split = 0.2)
# Out:
# Epoch 1/100
# 2022-04-28 23:11:32.984408: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2400/2400 [==============================] - 38s 13ms/step - loss: 2.9120 - mse_loss: 2.6970 - kl_loss: 0.2150 - val_loss: 1.8981 - val_mse_loss: 1.6599 - val_kl_loss: 0.2383
# Epoch 2/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6620 - mse_loss: 1.4316 - kl_loss: 0.2305 - val_loss: 1.5571 - val_mse_loss: 1.3291 - val_kl_loss: 0.2281
# Epoch 3/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4320 - mse_loss: 1.2035 - kl_loss: 0.2285 - val_loss: 1.3623 - val_mse_loss: 1.1369 - val_kl_loss: 0.2254
# Epoch 4/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.3072 - mse_loss: 1.0805 - kl_loss: 0.2267 - val_loss: 1.2846 - val_mse_loss: 1.0466 - val_kl_loss: 0.2380
# Epoch 5/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.2366 - mse_loss: 1.0107 - kl_loss: 0.2259 - val_loss: 1.1742 - val_mse_loss: 0.9514 - val_kl_loss: 0.2228
# Epoch 6/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.1786 - mse_loss: 0.9533 - kl_loss: 0.2252 - val_loss: 1.1512 - val_mse_loss: 0.9189 - val_kl_loss: 0.2323
# Epoch 7/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.1380 - mse_loss: 0.9141 - kl_loss: 0.2239 - val_loss: 1.1243 - val_mse_loss: 0.9149 - val_kl_loss: 0.2094
# Epoch 8/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0948 - mse_loss: 0.8710 - kl_loss: 0.2239 - val_loss: 1.0999 - val_mse_loss: 0.8876 - val_kl_loss: 0.2123
# Epoch 9/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0725 - mse_loss: 0.8494 - kl_loss: 0.2231 - val_loss: 1.0303 - val_mse_loss: 0.8017 - val_kl_loss: 0.2286
# Epoch 10/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0409 - mse_loss: 0.8176 - kl_loss: 0.2233 - val_loss: 1.1045 - val_mse_loss: 0.8817 - val_kl_loss: 0.2228
# Epoch 11/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0189 - mse_loss: 0.7964 - kl_loss: 0.2225 - val_loss: 1.0311 - val_mse_loss: 0.8010 - val_kl_loss: 0.2301
# Epoch 12/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 1.0037 - mse_loss: 0.7817 - kl_loss: 0.2220 - val_loss: 1.0179 - val_mse_loss: 0.7980 - val_kl_loss: 0.2199
# Epoch 13/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9870 - mse_loss: 0.7655 - kl_loss: 0.2215 - val_loss: 1.0002 - val_mse_loss: 0.7794 - val_kl_loss: 0.2208
# Epoch 14/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9758 - mse_loss: 0.7546 - kl_loss: 0.2212 - val_loss: 0.9945 - val_mse_loss: 0.7648 - val_kl_loss: 0.2296
# Epoch 15/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9604 - mse_loss: 0.7394 - kl_loss: 0.2211 - val_loss: 0.9582 - val_mse_loss: 0.7365 - val_kl_loss: 0.2217
# Epoch 16/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9522 - mse_loss: 0.7318 - kl_loss: 0.2204 - val_loss: 0.9861 - val_mse_loss: 0.7586 - val_kl_loss: 0.2274
# Epoch 17/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9464 - mse_loss: 0.7266 - kl_loss: 0.2198 - val_loss: 1.0828 - val_mse_loss: 0.8681 - val_kl_loss: 0.2148
# Epoch 18/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9347 - mse_loss: 0.7149 - kl_loss: 0.2198 - val_loss: 1.0198 - val_mse_loss: 0.8076 - val_kl_loss: 0.2122
# Epoch 19/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9337 - mse_loss: 0.7130 - kl_loss: 0.2206 - val_loss: 0.9510 - val_mse_loss: 0.7481 - val_kl_loss: 0.2029
# Epoch 20/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9087 - mse_loss: 0.6902 - kl_loss: 0.2186 - val_loss: 0.9059 - val_mse_loss: 0.6855 - val_kl_loss: 0.2204
# Epoch 21/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9197 - mse_loss: 0.7008 - kl_loss: 0.2189 - val_loss: 0.9430 - val_mse_loss: 0.7266 - val_kl_loss: 0.2164
# Epoch 22/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9048 - mse_loss: 0.6870 - kl_loss: 0.2178 - val_loss: 0.8936 - val_mse_loss: 0.6726 - val_kl_loss: 0.2210
# Epoch 23/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8979 - mse_loss: 0.6812 - kl_loss: 0.2168 - val_loss: 0.9161 - val_mse_loss: 0.6903 - val_kl_loss: 0.2259
# Epoch 24/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8859 - mse_loss: 0.6697 - kl_loss: 0.2162 - val_loss: 0.9229 - val_mse_loss: 0.6880 - val_kl_loss: 0.2349
# Epoch 25/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8862 - mse_loss: 0.6695 - kl_loss: 0.2168 - val_loss: 0.9153 - val_mse_loss: 0.7058 - val_kl_loss: 0.2095
# Epoch 26/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8732 - mse_loss: 0.6565 - kl_loss: 0.2167 - val_loss: 0.8863 - val_mse_loss: 0.6598 - val_kl_loss: 0.2265
# Epoch 27/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8851 - mse_loss: 0.6693 - kl_loss: 0.2158 - val_loss: 0.9034 - val_mse_loss: 0.6877 - val_kl_loss: 0.2156
# Epoch 28/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8744 - mse_loss: 0.6578 - kl_loss: 0.2167 - val_loss: 1.0388 - val_mse_loss: 0.8042 - val_kl_loss: 0.2345
# Epoch 29/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8669 - mse_loss: 0.6510 - kl_loss: 0.2159 - val_loss: 0.8823 - val_mse_loss: 0.6613 - val_kl_loss: 0.2209
# Epoch 30/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8560 - mse_loss: 0.6406 - kl_loss: 0.2154 - val_loss: 0.8614 - val_mse_loss: 0.6499 - val_kl_loss: 0.2116
# Epoch 31/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8510 - mse_loss: 0.6359 - kl_loss: 0.2151 - val_loss: 0.8551 - val_mse_loss: 0.6357 - val_kl_loss: 0.2194
# Epoch 32/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.8578 - mse_loss: 0.6414 - kl_loss: 0.2164 - val_loss: 0.8989 - val_mse_loss: 0.6710 - val_kl_loss: 0.2279
# Epoch 33/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8556 - mse_loss: 0.6421 - kl_loss: 0.2136 - val_loss: 0.8657 - val_mse_loss: 0.6505 - val_kl_loss: 0.2151
# Epoch 34/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8536 - mse_loss: 0.6388 - kl_loss: 0.2148 - val_loss: 0.8988 - val_mse_loss: 0.6685 - val_kl_loss: 0.2303
# Epoch 35/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8471 - mse_loss: 0.6318 - kl_loss: 0.2152 - val_loss: 0.8633 - val_mse_loss: 0.6514 - val_kl_loss: 0.2119
# Epoch 36/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8517 - mse_loss: 0.6374 - kl_loss: 0.2143 - val_loss: 0.8716 - val_mse_loss: 0.6576 - val_kl_loss: 0.2140
# Epoch 37/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8418 - mse_loss: 0.6277 - kl_loss: 0.2142 - val_loss: 0.8520 - val_mse_loss: 0.6289 - val_kl_loss: 0.2231
# Epoch 38/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8428 - mse_loss: 0.6290 - kl_loss: 0.2137 - val_loss: 0.9500 - val_mse_loss: 0.7267 - val_kl_loss: 0.2232
# Epoch 39/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8426 - mse_loss: 0.6278 - kl_loss: 0.2149 - val_loss: 0.9194 - val_mse_loss: 0.7065 - val_kl_loss: 0.2130
# Epoch 40/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8340 - mse_loss: 0.6208 - kl_loss: 0.2132 - val_loss: 0.9034 - val_mse_loss: 0.6877 - val_kl_loss: 0.2157
# Epoch 41/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8289 - mse_loss: 0.6155 - kl_loss: 0.2135 - val_loss: 0.9000 - val_mse_loss: 0.6733 - val_kl_loss: 0.2267
# Epoch 42/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8373 - mse_loss: 0.6234 - kl_loss: 0.2139 - val_loss: 0.8638 - val_mse_loss: 0.6444 - val_kl_loss: 0.2194
# Epoch 43/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8312 - mse_loss: 0.6182 - kl_loss: 0.2130 - val_loss: 0.9013 - val_mse_loss: 0.6920 - val_kl_loss: 0.2093
# Epoch 44/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8236 - mse_loss: 0.6120 - kl_loss: 0.2116 - val_loss: 0.8474 - val_mse_loss: 0.6457 - val_kl_loss: 0.2017
# Epoch 45/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8264 - mse_loss: 0.6132 - kl_loss: 0.2131 - val_loss: 0.8152 - val_mse_loss: 0.6000 - val_kl_loss: 0.2152
# Epoch 46/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.8178 - mse_loss: 0.6064 - kl_loss: 0.2114 - val_loss: 0.8340 - val_mse_loss: 0.6218 - val_kl_loss: 0.2122
# Epoch 47/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8141 - mse_loss: 0.6017 - kl_loss: 0.2125 - val_loss: 0.8407 - val_mse_loss: 0.6341 - val_kl_loss: 0.2066
# Epoch 48/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8220 - mse_loss: 0.6094 - kl_loss: 0.2126 - val_loss: 0.8415 - val_mse_loss: 0.6317 - val_kl_loss: 0.2098
# Epoch 49/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8213 - mse_loss: 0.6101 - kl_loss: 0.2112 - val_loss: 0.8744 - val_mse_loss: 0.6562 - val_kl_loss: 0.2182
# Epoch 50/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8158 - mse_loss: 0.6045 - kl_loss: 0.2113 - val_loss: 0.8131 - val_mse_loss: 0.6010 - val_kl_loss: 0.2121
# Epoch 51/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8051 - mse_loss: 0.5952 - kl_loss: 0.2099 - val_loss: 0.8675 - val_mse_loss: 0.6584 - val_kl_loss: 0.2091
# Epoch 52/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8054 - mse_loss: 0.5943 - kl_loss: 0.2111 - val_loss: 0.8119 - val_mse_loss: 0.6035 - val_kl_loss: 0.2084
# Epoch 53/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8084 - mse_loss: 0.5990 - kl_loss: 0.2095 - val_loss: 0.8379 - val_mse_loss: 0.6358 - val_kl_loss: 0.2021
# Epoch 54/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8042 - mse_loss: 0.5937 - kl_loss: 0.2105 - val_loss: 0.8301 - val_mse_loss: 0.6210 - val_kl_loss: 0.2091
# Epoch 55/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8028 - mse_loss: 0.5910 - kl_loss: 0.2117 - val_loss: 0.8334 - val_mse_loss: 0.6204 - val_kl_loss: 0.2130
# Epoch 56/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8102 - mse_loss: 0.6000 - kl_loss: 0.2102 - val_loss: 0.8328 - val_mse_loss: 0.6216 - val_kl_loss: 0.2112
# Epoch 57/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8089 - mse_loss: 0.5970 - kl_loss: 0.2119 - val_loss: 0.8565 - val_mse_loss: 0.6565 - val_kl_loss: 0.2000
# Epoch 58/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.8022 - mse_loss: 0.5912 - kl_loss: 0.2110 - val_loss: 0.8259 - val_mse_loss: 0.6160 - val_kl_loss: 0.2099
# Epoch 59/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8060 - mse_loss: 0.5954 - kl_loss: 0.2106 - val_loss: 0.8346 - val_mse_loss: 0.6129 - val_kl_loss: 0.2217
# Epoch 60/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8151 - mse_loss: 0.6033 - kl_loss: 0.2118 - val_loss: 0.8711 - val_mse_loss: 0.6587 - val_kl_loss: 0.2124
# Epoch 61/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8070 - mse_loss: 0.5965 - kl_loss: 0.2105 - val_loss: 0.8636 - val_mse_loss: 0.6458 - val_kl_loss: 0.2178
# Epoch 62/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7929 - mse_loss: 0.5835 - kl_loss: 0.2094 - val_loss: 0.7923 - val_mse_loss: 0.5806 - val_kl_loss: 0.2118
# Epoch 63/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7954 - mse_loss: 0.5853 - kl_loss: 0.2102 - val_loss: 0.8408 - val_mse_loss: 0.6351 - val_kl_loss: 0.2057
# Epoch 64/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8007 - mse_loss: 0.5911 - kl_loss: 0.2096 - val_loss: 0.8446 - val_mse_loss: 0.6417 - val_kl_loss: 0.2029
# Epoch 65/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8120 - mse_loss: 0.6018 - kl_loss: 0.2102 - val_loss: 0.8295 - val_mse_loss: 0.6142 - val_kl_loss: 0.2152
# Epoch 66/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8074 - mse_loss: 0.5988 - kl_loss: 0.2086 - val_loss: 0.8986 - val_mse_loss: 0.6772 - val_kl_loss: 0.2214
# Epoch 67/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7924 - mse_loss: 0.5837 - kl_loss: 0.2086 - val_loss: 0.8135 - val_mse_loss: 0.6030 - val_kl_loss: 0.2105
# Epoch 68/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8012 - mse_loss: 0.5910 - kl_loss: 0.2102 - val_loss: 0.8576 - val_mse_loss: 0.6554 - val_kl_loss: 0.2022
# Epoch 69/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8007 - mse_loss: 0.5916 - kl_loss: 0.2091 - val_loss: 0.8386 - val_mse_loss: 0.6359 - val_kl_loss: 0.2027
# Epoch 70/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8052 - mse_loss: 0.5955 - kl_loss: 0.2097 - val_loss: 0.8039 - val_mse_loss: 0.5924 - val_kl_loss: 0.2115
# Epoch 71/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8103 - mse_loss: 0.5995 - kl_loss: 0.2107 - val_loss: 0.8855 - val_mse_loss: 0.6792 - val_kl_loss: 0.2063
# Epoch 72/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7870 - mse_loss: 0.5778 - kl_loss: 0.2092 - val_loss: 0.8013 - val_mse_loss: 0.5913 - val_kl_loss: 0.2100
# Epoch 73/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7955 - mse_loss: 0.5857 - kl_loss: 0.2098 - val_loss: 0.8306 - val_mse_loss: 0.6268 - val_kl_loss: 0.2038
# Epoch 74/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.7837 - mse_loss: 0.5757 - kl_loss: 0.2080 - val_loss: 0.7879 - val_mse_loss: 0.5805 - val_kl_loss: 0.2074
# Epoch 75/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7858 - mse_loss: 0.5777 - kl_loss: 0.2081 - val_loss: 0.8457 - val_mse_loss: 0.6332 - val_kl_loss: 0.2124
# Epoch 76/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7807 - mse_loss: 0.5732 - kl_loss: 0.2074 - val_loss: 0.8304 - val_mse_loss: 0.6256 - val_kl_loss: 0.2048
# Epoch 77/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7964 - mse_loss: 0.5877 - kl_loss: 0.2087 - val_loss: 0.8691 - val_mse_loss: 0.6598 - val_kl_loss: 0.2093
# Epoch 78/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.7838 - mse_loss: 0.5761 - kl_loss: 0.2078 - val_loss: 0.8260 - val_mse_loss: 0.6161 - val_kl_loss: 0.2099
# Epoch 79/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7920 - mse_loss: 0.5836 - kl_loss: 0.2084 - val_loss: 0.8003 - val_mse_loss: 0.6016 - val_kl_loss: 0.1988
# Epoch 80/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.7791 - mse_loss: 0.5706 - kl_loss: 0.2085 - val_loss: 0.8029 - val_mse_loss: 0.6000 - val_kl_loss: 0.2029
# Epoch 81/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7786 - mse_loss: 0.5729 - kl_loss: 0.2058 - val_loss: 0.8181 - val_mse_loss: 0.6048 - val_kl_loss: 0.2134
# Epoch 82/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7943 - mse_loss: 0.5877 - kl_loss: 0.2067 - val_loss: 0.8723 - val_mse_loss: 0.6550 - val_kl_loss: 0.2173
# Epoch 83/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7934 - mse_loss: 0.5840 - kl_loss: 0.2094 - val_loss: 0.8405 - val_mse_loss: 0.6313 - val_kl_loss: 0.2093
# Epoch 84/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7847 - mse_loss: 0.5764 - kl_loss: 0.2083 - val_loss: 0.8333 - val_mse_loss: 0.6291 - val_kl_loss: 0.2042
# Epoch 85/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7844 - mse_loss: 0.5759 - kl_loss: 0.2084 - val_loss: 0.8709 - val_mse_loss: 0.6575 - val_kl_loss: 0.2134
# Epoch 86/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7915 - mse_loss: 0.5817 - kl_loss: 0.2098 - val_loss: 0.8419 - val_mse_loss: 0.6314 - val_kl_loss: 0.2105
# Epoch 87/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7750 - mse_loss: 0.5677 - kl_loss: 0.2073 - val_loss: 0.7813 - val_mse_loss: 0.5755 - val_kl_loss: 0.2059
# Epoch 88/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7785 - mse_loss: 0.5715 - kl_loss: 0.2070 - val_loss: 0.8409 - val_mse_loss: 0.6279 - val_kl_loss: 0.2129
# Epoch 89/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7707 - mse_loss: 0.5641 - kl_loss: 0.2066 - val_loss: 0.8296 - val_mse_loss: 0.6171 - val_kl_loss: 0.2125
# Epoch 90/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7792 - mse_loss: 0.5724 - kl_loss: 0.2069 - val_loss: 0.8257 - val_mse_loss: 0.6206 - val_kl_loss: 0.2051
# Epoch 91/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7843 - mse_loss: 0.5768 - kl_loss: 0.2075 - val_loss: 0.8540 - val_mse_loss: 0.6503 - val_kl_loss: 0.2037
# Epoch 92/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7791 - mse_loss: 0.5720 - kl_loss: 0.2071 - val_loss: 0.8047 - val_mse_loss: 0.5980 - val_kl_loss: 0.2067
# Epoch 93/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7755 - mse_loss: 0.5699 - kl_loss: 0.2057 - val_loss: 0.7576 - val_mse_loss: 0.5515 - val_kl_loss: 0.2061
# Epoch 94/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7782 - mse_loss: 0.5707 - kl_loss: 0.2075 - val_loss: 0.7712 - val_mse_loss: 0.5767 - val_kl_loss: 0.1945
# Epoch 95/100
# 2400/2400 [==============================] - 30s 12ms/step - loss: 0.7734 - mse_loss: 0.5677 - kl_loss: 0.2057 - val_loss: 0.7719 - val_mse_loss: 0.5751 - val_kl_loss: 0.1968
# Epoch 96/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7720 - mse_loss: 0.5660 - kl_loss: 0.2060 - val_loss: 0.8146 - val_mse_loss: 0.6134 - val_kl_loss: 0.2012
# Epoch 97/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7641 - mse_loss: 0.5586 - kl_loss: 0.2054 - val_loss: 0.7988 - val_mse_loss: 0.5872 - val_kl_loss: 0.2116
# Epoch 98/100
# 2400/2400 [==============================] - 30s 13ms/step - loss: 0.7710 - mse_loss: 0.5645 - kl_loss: 0.2065 - val_loss: 0.8131 - val_mse_loss: 0.6121 - val_kl_loss: 0.2010
# Epoch 99/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7641 - mse_loss: 0.5585 - kl_loss: 0.2056 - val_loss: 0.7929 - val_mse_loss: 0.5868 - val_kl_loss: 0.2061
# Epoch 100/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.7689 - mse_loss: 0.5621 - kl_loss: 0.2068 - val_loss: 0.8146 - val_mse_loss: 0.6087 - val_kl_loss: 0.2059

# %%
def histplot(history):
    plt.rcParams["figure.figsize"] = (10,7)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, label = 'Training loss')
    plt.plot(epochs, val_loss, label = 'Validation loss')
    plt.axhline( y = min(val_loss), color = 'black', linestyle = 'dotted', label = f'Minimum Validation Loss: {min(val_loss):.4f}')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
histplot(history)

# %%
def showimg(img, ax, title=None, vmin=0, vmax=1):
    ax.imshow(img.squeeze(), vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.axis('off')

def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    input_img = inputs[0][idx]
    comp1 = inputs[1][idx]
    comp2 = inputs[2][idx]
    z = encode.predict(input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    fig, ax = plt.subplots(7, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(input_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[0, i].set_title('Input Blend')
        ax[1, i].imshow(comp1[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[1, i].set_title('Input Component 1')
        ax[2, i].imshow(comp2[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[2, i].set_title('Input Component 2')
        ax[3, i].imshow(output_img1[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[3, i].set_title('Reconstruction Component 1')
        ax[3, i].set_xlabel(f'MSE: {mean_squared_error(comp1[i], output_img1[i]):.2f}, SSIM: {ssim(comp1[i], output_img1[i], channel_axis = 2):.2f}')
        ax[4, i].imshow(output_img2[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[4, i].set_title('Reconstruction Component 2')
        ax[5, i].imshow((output_img1[i] + output_img2[i]) , origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[5, i].set_title('Reconstruction Blend')
        ax[4, i].set_xlabel(f'MSE: {mean_squared_error(comp2[i], output_img2[i]):.2f}, SSIM: {ssim(comp2[i], output_img2[i], channel_axis = 2):.2f}')
        ax[6, i].imshow(abs(input_img[i] -(output_img1[i] + output_img2[i])) , origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[6, i].set_title('Blend Difference')
        plt.tight_layout()
    return idx

# %%
n=5
chosen=summary_plot(n,test_together,decode)
# Out:
# [ 6414 13523  8374  5256  4405]

# %%
def calc_ssim(inputs,decode):
    ssim_comp1 = np.zeros(test_ngals)
    ssim_comp2 = np.zeros(test_ngals)
    ssim_blends = np.zeros(test_ngals)
    input_img = inputs[0]
    comp1 = inputs[1]
    comp2 = inputs[2]
    z = encode.predict(input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    for i in range(test_ngals):
        ssim_comp1[i] = ssim(comp1[i], output_img1[i], channel_axis = 2)
        ssim_comp2[i] = ssim(comp2[i], output_img2[i], channel_axis = 2)
        ssim_blends[i] = ssim(input_img[i], (output_img1[i] + output_img2[i]), channel_axis = 2)
    mean_ssim_comp1 = np.mean(ssim_comp1)
    median_ssim_comp1 = np.median(ssim_comp1)
    
    mean_ssim_comp2 = np.mean(ssim_comp2)
    median_ssim_comp2 = np.median(ssim_comp2)
    
    mean_ssim_blends = np.mean(ssim_blends)
    median_ssim_blends = np.median(ssim_blends)
    
    ssim_values = np.array([mean_ssim_comp1, median_ssim_comp1, mean_ssim_comp2, median_ssim_comp2, mean_ssim_blends, median_ssim_blends])
    
    return ssim_values

# %%
ssim_values = calc_ssim(test_together, decode)

# %%
mean_ssim_comp1 = ssim_values[0]
median_ssim_comp1 = ssim_values[1]
mean_ssim_comp2 = ssim_values[2]
median_ssim_comp2 = ssim_values[3]
mean_ssim_blends = ssim_values[4]
median_ssim_blends = ssim_values[5]

# %%
print(f' Mean SSIMs: Component 1: {mean_ssim_comp1:.4f}, Component 2: {mean_ssim_comp2:.4f}, Blends: {mean_ssim_blends:.4f}')

print(f' Median SSIMs: Component 1: {median_ssim_comp1:.4f}, Component 2: {median_ssim_comp2:.4f}, Blends: {median_ssim_blends:.4f}')
# Out:
#  Mean SSIMs: Component 1: 0.9101, Component 2: 0.9102, Blends: 0.8745
#  Median SSIMs: Component 1: 0.9581, Component 2: 0.9576, Blends: 0.8763

# %%
#This function calculates the properties of the input and output images. The ellipticity and flux are stored in arrays 

def calc_properties(inputs,decode):
    
    empty_array = np.zeros(test_ngals)
    
    flux_in_comp1 = np.zeros(test_ngals)
    flux_in_comp2 = np.zeros(test_ngals)
    flux_in_blends = np.zeros(test_ngals)
    
    flux_out_comp1 = np.zeros(test_ngals)
    flux_out_comp2 = np.zeros(test_ngals)
    flux_out_blends = np.zeros(test_ngals)
    
    
    elip_in_comp1 = np.zeros(test_ngals)
    elip_in_comp2 = np.zeros(test_ngals)
    
    elip_out_comp1 = np.zeros(test_ngals)
    elip_out_comp2 = np.zeros(test_ngals)
    
    input_img = inputs[0]
    input_img = input_img.reshape(test_ngals, height, width)
    comp1 = inputs[1]
    comp1 = comp1.reshape(test_ngals, height, width)
    comp2 = inputs[2]
    comp2 = comp2.reshape(test_ngals, height,width)
    z = encode.predict(input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    
    output_img1 = output_img1.reshape(test_ngals, height, width)
    output_img2 = output_img2.reshape(test_ngals, height, width)
    
    for i in range(test_ngals):
        
        in_comp1_cat = photutils.morphology.data_properties(comp1[i], mask = None, background = 0)
        elip_in_comp1[i] = in_comp1_cat.ellipticity
        flux_in_comp1[i] = in_comp1_cat.segment_flux
        
        in_comp2_cat = photutils.morphology.data_properties(comp2[i], mask = None, background = 0)
  
        elip_in_comp2[i] = in_comp2_cat.ellipticity
        flux_in_comp2[i] = in_comp2_cat.segment_flux
        
        in_blends_cat = photutils.morphology.data_properties(input_img[i], mask = None, background = 0)
        flux_in_blends[i] = in_blends_cat.segment_flux

            
        out_comp1_cat = photutils.morphology.data_properties(output_img1[i], mask = None, background = 0)
        elip_out_comp1[i] = out_comp1_cat.ellipticity
        flux_out_comp1[i] = out_comp1_cat.segment_flux
        
        out_comp2_cat = photutils.morphology.data_properties(output_img2[i], mask = None, background = 0)
        elip_out_comp2[i] = out_comp2_cat.ellipticity
        flux_out_comp2[i] = out_comp2_cat.segment_flux
        
        out_blends_cat = photutils.morphology.data_properties((output_img1[i] + output_img2[i]), mask = None, background = 0)
        flux_out_blends[i] = out_blends_cat.segment_flux
        
        parameters = [elip_in_comp1, elip_out_comp1, flux_in_comp1, flux_out_comp1, elip_in_comp2, elip_out_comp2, flux_in_comp2, flux_out_comp2, flux_in_blends, flux_out_blends]   
    return parameters

# %%
parameters = calc_properties(test_together, decode)

# %%
ellip_in_comp1 = parameters[0]
ellip_out_comp1 = parameters[1]
flux_in_comp1 = parameters[2]
flux_out_comp1 = parameters[3]
ellip_in_comp2 = parameters[4]
ellip_out_comp2 = parameters[5]
flux_in_comp2 = parameters[6]
flux_out_comp2 = parameters[7]
flux_in_blends = parameters[8]
flux_out_blends = parameters[9]

# %%
#Calculate the standard deviations 
def calc_std(parameters):
    num_of_params = len(parameters)
    standard_dev_of_params = np.zeros(num_of_params)
    for i in range(0,num_of_params):
        standard_dev_of_params[i] = np.std(parameters[i])
    return standard_dev_of_params

# %%
std_of_params = calc_std(parameters)

# %%
print(f'Std dev of Ellip: Comp1 [In] {std_of_params[0]:.4f}, Comp1 [Out] {std_of_params[1]:.4f}, Comp2 [In] {std_of_params[4]:.4f}, Comp2 [Out] {std_of_params[5]:.4f} ')
print(f'Std dev of Flux: Comp1 [In] {std_of_params[2]:.4f}, Comp1 [Out] {std_of_params[3]:.4f}, Comp2 [In] {std_of_params[6]:.4f}, Comp2 [Out] {std_of_params[7]:.4f}, Blend [In] {std_of_params[8]:.4f}, Blend [Out] {std_of_params[9]:.4f} ')
# Out:
# Std dev of Ellip: Comp1 [In] 0.0264, Comp1 [Out] 0.0251, Comp2 [In] 0.0263, Comp2 [Out] 0.0255
# Std dev of Flux: Comp1 [In] 59.9252, Comp1 [Out] 54.6144, Comp2 [In] 59.8139, Comp2 [Out] 56.0164, Blend [In] 84.6733, Blend [Out] 83.0921

# %%
fig, axes = plt.subplots(1, 2, figsize = (13,5))

axes[0].set_title("Ellipticity of Component 1")
hex1 = axes[0].hexbin(ellip_in_comp1, ellip_out_comp1, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[0].set_xlabel("Ellipticity of Component 1 [Input]")
axes[0].set_ylabel("Ellipticity of Component 1 [Output]")
fig.colorbar(hex1, ax=axes[0])

lims = [
    np.min([axes[0].get_xlim(), axes[0].get_ylim()]),  # min of both axes
    np.max([axes[0].get_xlim(), axes[0].get_ylim()]),  # max of both axes
]


# now plot both limits against eachother
axes[0].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

axes[1].set_title("Ellipticity of Component 2")
hex2 = axes[1].hexbin(ellip_in_comp2, ellip_out_comp2, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[1].set_xlabel("Ellipticity Component 2 [Input]")
axes[1].set_ylabel("Ellipticity Component 2 [Output]")
fig.colorbar(hex2, ax=axes[1])

lims = [
    np.min([axes[1].get_xlim(), axes[1].get_ylim()]),  # min of both axes
    np.max([axes[1].get_xlim(), axes[1].get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
axes[1].plot(lims, lims, 'k-', alpha=0.5, zorder=1)


fig.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize = (17,5))

axes[0].set_title("Segment Flux of Component 1")
hex1 = axes[0].hexbin(flux_in_comp1, flux_out_comp1, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[0].set_xlabel("Segment Flux of Component 1 [Input]")
axes[0].set_ylabel("Segment Flux of Component 1 [Output]")
fig.colorbar(hex1, ax=axes[0])

lims = [
    np.min([axes[0].get_xlim(), axes[0].get_ylim()]),  # min of both axes
    np.max([axes[0].get_xlim(), axes[0].get_ylim()]),  # max of both axes
]


# now plot both limits against eachother
axes[0].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

axes[1].set_title("Segment Flux of Component 2")
hex2 = axes[1].hexbin(flux_in_comp2, flux_out_comp2, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[1].set_xlabel("Segment Flux of Component 2 [Input]")
axes[1].set_ylabel("Segment Flux of Component 2 [Output]")
fig.colorbar(hex2, ax=axes[1])

lims = [
    np.min([axes[1].get_xlim(), axes[1].get_ylim()]),  # min of both axes
    np.max([axes[1].get_xlim(), axes[1].get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
axes[1].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

axes[2].set_title("Segment Flux of Blend")
hex3 = axes[2].hexbin(flux_in_blends, flux_out_blends, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[2].set_xlabel("Segment Flux of Blend [Input]")
axes[2].set_ylabel("Segment Flux of Blend [Output]")
fig.colorbar(hex3, ax=axes[2])

lims = [
    np.min([axes[2].get_xlim(), axes[2].get_ylim()]),  # min of both axes
    np.max([axes[2].get_xlim(), axes[2].get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
axes[2].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

fig.tight_layout()

plt.show()

# %%
# Calculate accuracys 

ellip_comp1_accuracy = abs(ellip_out_comp1 / ellip_in_comp1) * 100
mean_ellip_comp1_accuracy = np.mean(ellip_comp1_accuracy)
median_ellip_comp1_accuracy = np.median(ellip_comp1_accuracy)

flux_comp1_accuracy = abs(flux_out_comp1 / flux_in_comp1) * 100
mean_flux_comp1_accuracy = np.mean(flux_comp1_accuracy)
median_flux_comp1_accuracy = np.median(flux_comp1_accuracy)

ellip_comp2_accuracy = abs(ellip_out_comp2 / ellip_in_comp2) * 100
mean_ellip_comp2_accuracy = np.mean(ellip_comp2_accuracy)
median_ellip_comp2_accuracy = np.median(ellip_comp2_accuracy)

flux_comp2_accuracy = abs(flux_out_comp2 / flux_in_comp2) * 100
mean_flux_comp2_accuracy = np.mean(flux_comp2_accuracy)
median_flux_comp2_accuracy = np.median(flux_comp2_accuracy)

flux_blend_accuracy = abs(flux_out_blends / flux_in_blends) * 100 
mean_flux_blend_accuracy = np.mean(flux_blend_accuracy)
median_flux_blend_accuracy = np.median(flux_blend_accuracy)

# %%
print(f' Mean ellipticity accuracys: Component 1: {mean_ellip_comp1_accuracy :.4f}, Component 2: {mean_ellip_comp2_accuracy:.4f}')
print(f' Median ellipticity accuracys: Component 1: {median_ellip_comp1_accuracy:.4f}, Component 2: {median_ellip_comp2_accuracy:.4f} \n')

print(f' Mean flux accuracys: Component 1: {mean_flux_comp1_accuracy:.4f}, Component 2: {mean_flux_comp2_accuracy:.4f}, Blends: {mean_flux_blend_accuracy:.4f}')
print(f' Median flux accuracys: Component 1: {median_flux_comp1_accuracy:.4f}, Component 2: {median_flux_comp2_accuracy:.4f}, Blends: {median_flux_blend_accuracy:.4f}')
# Out:
#  Mean ellipticity accuracys: Component 1: 126.0068, Component 2: 125.5985
#  Median ellipticity accuracys: Component 1: 94.1761, Component 2: 96.6785
#
#  Mean flux accuracys: Component 1: 101.1460, Component 2: 100.9987, Blends: 146.3530
#  Median flux accuracys: Component 1: 100.1603, Component 2: 99.5813, Blends: 145.4000
