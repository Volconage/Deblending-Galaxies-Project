# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn
import pandas as pd
import photutils

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

from photutils.detection import DAOStarFinder
from photutils.morphology import data_properties
from astropy.stats import mad_std

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Dense, Flatten, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

from tensorflow.config import list_logical_devices, list_physical_devices, set_visible_devices
from tensorflow.config.experimental import set_memory_growth

# %%
#Setup notebook so Tensorflow works in a friendly way in a shared multi GPU env

def setup_tensorflow(seed=None):
    try:
        import nvsmi

        gpu_mem_free = np.array([gpu.mem_free for gpu in nvsmi.get_gpus()])
        if len(gpu_mem_free) > 0 and (gpu_mem_free > 0).any():
            idx = np.argmax(gpu_mem_free)
            gpu = list_physical_devices("GPU")[idx]
            set_memory_growth(gpu, True)
            set_visible_devices(gpu, "GPU")
            gpus = list_logical_devices("GPU")
            print(f"Using GPU: {gpus}")
        else:
            raise Exception
    except:
        print(f"Tensorflow using CPU")
    tf.random.set_seed(seed)

# %%
setup_tensorflow()
# Out:
# Using GPU: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-04-28 15:02:53.200240: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-28 15:02:55.261924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9650 MB memory:  -> device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:17:00.0, compute capability: 7.5

# %%
#load the image arrays 

#Blends/Components 2 is where the blends have been made AFTER the galaxies have had noise and shift added to them not before

blends = np.load("blends2.npy")
components = np.load("components2.npy")

# %%
#Constant factor normalisation 

#Lets just divide them all by the maximum value found 

norm_max = np.max([ np.max(blends), np.max(components) ])

blends = blends / norm_max 

components = components / norm_max

# %%
blends.shape, components.shape
# Out:
# ((120000, 64, 64), (2, 120000, 64, 64))

# %%
#Split into training and test set 

#Going to split training and test 80% and 20% respectively 

train_ngals = int(blends.shape[0] * 0.8)
test_ngals = int(blends.shape[0] * 0.2)

train_blends = blends[:train_ngals]
test_blends = blends[train_ngals:]

a, b, c, d, test_components = np.split(components, 5, axis = 1)
`
train_components = np.concatenate((a, b, c, d), axis = 1)

# %%
np.amax(train_blends), np.amin(train_blends), np.amax(test_blends), np.amin(test_blends)
# Out:
# (1.0, -0.06057619365134562, 0.9295090699421322, -0.057384258024507716)

# %%
np.amax(test_components), np.amin(test_components), np.amax(test_blends), np.amin(test_blends)
# Out:
# (0.609042238445277,
#  -0.04360320433071323,
#  0.9295090699421322,
#  -0.057384258024507716)

# %%
height,width=64,64

train_blends = train_blends.reshape(train_ngals, height, width, 1).astype('float32')
train_components = train_components.reshape(2, train_ngals, height, width, 1).astype('float32')

test_blends = test_blends.reshape(test_ngals, height, width, 1).astype('float32')
test_components = test_components.reshape(2, test_ngals, height, width, 1).astype('float32')

# %%
batch_size = 32
latent_dimensions = 32

# %%
fig, ax = plt.subplots(2 + 1, 5, figsize=(15, 10))
for i in range(5):
    ax[0, i].imshow(train_blends[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
    ax[1, i].imshow(train_components[0, i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
    ax[2, i].imshow(train_components[1, i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)

# %%
#Will optimise encoder / decoder later
def encoder(x):
    x=Conv2D(32,3,activation='relu', strides = 2, padding='same')(x)
    x=Conv2D(64,3,activation='relu', strides = 2, padding='same')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    return x

# %%
def decoder(x):
    x=UpSampling2D(size=(2,2))(x)
    x=Conv2DTranspose(64,3,activation='relu', strides = 2 ,padding='same')(x)
    x=Conv2DTranspose(32,3,activation='relu', strides = 2 ,padding='same')(x)
    return x

# %%
def sampling(args):
    z_mean,z_log_sigma=args
    epsilon=tf.random.normal(shape=tf.shape(z_mean))
    z=z_mean+tf.exp(0.5*z_log_sigma)*epsilon
    return z

# %%
# encoder
input_blend=Input(shape=(height, width,1))

encoded=encoder(input_blend)
shape=encoded.get_shape()[1:]
encoded=Flatten()(encoded)

z_mean=Dense(latent_dimensions)(encoded)
z_log_sigma=Dense(latent_dimensions)(encoded)
z=Lambda(sampling)([z_mean,z_log_sigma])

# %%
# decoder
input_embed=Input(shape=latent_dimensions)

embed1=Dense(np.prod(shape),activation='relu')(input_embed)
embed1=Reshape(shape)(embed1)
decoded1=decoder(embed1)
output1=Conv2DTranspose(1,3,padding='same')(decoded1)

embed2=Dense(np.prod(shape),activation='relu')(input_embed)
embed2=Reshape(shape)(embed2)
decoded2=decoder(embed2)
output2=Conv2DTranspose(1,3,padding='same')(decoded2)

# %%
encode=Model(input_blend,z)
encode.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           131104      ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_component1 = Input(shape=(height, width, 1))
input_component2 = Input(shape=(height, width, 1))

decode=Model([input_embed, input_component1, input_component2], [output1, output2])
decode.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  dense_2 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  dense_3 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 64)     0           ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 64)     0           ['dense_3[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['reshape[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 64)  0           ['reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  36928       ['up_sampling2d[0][0]']
#  ose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 64)  36928       ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose_3[0][0]']
#  spose)
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_1[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_4[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 381,698
# Trainable params: 381,698
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoding = encode(input_blend)
re1, re2 = decode([encoding, input_component1, input_component2])

vae = Model([input_blend, input_component1, input_component2], [re1, re2])

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model (Functional)             (None, 32)           281024      ['input_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_1 (Functional)           [(None, 64, 64, 1),  381698      ['model[0][0]',
#                                  (None, 64, 64, 1)]               'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 662,722
# Trainable params: 662,722
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
mse_lossA = mse(input_component1, re1) + mse(input_component2, re2)
mse_lossA = tf.reduce_mean(mse_lossA / 2, axis=(1, 2))
mse_lossB = mse(input_component1, re2) + mse(input_component2, re1)
mse_lossB = tf.reduce_mean(mse_lossB / 2, axis=(1, 2))
mse_loss = tf.reduce_mean(tf.minimum(mse_lossA, mse_lossB)) * height * width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss, 'mse_loss')

kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma-tf.square(z_mean)-tf.exp(z_log_sigma)))*0.1
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')


train_together = [train_blends, train_components[0], train_components[1]]
test_together = [test_blends, test_components[0], test_components[1]]

vae.compile(optimizer=Adam())

# %%
history=vae.fit(train_together, verbose = 1, epochs = 100, batch_size = batch_size, validation_split = 0.2)
# Out:
# Epoch 1/100
# 2022-04-28 15:04:50.723066: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# 2400/2400 [==============================] - 38s 13ms/step - loss: 2.8012 - mse_loss: 2.5716 - kl_loss: 0.2296 - val_loss: 1.8665 - val_mse_loss: 1.6198 - val_kl_loss: 0.2467
# Epoch 2/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6499 - mse_loss: 1.4111 - kl_loss: 0.2388 - val_loss: 1.5640 - val_mse_loss: 1.3310 - val_kl_loss: 0.2330
# Epoch 3/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4288 - mse_loss: 1.1922 - kl_loss: 0.2367 - val_loss: 1.3889 - val_mse_loss: 1.1563 - val_kl_loss: 0.2326
# Epoch 4/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.3173 - mse_loss: 1.0815 - kl_loss: 0.2358 - val_loss: 1.2916 - val_mse_loss: 1.0600 - val_kl_loss: 0.2315
# Epoch 5/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.2263 - mse_loss: 0.9911 - kl_loss: 0.2352 - val_loss: 1.2621 - val_mse_loss: 1.0103 - val_kl_loss: 0.2518
# Epoch 6/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.1714 - mse_loss: 0.9377 - kl_loss: 0.2337 - val_loss: 1.1833 - val_mse_loss: 0.9552 - val_kl_loss: 0.2281
# Epoch 7/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.1300 - mse_loss: 0.8984 - kl_loss: 0.2316 - val_loss: 1.1178 - val_mse_loss: 0.8933 - val_kl_loss: 0.2245
# Epoch 8/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0857 - mse_loss: 0.8545 - kl_loss: 0.2312 - val_loss: 1.1731 - val_mse_loss: 0.9452 - val_kl_loss: 0.2279
# Epoch 9/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0754 - mse_loss: 0.8458 - kl_loss: 0.2296 - val_loss: 1.0986 - val_mse_loss: 0.8655 - val_kl_loss: 0.2330
# Epoch 10/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0580 - mse_loss: 0.8281 - kl_loss: 0.2299 - val_loss: 1.0372 - val_mse_loss: 0.8084 - val_kl_loss: 0.2289
# Epoch 11/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0303 - mse_loss: 0.8014 - kl_loss: 0.2289 - val_loss: 1.0453 - val_mse_loss: 0.8217 - val_kl_loss: 0.2237
# Epoch 12/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0078 - mse_loss: 0.7786 - kl_loss: 0.2292 - val_loss: 1.0621 - val_mse_loss: 0.8376 - val_kl_loss: 0.2244
# Epoch 13/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.0056 - mse_loss: 0.7779 - kl_loss: 0.2277 - val_loss: 0.9842 - val_mse_loss: 0.7594 - val_kl_loss: 0.2248
# Epoch 14/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9766 - mse_loss: 0.7499 - kl_loss: 0.2267 - val_loss: 1.0087 - val_mse_loss: 0.7806 - val_kl_loss: 0.2280
# Epoch 15/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9677 - mse_loss: 0.7410 - kl_loss: 0.2268 - val_loss: 1.0449 - val_mse_loss: 0.8195 - val_kl_loss: 0.2254
# Epoch 16/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9730 - mse_loss: 0.7472 - kl_loss: 0.2258 - val_loss: 1.0542 - val_mse_loss: 0.8370 - val_kl_loss: 0.2172
# Epoch 17/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9696 - mse_loss: 0.7435 - kl_loss: 0.2261 - val_loss: 0.9903 - val_mse_loss: 0.7540 - val_kl_loss: 0.2363
# Epoch 18/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9532 - mse_loss: 0.7269 - kl_loss: 0.2263 - val_loss: 0.9681 - val_mse_loss: 0.7318 - val_kl_loss: 0.2363
# Epoch 19/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9451 - mse_loss: 0.7189 - kl_loss: 0.2262 - val_loss: 0.9548 - val_mse_loss: 0.7271 - val_kl_loss: 0.2277
# Epoch 20/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9292 - mse_loss: 0.7056 - kl_loss: 0.2236 - val_loss: 0.9466 - val_mse_loss: 0.7209 - val_kl_loss: 0.2257
# Epoch 21/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9380 - mse_loss: 0.7133 - kl_loss: 0.2247 - val_loss: 0.9364 - val_mse_loss: 0.7149 - val_kl_loss: 0.2214
# Epoch 22/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9199 - mse_loss: 0.6959 - kl_loss: 0.2240 - val_loss: 0.9435 - val_mse_loss: 0.7190 - val_kl_loss: 0.2245
# Epoch 23/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9287 - mse_loss: 0.7033 - kl_loss: 0.2254 - val_loss: 0.9487 - val_mse_loss: 0.7293 - val_kl_loss: 0.2194
# Epoch 24/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9181 - mse_loss: 0.6944 - kl_loss: 0.2238 - val_loss: 0.9725 - val_mse_loss: 0.7459 - val_kl_loss: 0.2265
# Epoch 25/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9208 - mse_loss: 0.6962 - kl_loss: 0.2246 - val_loss: 0.9201 - val_mse_loss: 0.7018 - val_kl_loss: 0.2184
# Epoch 26/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9180 - mse_loss: 0.6937 - kl_loss: 0.2243 - val_loss: 0.9022 - val_mse_loss: 0.6784 - val_kl_loss: 0.2237
# Epoch 27/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9099 - mse_loss: 0.6863 - kl_loss: 0.2236 - val_loss: 0.8995 - val_mse_loss: 0.6795 - val_kl_loss: 0.2200
# Epoch 28/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9099 - mse_loss: 0.6867 - kl_loss: 0.2231 - val_loss: 0.9286 - val_mse_loss: 0.7036 - val_kl_loss: 0.2249
# Epoch 29/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8934 - mse_loss: 0.6701 - kl_loss: 0.2234 - val_loss: 0.9179 - val_mse_loss: 0.6890 - val_kl_loss: 0.2289
# Epoch 30/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8972 - mse_loss: 0.6736 - kl_loss: 0.2236 - val_loss: 0.9055 - val_mse_loss: 0.6890 - val_kl_loss: 0.2165
# Epoch 31/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8830 - mse_loss: 0.6612 - kl_loss: 0.2218 - val_loss: 0.8880 - val_mse_loss: 0.6670 - val_kl_loss: 0.2210
# Epoch 32/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8828 - mse_loss: 0.6612 - kl_loss: 0.2215 - val_loss: 0.9508 - val_mse_loss: 0.7327 - val_kl_loss: 0.2181
# Epoch 33/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.9025 - mse_loss: 0.6797 - kl_loss: 0.2228 - val_loss: 0.9023 - val_mse_loss: 0.6844 - val_kl_loss: 0.2179
# Epoch 34/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8890 - mse_loss: 0.6655 - kl_loss: 0.2235 - val_loss: 0.8913 - val_mse_loss: 0.6660 - val_kl_loss: 0.2253
# Epoch 35/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8837 - mse_loss: 0.6622 - kl_loss: 0.2214 - val_loss: 0.9559 - val_mse_loss: 0.7302 - val_kl_loss: 0.2257
# Epoch 36/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8800 - mse_loss: 0.6570 - kl_loss: 0.2231 - val_loss: 0.8844 - val_mse_loss: 0.6663 - val_kl_loss: 0.2181
# Epoch 37/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8843 - mse_loss: 0.6626 - kl_loss: 0.2216 - val_loss: 0.9201 - val_mse_loss: 0.6960 - val_kl_loss: 0.2240
# Epoch 38/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8837 - mse_loss: 0.6627 - kl_loss: 0.2210 - val_loss: 0.8707 - val_mse_loss: 0.6471 - val_kl_loss: 0.2236
# Epoch 39/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8576 - mse_loss: 0.6365 - kl_loss: 0.2211 - val_loss: 0.8920 - val_mse_loss: 0.6692 - val_kl_loss: 0.2228
# Epoch 40/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8716 - mse_loss: 0.6507 - kl_loss: 0.2208 - val_loss: 0.9773 - val_mse_loss: 0.7551 - val_kl_loss: 0.2223
# Epoch 41/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8805 - mse_loss: 0.6596 - kl_loss: 0.2209 - val_loss: 0.8866 - val_mse_loss: 0.6599 - val_kl_loss: 0.2267
# Epoch 42/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8720 - mse_loss: 0.6508 - kl_loss: 0.2212 - val_loss: 0.9396 - val_mse_loss: 0.7187 - val_kl_loss: 0.2209
# Epoch 43/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8594 - mse_loss: 0.6384 - kl_loss: 0.2210 - val_loss: 0.8778 - val_mse_loss: 0.6570 - val_kl_loss: 0.2209
# Epoch 44/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8552 - mse_loss: 0.6342 - kl_loss: 0.2210 - val_loss: 0.8667 - val_mse_loss: 0.6471 - val_kl_loss: 0.2197
# Epoch 45/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8654 - mse_loss: 0.6445 - kl_loss: 0.2209 - val_loss: 0.8400 - val_mse_loss: 0.6149 - val_kl_loss: 0.2251
# Epoch 46/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8694 - mse_loss: 0.6490 - kl_loss: 0.2203 - val_loss: 0.9067 - val_mse_loss: 0.6897 - val_kl_loss: 0.2170
# Epoch 47/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8608 - mse_loss: 0.6417 - kl_loss: 0.2190 - val_loss: 0.9099 - val_mse_loss: 0.6928 - val_kl_loss: 0.2171
# Epoch 48/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8622 - mse_loss: 0.6398 - kl_loss: 0.2224 - val_loss: 0.8667 - val_mse_loss: 0.6504 - val_kl_loss: 0.2163
# Epoch 49/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8668 - mse_loss: 0.6452 - kl_loss: 0.2216 - val_loss: 0.9138 - val_mse_loss: 0.6944 - val_kl_loss: 0.2194
# Epoch 50/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8662 - mse_loss: 0.6440 - kl_loss: 0.2222 - val_loss: 0.9342 - val_mse_loss: 0.6998 - val_kl_loss: 0.2343
# Epoch 51/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8542 - mse_loss: 0.6339 - kl_loss: 0.2203 - val_loss: 0.8937 - val_mse_loss: 0.6597 - val_kl_loss: 0.2340
# Epoch 52/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8392 - mse_loss: 0.6203 - kl_loss: 0.2189 - val_loss: 0.8829 - val_mse_loss: 0.6602 - val_kl_loss: 0.2227
# Epoch 53/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8484 - mse_loss: 0.6281 - kl_loss: 0.2204 - val_loss: 0.8290 - val_mse_loss: 0.6126 - val_kl_loss: 0.2164
# Epoch 54/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8616 - mse_loss: 0.6398 - kl_loss: 0.2217 - val_loss: 0.9267 - val_mse_loss: 0.7142 - val_kl_loss: 0.2125
# Epoch 55/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8444 - mse_loss: 0.6250 - kl_loss: 0.2194 - val_loss: 0.8912 - val_mse_loss: 0.6678 - val_kl_loss: 0.2234
# Epoch 56/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8567 - mse_loss: 0.6362 - kl_loss: 0.2205 - val_loss: 0.9050 - val_mse_loss: 0.6793 - val_kl_loss: 0.2257
# Epoch 57/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8528 - mse_loss: 0.6313 - kl_loss: 0.2215 - val_loss: 0.8608 - val_mse_loss: 0.6331 - val_kl_loss: 0.2276
# Epoch 58/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8424 - mse_loss: 0.6217 - kl_loss: 0.2207 - val_loss: 0.8538 - val_mse_loss: 0.6313 - val_kl_loss: 0.2225
# Epoch 59/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8387 - mse_loss: 0.6179 - kl_loss: 0.2208 - val_loss: 0.8373 - val_mse_loss: 0.6181 - val_kl_loss: 0.2191
# Epoch 60/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8465 - mse_loss: 0.6282 - kl_loss: 0.2183 - val_loss: 0.8543 - val_mse_loss: 0.6325 - val_kl_loss: 0.2219
# Epoch 61/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8442 - mse_loss: 0.6238 - kl_loss: 0.2204 - val_loss: 0.8710 - val_mse_loss: 0.6445 - val_kl_loss: 0.2265
# Epoch 62/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8392 - mse_loss: 0.6204 - kl_loss: 0.2189 - val_loss: 0.9440 - val_mse_loss: 0.7134 - val_kl_loss: 0.2305
# Epoch 63/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8460 - mse_loss: 0.6260 - kl_loss: 0.2201 - val_loss: 0.8437 - val_mse_loss: 0.6252 - val_kl_loss: 0.2185
# Epoch 64/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8280 - mse_loss: 0.6101 - kl_loss: 0.2179 - val_loss: 0.8906 - val_mse_loss: 0.6658 - val_kl_loss: 0.2248
# Epoch 65/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8697 - mse_loss: 0.6485 - kl_loss: 0.2213 - val_loss: 0.8963 - val_mse_loss: 0.6748 - val_kl_loss: 0.2215
# Epoch 66/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8518 - mse_loss: 0.6305 - kl_loss: 0.2213 - val_loss: 0.8235 - val_mse_loss: 0.6070 - val_kl_loss: 0.2165
# Epoch 67/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8516 - mse_loss: 0.6331 - kl_loss: 0.2185 - val_loss: 0.8487 - val_mse_loss: 0.6289 - val_kl_loss: 0.2198
# Epoch 68/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8503 - mse_loss: 0.6313 - kl_loss: 0.2190 - val_loss: 0.8456 - val_mse_loss: 0.6260 - val_kl_loss: 0.2196
# Epoch 69/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8312 - mse_loss: 0.6138 - kl_loss: 0.2174 - val_loss: 0.8663 - val_mse_loss: 0.6571 - val_kl_loss: 0.2092
# Epoch 70/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8376 - mse_loss: 0.6187 - kl_loss: 0.2188 - val_loss: 0.8568 - val_mse_loss: 0.6375 - val_kl_loss: 0.2192
# Epoch 71/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8342 - mse_loss: 0.6152 - kl_loss: 0.2190 - val_loss: 0.9037 - val_mse_loss: 0.6752 - val_kl_loss: 0.2285
# Epoch 72/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8200 - mse_loss: 0.6031 - kl_loss: 0.2169 - val_loss: 0.8654 - val_mse_loss: 0.6538 - val_kl_loss: 0.2116
# Epoch 73/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8419 - mse_loss: 0.6237 - kl_loss: 0.2182 - val_loss: 0.8745 - val_mse_loss: 0.6502 - val_kl_loss: 0.2243
# Epoch 74/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8304 - mse_loss: 0.6130 - kl_loss: 0.2175 - val_loss: 0.8930 - val_mse_loss: 0.6738 - val_kl_loss: 0.2192
# Epoch 75/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8440 - mse_loss: 0.6257 - kl_loss: 0.2184 - val_loss: 0.8744 - val_mse_loss: 0.6616 - val_kl_loss: 0.2127
# Epoch 76/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8472 - mse_loss: 0.6281 - kl_loss: 0.2191 - val_loss: 0.8971 - val_mse_loss: 0.6835 - val_kl_loss: 0.2136
# Epoch 77/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8228 - mse_loss: 0.6030 - kl_loss: 0.2198 - val_loss: 0.8814 - val_mse_loss: 0.6617 - val_kl_loss: 0.2197
# Epoch 78/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8274 - mse_loss: 0.6090 - kl_loss: 0.2184 - val_loss: 0.8385 - val_mse_loss: 0.6220 - val_kl_loss: 0.2165
# Epoch 79/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8377 - mse_loss: 0.6201 - kl_loss: 0.2176 - val_loss: 0.8517 - val_mse_loss: 0.6261 - val_kl_loss: 0.2256
# Epoch 80/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8307 - mse_loss: 0.6129 - kl_loss: 0.2177 - val_loss: 0.8125 - val_mse_loss: 0.5888 - val_kl_loss: 0.2237
# Epoch 81/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8301 - mse_loss: 0.6143 - kl_loss: 0.2157 - val_loss: 0.8812 - val_mse_loss: 0.6583 - val_kl_loss: 0.2229
# Epoch 82/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8363 - mse_loss: 0.6181 - kl_loss: 0.2182 - val_loss: 0.8518 - val_mse_loss: 0.6295 - val_kl_loss: 0.2223
# Epoch 83/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8269 - mse_loss: 0.6088 - kl_loss: 0.2181 - val_loss: 0.8765 - val_mse_loss: 0.6518 - val_kl_loss: 0.2246
# Epoch 84/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8565 - mse_loss: 0.6383 - kl_loss: 0.2182 - val_loss: 0.8511 - val_mse_loss: 0.6211 - val_kl_loss: 0.2300
# Epoch 85/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8364 - mse_loss: 0.6177 - kl_loss: 0.2187 - val_loss: 0.8488 - val_mse_loss: 0.6318 - val_kl_loss: 0.2171
# Epoch 86/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8349 - mse_loss: 0.6172 - kl_loss: 0.2177 - val_loss: 0.8981 - val_mse_loss: 0.6879 - val_kl_loss: 0.2102
# Epoch 87/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8095 - mse_loss: 0.5929 - kl_loss: 0.2166 - val_loss: 0.8304 - val_mse_loss: 0.6123 - val_kl_loss: 0.2181
# Epoch 88/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8196 - mse_loss: 0.6022 - kl_loss: 0.2174 - val_loss: 0.8798 - val_mse_loss: 0.6655 - val_kl_loss: 0.2143
# Epoch 89/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8256 - mse_loss: 0.6083 - kl_loss: 0.2173 - val_loss: 0.8200 - val_mse_loss: 0.6026 - val_kl_loss: 0.2174
# Epoch 90/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8185 - mse_loss: 0.6008 - kl_loss: 0.2177 - val_loss: 0.8525 - val_mse_loss: 0.6298 - val_kl_loss: 0.2228
# Epoch 91/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8407 - mse_loss: 0.6225 - kl_loss: 0.2182 - val_loss: 0.8733 - val_mse_loss: 0.6603 - val_kl_loss: 0.2130
# Epoch 92/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8284 - mse_loss: 0.6103 - kl_loss: 0.2180 - val_loss: 0.9165 - val_mse_loss: 0.7147 - val_kl_loss: 0.2018
# Epoch 93/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8102 - mse_loss: 0.5931 - kl_loss: 0.2171 - val_loss: 0.8415 - val_mse_loss: 0.6242 - val_kl_loss: 0.2172
# Epoch 94/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8312 - mse_loss: 0.6133 - kl_loss: 0.2179 - val_loss: 0.8602 - val_mse_loss: 0.6540 - val_kl_loss: 0.2062
# Epoch 95/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8354 - mse_loss: 0.6179 - kl_loss: 0.2175 - val_loss: 0.8620 - val_mse_loss: 0.6468 - val_kl_loss: 0.2152
# Epoch 96/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8379 - mse_loss: 0.6197 - kl_loss: 0.2182 - val_loss: 0.8731 - val_mse_loss: 0.6571 - val_kl_loss: 0.2160
# Epoch 97/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8229 - mse_loss: 0.6059 - kl_loss: 0.2169 - val_loss: 0.8528 - val_mse_loss: 0.6327 - val_kl_loss: 0.2201
# Epoch 98/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8246 - mse_loss: 0.6074 - kl_loss: 0.2172 - val_loss: 0.8561 - val_mse_loss: 0.6418 - val_kl_loss: 0.2142
# Epoch 99/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8386 - mse_loss: 0.6186 - kl_loss: 0.2201 - val_loss: 0.9275 - val_mse_loss: 0.7105 - val_kl_loss: 0.2170
# Epoch 100/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 0.8231 - mse_loss: 0.6047 - kl_loss: 0.2185 - val_loss: 0.8475 - val_mse_loss: 0.6255 - val_kl_loss: 0.2219

# %%
def histplot(history):
    plt.rcParams["figure.figsize"] = (10,7)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, label = 'Training loss')
    plt.plot(epochs, val_loss, label = 'Validation loss')
    plt.axhline( y = min(val_loss), color = 'black', linestyle = 'dotted', label = f'Minimum Validation Loss: {min(val_loss):.4f}')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
histplot(history)

# %%
def showimg(img, ax, title=None, vmin=0, vmax=1):
    ax.imshow(img.squeeze(), vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.axis('off')

def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    input_img = inputs[0][idx]
    comp1 = inputs[1][idx]
    comp2 = inputs[2][idx]
    z = encode.predict(input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    fig, ax = plt.subplots(7, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(input_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[0, i].set_title('Input Blend')
        ax[1, i].imshow(comp1[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[1, i].set_title('Input Component 1')
        ax[2, i].imshow(comp2[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[2, i].set_title('Input Component 2')
        ax[3, i].imshow(output_img1[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[3, i].set_title('Reconstruction Component 1')
        ax[3, i].set_xlabel(f'MSE: {mean_squared_error(comp1[i], output_img1[i]):.2f}, SSIM: {ssim(comp1[i], output_img1[i], channel_axis = 2):.2f}')
        ax[4, i].imshow(output_img2[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[4, i].set_title('Reconstruction Component 2')
        ax[5, i].imshow((output_img1[i] + output_img2[i]) , origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[5, i].set_title('Reconstruction Blend')
        ax[4, i].set_xlabel(f'MSE: {mean_squared_error(comp2[i], output_img2[i]):.2f}, SSIM: {ssim(comp2[i], output_img2[i], channel_axis = 2):.2f}')
        ax[6, i].imshow(abs(input_img[i] -(output_img1[i] + output_img2[i])) , origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[6, i].set_title('Blend Difference')
        plt.tight_layout()
    return idx

# %%
n=5
chosen=summary_plot(n,test_together,decode)
# Out:
# [ 6414 13523  8374  5256  4405]

# %%
def calc_ssim(inputs,decode):
    ssim_comp1 = np.zeros(test_ngals)
    ssim_comp2 = np.zeros(test_ngals)
    ssim_blends = np.zeros(test_ngals)
    input_img = inputs[0]
    comp1 = inputs[1]
    comp2 = inputs[2]
    z = encode.predict(input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    for i in range(test_ngals):
        ssim_comp1[i] = ssim(comp1[i], output_img1[i], channel_axis = 2)
        ssim_comp2[i] = ssim(comp2[i], output_img2[i], channel_axis = 2)
        ssim_blends[i] = ssim(input_img[i], (output_img1[i] + output_img2[i]), channel_axis = 2)
    mean_ssim_comp1 = np.mean(ssim_comp1)
    median_ssim_comp1 = np.median(ssim_comp1)
    
    mean_ssim_comp2 = np.mean(ssim_comp2)
    median_ssim_comp2 = np.median(ssim_comp2)
    
    mean_ssim_blends = np.mean(ssim_blends)
    median_ssim_blends = np.median(ssim_blends)
    
    ssim_values = np.array([mean_ssim_comp1, median_ssim_comp1, mean_ssim_comp2, median_ssim_comp2, mean_ssim_blends, median_ssim_blends])
    
    return ssim_values

# %%
ssim_values = calc_ssim(test_together, decode)

# %%
mean_ssim_comp1 = ssim_values[0]
median_ssim_comp1 = ssim_values[1]
mean_ssim_comp2 = ssim_values[2]
median_ssim_comp2 = ssim_values[3]
mean_ssim_blends = ssim_values[4]
median_ssim_blends = ssim_values[5]

# %%
print(f' Mean SSIMs: Component 1: {mean_ssim_comp1:.4f}, Component 2: {mean_ssim_comp2:.4f}, Blends: {mean_ssim_blends:.4f}')

print(f' Median SSIMs: Component 1: {median_ssim_comp1:.4f}, Component 2: {median_ssim_comp2:.4f}, Blends: {median_ssim_blends:.4f}')
# Out:
#  Mean SSIMs: Component 1: 0.8024, Component 2: 0.8013, Blends: 0.9628
#  Median SSIMs: Component 1: 0.8993, Component 2: 0.9017, Blends: 0.9654

# %%
#This function calculates the properties of the input and output images. The ellipticity and flux are stored in arrays 

def calc_properties(inputs,decode):
    
    empty_array = np.zeros(test_ngals)
    
    flux_in_comp1 = np.zeros(test_ngals)
    flux_in_comp2 = np.zeros(test_ngals)
    flux_in_blends = np.zeros(test_ngals)
    
    flux_out_comp1 = np.zeros(test_ngals)
    flux_out_comp2 = np.zeros(test_ngals)
    flux_out_blends = np.zeros(test_ngals)
    
    
    elip_in_comp1 = np.zeros(test_ngals)
    elip_in_comp2 = np.zeros(test_ngals)
    
    elip_out_comp1 = np.zeros(test_ngals)
    elip_out_comp2 = np.zeros(test_ngals)
    
    input_img = inputs[0]
    input_img = input_img.reshape(test_ngals, height, width)
    comp1 = inputs[1]
    comp1 = comp1.reshape(test_ngals, height, width)
    comp2 = inputs[2]
    comp2 = comp2.reshape(test_ngals, height,width)
    z = encode.predict(input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    
    output_img1 = output_img1.reshape(test_ngals, height, width)
    output_img2 = output_img2.reshape(test_ngals, height, width)
    
    for i in range(test_ngals):
        
        in_comp1_cat = photutils.morphology.data_properties(comp1[i], mask = None, background = 0)
        elip_in_comp1[i] = in_comp1_cat.ellipticity
        flux_in_comp1[i] = in_comp1_cat.segment_flux
        
        in_comp2_cat = photutils.morphology.data_properties(comp2[i], mask = None, background = 0)
  
        elip_in_comp2[i] = in_comp2_cat.ellipticity
        flux_in_comp2[i] = in_comp2_cat.segment_flux
        
        in_blends_cat = photutils.morphology.data_properties(input_img[i], mask = None, background = 0)
        flux_in_blends[i] = in_blends_cat.segment_flux

            
        out_comp1_cat = photutils.morphology.data_properties(output_img1[i], mask = None, background = 0)
        elip_out_comp1[i] = out_comp1_cat.ellipticity
        flux_out_comp1[i] = out_comp1_cat.segment_flux
        
        out_comp2_cat = photutils.morphology.data_properties(output_img2[i], mask = None, background = 0)
        elip_out_comp2[i] = out_comp2_cat.ellipticity
        flux_out_comp2[i] = out_comp2_cat.segment_flux
        
        out_blends_cat = photutils.morphology.data_properties((output_img1[i] + output_img2[i]), mask = None, background = 0)
        flux_out_blends[i] = out_blends_cat.segment_flux
        
        parameters = [elip_in_comp1, elip_out_comp1, flux_in_comp1, flux_out_comp1, elip_in_comp2, elip_out_comp2, flux_in_comp2, flux_out_comp2, flux_in_blends, flux_out_blends]   
    return parameters

# %%
parameters = calc_properties(test_together, decode)

# %%
ellip_in_comp1 = parameters[0]
ellip_out_comp1 = parameters[1]
flux_in_comp1 = parameters[2]
flux_out_comp1 = parameters[3]
ellip_in_comp2 = parameters[4]
ellip_out_comp2 = parameters[5]
flux_in_comp2 = parameters[6]
flux_out_comp2 = parameters[7]
flux_in_blends = parameters[8]
flux_out_blends = parameters[9]

# %%
#Calculate the standard deviations 
def calc_std(parameters):
    num_of_params = len(parameters)
    standard_dev_of_params = np.zeros(num_of_params)
    for i in range(0,num_of_params):
        standard_dev_of_params[i] = np.std(parameters[i])
    return standard_dev_of_params

# %%
std_of_params = calc_std(parameters)

# %%
print(f'Std dev of Ellip: Comp1 [In] {std_of_params[0]:.4f}, Comp1 [Out] {std_of_params[1]:.4f}, Comp2 [In] {std_of_params[4]:.4f}, Comp2 [Out] {std_of_params[5]:.4f} ')
print(f'Std dev of Flux: Comp1 [In] {std_of_params[2]:.4f}, Comp1 [Out] {std_of_params[3]:.4f}, Comp2 [In] {std_of_params[6]:.4f}, Comp2 [Out] {std_of_params[7]:.4f}, Blend [In] {std_of_params[8]:.4f}, Blend [Out] {std_of_params[9]:.4f} ')
# Out:
# Std dev of Ellip: Comp1 [In] 0.1202, Comp1 [Out] 0.1763, Comp2 [In] 0.1195, Comp2 [Out] 0.1973
# Std dev of Flux: Comp1 [In] 63.5553, Comp1 [Out] 62.1106, Comp2 [In] 63.4373, Comp2 [Out] 59.7303, Blend [In] 89.8025, Blend [Out] 88.9197

# %%
fig, axes = plt.subplots(1, 2, figsize = (13,5))

axes[0].set_title("Ellipticity of Component 1")
hex1 = axes[0].hexbin(ellip_in_comp1, ellip_out_comp1, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[0].set_xlabel("Ellipticity of Component 1 [Input]")
axes[0].set_ylabel("Ellipticity of Component 1 [Output]")
fig.colorbar(hex1, ax=axes[0])

lims = [
    np.min([axes[0].get_xlim(), axes[0].get_ylim()]),  # min of both axes
    np.max([axes[0].get_xlim(), axes[0].get_ylim()]),  # max of both axes
]


# now plot both limits against eachother
axes[0].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

axes[1].set_title("Ellipticity of Component 2")
hex2 = axes[1].hexbin(ellip_in_comp2, ellip_out_comp2, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[1].set_xlabel("Ellipticity Component 2 [Input]")
axes[1].set_ylabel("Ellipticity Component 2 [Output]")
fig.colorbar(hex2, ax=axes[1])

lims = [
    np.min([axes[1].get_xlim(), axes[1].get_ylim()]),  # min of both axes
    np.max([axes[1].get_xlim(), axes[1].get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
axes[1].plot(lims, lims, 'k-', alpha=0.5, zorder=1)


fig.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize = (17,5))

axes[0].set_title("Segment Flux of Component 1")
hex1 = axes[0].hexbin(flux_in_comp1, flux_out_comp1, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[0].set_xlabel("Segment Flux of Component 1 [Input]")
axes[0].set_ylabel("Segment Flux of Component 1 [Output]")
fig.colorbar(hex1, ax=axes[0])

lims = [
    np.min([axes[0].get_xlim(), axes[0].get_ylim()]),  # min of both axes
    np.max([axes[0].get_xlim(), axes[0].get_ylim()]),  # max of both axes
]


# now plot both limits against eachother
axes[0].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

axes[1].set_title("Segment Flux of Component 2")
hex2 = axes[1].hexbin(flux_in_comp2, flux_out_comp2, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[1].set_xlabel("Segment Flux of Component 2 [Input]")
axes[1].set_ylabel("Segment Flux of Component 2 [Output]")
fig.colorbar(hex2, ax=axes[1])

lims = [
    np.min([axes[1].get_xlim(), axes[1].get_ylim()]),  # min of both axes
    np.max([axes[1].get_xlim(), axes[1].get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
axes[1].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

axes[2].set_title("Segment Flux of Blend")
hex3 = axes[2].hexbin(flux_in_blends, flux_out_blends, gridsize=30, cmap='Blues', mincnt=10, alpha=0.7)
axes[2].set_xlabel("Segment Flux of Blend [Input]")
axes[2].set_ylabel("Segment Flux of Blend [Output]")
fig.colorbar(hex3, ax=axes[2])

lims = [
    np.min([axes[2].get_xlim(), axes[2].get_ylim()]),  # min of both axes
    np.max([axes[2].get_xlim(), axes[2].get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
axes[2].plot(lims, lims, 'k-', alpha=0.5, zorder=1)

fig.tight_layout()

plt.show()

# %%
# Calculate accuracys 

ellip_comp1_accuracy = abs(ellip_out_comp1 / ellip_in_comp1) * 100
mean_ellip_comp1_accuracy = np.mean(ellip_comp1_accuracy)
median_ellip_comp1_accuracy = np.median(ellip_comp1_accuracy)

flux_comp1_accuracy = abs(flux_out_comp1 / flux_in_comp1) * 100
mean_flux_comp1_accuracy = np.mean(flux_comp1_accuracy)
median_flux_comp1_accuracy = np.median(flux_comp1_accuracy)

ellip_comp2_accuracy = abs(ellip_out_comp2 / ellip_in_comp2) * 100
mean_ellip_comp2_accuracy = np.mean(ellip_comp2_accuracy)
median_ellip_comp2_accuracy = np.median(ellip_comp2_accuracy)

flux_comp2_accuracy = abs(flux_out_comp2 / flux_in_comp2) * 100
mean_flux_comp2_accuracy = np.mean(flux_comp2_accuracy)
median_flux_comp2_accuracy = np.median(flux_comp2_accuracy)

flux_blend_accuracy = abs(flux_out_blends / flux_in_blends) * 100 
mean_flux_blend_accuracy = np.mean(flux_blend_accuracy)
median_flux_blend_accuracy = np.median(flux_blend_accuracy)

# %%
print(f' Mean ellipticity accuracys: Component 1: {mean_ellip_comp1_accuracy :.4f}, Component 2: {mean_ellip_comp2_accuracy:.4f}')
print(f' Median ellipticity accuracys: Component 1: {median_ellip_comp1_accuracy:.4f}, Component 2: {median_ellip_comp2_accuracy:.4f} \n')

print(f' Mean flux accuracys: Component 1: {mean_flux_comp1_accuracy:.4f}, Component 2: {mean_flux_comp2_accuracy:.4f}, Blends: {mean_flux_blend_accuracy:.4f}')
print(f' Median flux accuracys: Component 1: {median_flux_comp1_accuracy:.4f}, Component 2: {median_flux_comp2_accuracy:.4f}, Blends: {median_flux_blend_accuracy:.4f}')
# Out:
#  Mean ellipticity accuracys: Component 1: 229.8558, Component 2: 230.1850
#  Median ellipticity accuracys: Component 1: 124.4664, Component 2: 134.4164
#
#  Mean flux accuracys: Component 1: 114.5763, Component 2: 107.7545, Blends: 99.1933
#  Median flux accuracys: Component 1: 103.5511, Component 2: 95.0672, Blends: 99.1450
