# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import photutils

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

from photutils.detection import DAOStarFinder
from photutils.morphology import data_properties
from astropy.stats import mad_std
from numpy.random import normal

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Dense, Flatten, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

from tensorflow.config import list_logical_devices, list_physical_devices, set_visible_devices
from tensorflow.config.experimental import set_memory_growth

# %%
#Setup notebook so Tensorflow works in a friendly way in a shared multi GPU env

def setup_tensorflow(seed=None):
    try:
        import nvsmi
        gpu_mem_free = np.array([gpu.mem_free for gpu in nvsmi.get_gpus()])
        if len(gpu_mem_free) > 0 and (gpu_mem_free > 0).any():
            idx = np.argmax(gpu_mem_free)
            gpu = list_physical_devices("GPU")[idx]
            set_memory_growth(gpu, True)
            set_visible_devices(gpu, "GPU")
            gpus = list_logical_devices("GPU")
            print(f"Using GPU: {gpus}")
        else:
            raise Exception
    except:
        print(f"Tensorflow using CPU")
    tf.random.set_seed(seed)

# %%
#If working in a multiply GPU setup run setup_tensorflow()

setup_tensorflow()
# Out:
# Using GPU: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-05-19 18:26:58.165516: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#load the image arrays, Size: (ngals, 64, 64), (2, ngals, 64, 64) respectively 

#Blends and components arrays are both noiseless

#Noise is then added to the blends which the network trains on

#Noiseless blends are used for the metrics 

blends = np.load("c_blends.npy")
components = np.load("c_components.npy")

# %%
def add_noise(img, scale=0.01):
    return img + normal(scale=scale, size=img.shape)

# %%
blends.shape, components.shape
# Out:
# ((120000, 64, 64), (2, 120000, 64, 64))

# %%
np.mean(blends), np.mean(components)
# Out:
# (0.3124135834937247, 0.15620679174686417)

# %%
#Split into training and test set 

#Going to split training and test 80% and 20% respectively 

train_ngals = int(blends.shape[0] * 0.8)
test_ngals = int(blends.shape[0] * 0.2)

train_blends = blends[:train_ngals]
test_blends = blends[train_ngals:]

a, b, c, d, test_components = np.split(components, 5, axis = 1)

train_components = np.concatenate((a, b, c, d), axis = 1)

# %%
#Add noise to the training blends 

#Note we have split them up before encase later on we would like to change if our train / test blends have noise

train_blends = add_noise(train_blends)
test_blends = add_noise(test_blends)

# %%
#Now normalise based on maximum value of the arrays

norm_max = np.max([ np.max(train_blends), np.max(test_blends), np.max(train_components), np.max(test_components)])

train_blends /= norm_max
test_blends /= norm_max
train_components /= norm_max
test_components /= norm_max

# %%
train_components.shape, test_components.shape
# Out:
# ((2, 96000, 64, 64), (2, 24000, 64, 64))

# %%
train_blends.shape, test_blends.shape
# Out:
# ((96000, 64, 64), (24000, 64, 64))

# %%
np.amax(train_blends), np.amin(train_blends), np.amax(test_blends), np.amin(test_blends)
# Out:
# (1.0, -0.010256837125201031, 0.9269649160773504, -0.009709387200735983)

# %%
np.amax(test_components), np.amin(test_components), np.amax(test_blends), np.amin(test_blends)
# Out:
# (0.6400044097617515,
#  2.4077330747973892e-32,
#  0.9269649160773504,
#  -0.009709387200735983)

# %%
height,width=64,64

train_blends = train_blends.reshape(train_ngals, height, width, 1).astype('float32')
train_components = train_components.reshape(2, train_ngals, height, width, 1).astype('float32')

test_blends = test_blends.reshape(test_ngals, height, width, 1).astype('float32')
test_components = test_components.reshape(2, test_ngals, height, width, 1).astype('float32')

# %%
batch_size = 32
latent_dimensions = 32

# %%
fig, ax = plt.subplots(train_components.shape[0] + 1, 5, figsize=(15, 10))
for i in range(5):
    ax[0, i].imshow(train_blends[i], origin='lower', interpolation='nearest')
    ax[0, i].axis('off')
    ax[1, i].imshow(train_components[0, i], origin='lower', interpolation='nearest')
    ax[1, i].axis('off')
    ax[2, i].imshow(train_components[1, i], origin='lower', interpolation='nearest')
    ax[2, i].axis('off')

# %%
#Will optimise encoder / decoder later
def encoder(x):
    x = Conv2D(32,3,activation='relu',padding='same', strides=2)(x)
    x = Conv2D(64,3,activation='relu',padding='same', strides=2)(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    return x

# %%
def decoder(x):
    x = UpSampling2D(size=(2,2))(x)
    x = Conv2DTranspose(64,3,activation='relu',padding='same', strides=2)(x)
    x = Conv2DTranspose(32,3,activation='relu',padding='same', strides=2)(x)
    return x

# %%
def sampling(args):
    z_mean,z_log_sigma=args
    epsilon=tf.random.normal(shape=tf.shape(z_mean))
    z=z_mean+tf.exp(0.5*z_log_sigma)*epsilon
    return z

# %%
# encoder
input_blend=Input(shape=(height, width,1))

encoded=encoder(input_blend)
shape=encoded.get_shape()[1:]
encoded=Flatten()(encoded)

z_mean=Dense(latent_dimensions)(encoded)
z_log_sigma=Dense(latent_dimensions)(encoded)
z=Lambda(sampling)([z_mean,z_log_sigma])

# %%
# decoder
input_embed=Input(shape=latent_dimensions)

embed1=Dense(np.prod(shape),activation='relu')(input_embed)
embed1=Reshape(shape)(embed1)
decoded1=decoder(embed1)
output1=Conv2DTranspose(1,3,padding='same')(decoded1)

# %%
encode=Model(input_blend,z)
encode.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           131104      ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_component1 = Input(shape=(height, width, 1))

decode=Model([input_embed, input_component1], [output1])
decode.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  dense_2 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 64)     0           ['dense_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['reshape[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  36928       ['up_sampling2d[0][0]']
#  ose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose[0][0]']
#  spose)
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_1[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 190,849
# Trainable params: 190,849
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoding = encode(input_blend)
re1 = decode([encoding, input_component1])

vae = Model([input_blend, input_component1], [re1])

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model (Functional)             (None, 32)           281024      ['input_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_1 (Functional)           (None, 64, 64, 1)    190849      ['model[0][0]',
#                                                                   'input_3[0][0]']
#
# ==================================================================================================
# Total params: 471,873
# Trainable params: 471,873
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#In our loss we are only going to compare to the central image i.e component 1 

mse_loss = tf.reduce_mean(mse(input_component1,re1)) * height * width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss, 'mse_loss')

beta = 0.1 
kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma-tf.square(z_mean)-tf.exp(z_log_sigma)))*beta
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')


train_together = [train_blends, train_components[0]]
test_together = [test_blends, test_components[0]]

#need an array which has the blends and both components for later use of calculating metrics - this will be using the test set 

metrics_together = [test_blends, test_components[0], test_components[1]]


vae.compile(optimizer=Adam())

# %%
val_split_ratio = 0.2
print(val_split_ratio * train_ngals)
# Out:
# 19200.0

# %%
#training
history=vae.fit(train_together, verbose=1, epochs=100, batch_size=batch_size, validation_split = val_split_ratio)
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 32s 12ms/step - loss: 0.9604 - mse_loss: 0.8312 - kl_loss: 0.1292 - val_loss: 0.6479 - val_mse_loss: 0.5359 - val_kl_loss: 0.1120
# Epoch 2/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.5103 - mse_loss: 0.4018 - kl_loss: 0.1084 - val_loss: 0.4335 - val_mse_loss: 0.3313 - val_kl_loss: 0.1022
# Epoch 3/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.3985 - mse_loss: 0.2980 - kl_loss: 0.1004 - val_loss: 0.3553 - val_mse_loss: 0.2546 - val_kl_loss: 0.1007
# Epoch 4/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.3489 - mse_loss: 0.2553 - kl_loss: 0.0937 - val_loss: 0.3332 - val_mse_loss: 0.2402 - val_kl_loss: 0.0930
# Epoch 5/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.3126 - mse_loss: 0.2226 - kl_loss: 0.0900 - val_loss: 0.3003 - val_mse_loss: 0.2147 - val_kl_loss: 0.0856
# Epoch 6/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2882 - mse_loss: 0.2015 - kl_loss: 0.0867 - val_loss: 0.2852 - val_mse_loss: 0.2047 - val_kl_loss: 0.0805
# Epoch 7/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2708 - mse_loss: 0.1873 - kl_loss: 0.0834 - val_loss: 0.2733 - val_mse_loss: 0.1931 - val_kl_loss: 0.0802
# Epoch 8/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2560 - mse_loss: 0.1746 - kl_loss: 0.0814 - val_loss: 0.2589 - val_mse_loss: 0.1756 - val_kl_loss: 0.0833
# Epoch 9/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2433 - mse_loss: 0.1636 - kl_loss: 0.0796 - val_loss: 0.2289 - val_mse_loss: 0.1477 - val_kl_loss: 0.0812
# Epoch 10/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2349 - mse_loss: 0.1565 - kl_loss: 0.0784 - val_loss: 0.2308 - val_mse_loss: 0.1532 - val_kl_loss: 0.0776
# Epoch 11/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2276 - mse_loss: 0.1502 - kl_loss: 0.0774 - val_loss: 0.2305 - val_mse_loss: 0.1578 - val_kl_loss: 0.0727
# Epoch 12/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2216 - mse_loss: 0.1449 - kl_loss: 0.0766 - val_loss: 0.2337 - val_mse_loss: 0.1561 - val_kl_loss: 0.0776
# Epoch 13/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2144 - mse_loss: 0.1390 - kl_loss: 0.0754 - val_loss: 0.2090 - val_mse_loss: 0.1373 - val_kl_loss: 0.0717
# Epoch 14/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2107 - mse_loss: 0.1360 - kl_loss: 0.0747 - val_loss: 0.2014 - val_mse_loss: 0.1264 - val_kl_loss: 0.0750
# Epoch 15/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2062 - mse_loss: 0.1322 - kl_loss: 0.0741 - val_loss: 0.2163 - val_mse_loss: 0.1445 - val_kl_loss: 0.0718
# Epoch 16/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.2035 - mse_loss: 0.1299 - kl_loss: 0.0735 - val_loss: 0.2313 - val_mse_loss: 0.1559 - val_kl_loss: 0.0755
# Epoch 17/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1980 - mse_loss: 0.1252 - kl_loss: 0.0728 - val_loss: 0.2066 - val_mse_loss: 0.1361 - val_kl_loss: 0.0704
# Epoch 18/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1949 - mse_loss: 0.1224 - kl_loss: 0.0725 - val_loss: 0.2068 - val_mse_loss: 0.1319 - val_kl_loss: 0.0749
# Epoch 19/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1916 - mse_loss: 0.1197 - kl_loss: 0.0719 - val_loss: 0.1922 - val_mse_loss: 0.1194 - val_kl_loss: 0.0729
# Epoch 20/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1895 - mse_loss: 0.1181 - kl_loss: 0.0713 - val_loss: 0.1865 - val_mse_loss: 0.1177 - val_kl_loss: 0.0687
# Epoch 21/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1877 - mse_loss: 0.1168 - kl_loss: 0.0708 - val_loss: 0.1936 - val_mse_loss: 0.1229 - val_kl_loss: 0.0707
# Epoch 22/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1842 - mse_loss: 0.1137 - kl_loss: 0.0705 - val_loss: 0.1847 - val_mse_loss: 0.1127 - val_kl_loss: 0.0721
# Epoch 23/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1835 - mse_loss: 0.1132 - kl_loss: 0.0702 - val_loss: 0.2021 - val_mse_loss: 0.1284 - val_kl_loss: 0.0738
# Epoch 24/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1795 - mse_loss: 0.1098 - kl_loss: 0.0697 - val_loss: 0.1968 - val_mse_loss: 0.1258 - val_kl_loss: 0.0710
# Epoch 25/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1787 - mse_loss: 0.1093 - kl_loss: 0.0694 - val_loss: 0.1789 - val_mse_loss: 0.1110 - val_kl_loss: 0.0679
# Epoch 26/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1756 - mse_loss: 0.1067 - kl_loss: 0.0688 - val_loss: 0.1950 - val_mse_loss: 0.1244 - val_kl_loss: 0.0706
# Epoch 27/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1753 - mse_loss: 0.1066 - kl_loss: 0.0687 - val_loss: 0.1867 - val_mse_loss: 0.1167 - val_kl_loss: 0.0700
# Epoch 28/100
# 2400/2400 [==============================] - 26s 11ms/step - loss: 0.1762 - mse_loss: 0.1074 - kl_loss: 0.0688 - val_loss: 0.1791 - val_mse_loss: 0.1089 - val_kl_loss: 0.0702
# Epoch 29/100
# 2400/2400 [==============================] - 27s 11ms/step - loss: 0.1694 - mse_loss: 0.1014 - kl_loss: 0.0680 - val_loss: 0.1711 - val_mse_loss: 0.1023 - val_kl_loss: 0.0689
# Epoch 30/100
# 2400/2400 [==============================] - 28s 12ms/step - loss: 0.1693 - mse_loss: 0.1017 - kl_loss: 0.0676 - val_loss: 0.1963 - val_mse_loss: 0.1280 - val_kl_loss: 0.0683
# Epoch 31/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1695 - mse_loss: 0.1016 - kl_loss: 0.0679 - val_loss: 0.1803 - val_mse_loss: 0.1112 - val_kl_loss: 0.0691
# Epoch 32/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.1678 - mse_loss: 0.1004 - kl_loss: 0.0674 - val_loss: 0.1742 - val_mse_loss: 0.1084 - val_kl_loss: 0.0658
# Epoch 33/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1661 - mse_loss: 0.0988 - kl_loss: 0.0673 - val_loss: 0.1854 - val_mse_loss: 0.1148 - val_kl_loss: 0.0706
# Epoch 34/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1639 - mse_loss: 0.0972 - kl_loss: 0.0667 - val_loss: 0.1841 - val_mse_loss: 0.1164 - val_kl_loss: 0.0677
# Epoch 35/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1637 - mse_loss: 0.0967 - kl_loss: 0.0670 - val_loss: 0.1643 - val_mse_loss: 0.0986 - val_kl_loss: 0.0656
# Epoch 36/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1623 - mse_loss: 0.0959 - kl_loss: 0.0664 - val_loss: 0.1640 - val_mse_loss: 0.0978 - val_kl_loss: 0.0662
# Epoch 37/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1623 - mse_loss: 0.0961 - kl_loss: 0.0661 - val_loss: 0.1657 - val_mse_loss: 0.0984 - val_kl_loss: 0.0673
# Epoch 38/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1601 - mse_loss: 0.0939 - kl_loss: 0.0662 - val_loss: 0.1622 - val_mse_loss: 0.0951 - val_kl_loss: 0.0671
# Epoch 39/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1619 - mse_loss: 0.0958 - kl_loss: 0.0661 - val_loss: 0.1682 - val_mse_loss: 0.0993 - val_kl_loss: 0.0689
# Epoch 40/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1579 - mse_loss: 0.0923 - kl_loss: 0.0656 - val_loss: 0.1813 - val_mse_loss: 0.1147 - val_kl_loss: 0.0666
# Epoch 41/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1592 - mse_loss: 0.0935 - kl_loss: 0.0657 - val_loss: 0.1639 - val_mse_loss: 0.0973 - val_kl_loss: 0.0665
# Epoch 42/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1565 - mse_loss: 0.0910 - kl_loss: 0.0655 - val_loss: 0.1692 - val_mse_loss: 0.1030 - val_kl_loss: 0.0662
# Epoch 43/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1569 - mse_loss: 0.0915 - kl_loss: 0.0654 - val_loss: 0.1598 - val_mse_loss: 0.0931 - val_kl_loss: 0.0667
# Epoch 44/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1537 - mse_loss: 0.0888 - kl_loss: 0.0649 - val_loss: 0.1652 - val_mse_loss: 0.0979 - val_kl_loss: 0.0673
# Epoch 45/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1563 - mse_loss: 0.0911 - kl_loss: 0.0651 - val_loss: 0.1664 - val_mse_loss: 0.0993 - val_kl_loss: 0.0671
# Epoch 46/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1535 - mse_loss: 0.0887 - kl_loss: 0.0647 - val_loss: 0.1602 - val_mse_loss: 0.0970 - val_kl_loss: 0.0631
# Epoch 47/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1571 - mse_loss: 0.0921 - kl_loss: 0.0650 - val_loss: 0.1660 - val_mse_loss: 0.1007 - val_kl_loss: 0.0654
# Epoch 48/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1511 - mse_loss: 0.0866 - kl_loss: 0.0645 - val_loss: 0.1542 - val_mse_loss: 0.0890 - val_kl_loss: 0.0652
# Epoch 49/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1548 - mse_loss: 0.0901 - kl_loss: 0.0648 - val_loss: 0.1630 - val_mse_loss: 0.0974 - val_kl_loss: 0.0655
# Epoch 50/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1506 - mse_loss: 0.0864 - kl_loss: 0.0643 - val_loss: 0.1829 - val_mse_loss: 0.1190 - val_kl_loss: 0.0639
# Epoch 51/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1526 - mse_loss: 0.0883 - kl_loss: 0.0643 - val_loss: 0.1827 - val_mse_loss: 0.1159 - val_kl_loss: 0.0667
# Epoch 52/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1513 - mse_loss: 0.0870 - kl_loss: 0.0643 - val_loss: 0.1742 - val_mse_loss: 0.1105 - val_kl_loss: 0.0637
# Epoch 53/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1504 - mse_loss: 0.0862 - kl_loss: 0.0642 - val_loss: 0.1577 - val_mse_loss: 0.0945 - val_kl_loss: 0.0632
# Epoch 54/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1495 - mse_loss: 0.0855 - kl_loss: 0.0640 - val_loss: 0.1575 - val_mse_loss: 0.0916 - val_kl_loss: 0.0658
# Epoch 55/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1491 - mse_loss: 0.0856 - kl_loss: 0.0635 - val_loss: 0.1561 - val_mse_loss: 0.0937 - val_kl_loss: 0.0624
# Epoch 56/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1483 - mse_loss: 0.0847 - kl_loss: 0.0636 - val_loss: 0.1623 - val_mse_loss: 0.0974 - val_kl_loss: 0.0649
# Epoch 57/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1484 - mse_loss: 0.0848 - kl_loss: 0.0637 - val_loss: 0.1612 - val_mse_loss: 0.0983 - val_kl_loss: 0.0629
# Epoch 58/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1488 - mse_loss: 0.0854 - kl_loss: 0.0634 - val_loss: 0.1591 - val_mse_loss: 0.0958 - val_kl_loss: 0.0632
# Epoch 59/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1483 - mse_loss: 0.0850 - kl_loss: 0.0632 - val_loss: 0.1512 - val_mse_loss: 0.0881 - val_kl_loss: 0.0631
# Epoch 60/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1441 - mse_loss: 0.0811 - kl_loss: 0.0629 - val_loss: 0.1668 - val_mse_loss: 0.1053 - val_kl_loss: 0.0616
# Epoch 61/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1464 - mse_loss: 0.0834 - kl_loss: 0.0630 - val_loss: 0.1612 - val_mse_loss: 0.0981 - val_kl_loss: 0.0631
# Epoch 62/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1447 - mse_loss: 0.0817 - kl_loss: 0.0630 - val_loss: 0.1546 - val_mse_loss: 0.0922 - val_kl_loss: 0.0624
# Epoch 63/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1447 - mse_loss: 0.0817 - kl_loss: 0.0630 - val_loss: 0.1541 - val_mse_loss: 0.0909 - val_kl_loss: 0.0632
# Epoch 64/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1437 - mse_loss: 0.0810 - kl_loss: 0.0627 - val_loss: 0.1812 - val_mse_loss: 0.1172 - val_kl_loss: 0.0639
# Epoch 65/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1457 - mse_loss: 0.0830 - kl_loss: 0.0627 - val_loss: 0.1703 - val_mse_loss: 0.1072 - val_kl_loss: 0.0631
# Epoch 66/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1424 - mse_loss: 0.0799 - kl_loss: 0.0625 - val_loss: 0.1603 - val_mse_loss: 0.0959 - val_kl_loss: 0.0644
# Epoch 67/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1456 - mse_loss: 0.0830 - kl_loss: 0.0625 - val_loss: 0.1550 - val_mse_loss: 0.0899 - val_kl_loss: 0.0651
# Epoch 68/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1425 - mse_loss: 0.0802 - kl_loss: 0.0623 - val_loss: 0.1657 - val_mse_loss: 0.1032 - val_kl_loss: 0.0624
# Epoch 69/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1424 - mse_loss: 0.0801 - kl_loss: 0.0623 - val_loss: 0.1542 - val_mse_loss: 0.0910 - val_kl_loss: 0.0632
# Epoch 70/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1422 - mse_loss: 0.0800 - kl_loss: 0.0622 - val_loss: 0.1476 - val_mse_loss: 0.0858 - val_kl_loss: 0.0618
# Epoch 71/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1425 - mse_loss: 0.0805 - kl_loss: 0.0620 - val_loss: 0.1852 - val_mse_loss: 0.1206 - val_kl_loss: 0.0646
# Epoch 72/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1412 - mse_loss: 0.0790 - kl_loss: 0.0622 - val_loss: 0.1634 - val_mse_loss: 0.0987 - val_kl_loss: 0.0646
# Epoch 73/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1442 - mse_loss: 0.0820 - kl_loss: 0.0622 - val_loss: 0.1452 - val_mse_loss: 0.0825 - val_kl_loss: 0.0627
# Epoch 74/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1414 - mse_loss: 0.0794 - kl_loss: 0.0620 - val_loss: 0.1433 - val_mse_loss: 0.0810 - val_kl_loss: 0.0622
# Epoch 75/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1411 - mse_loss: 0.0792 - kl_loss: 0.0618 - val_loss: 0.1765 - val_mse_loss: 0.1139 - val_kl_loss: 0.0625
# Epoch 76/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1417 - mse_loss: 0.0798 - kl_loss: 0.0618 - val_loss: 0.1543 - val_mse_loss: 0.0936 - val_kl_loss: 0.0606
# Epoch 77/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1397 - mse_loss: 0.0780 - kl_loss: 0.0616 - val_loss: 0.1615 - val_mse_loss: 0.1003 - val_kl_loss: 0.0612
# Epoch 78/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1383 - mse_loss: 0.0769 - kl_loss: 0.0614 - val_loss: 0.1601 - val_mse_loss: 0.0980 - val_kl_loss: 0.0621
# Epoch 79/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1413 - mse_loss: 0.0796 - kl_loss: 0.0617 - val_loss: 0.1488 - val_mse_loss: 0.0876 - val_kl_loss: 0.0612
# Epoch 80/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1388 - mse_loss: 0.0773 - kl_loss: 0.0614 - val_loss: 0.1520 - val_mse_loss: 0.0919 - val_kl_loss: 0.0601
# Epoch 81/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1386 - mse_loss: 0.0774 - kl_loss: 0.0612 - val_loss: 0.1525 - val_mse_loss: 0.0908 - val_kl_loss: 0.0617
# Epoch 82/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1371 - mse_loss: 0.0759 - kl_loss: 0.0612 - val_loss: 0.1772 - val_mse_loss: 0.1176 - val_kl_loss: 0.0596
# Epoch 83/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1405 - mse_loss: 0.0791 - kl_loss: 0.0614 - val_loss: 0.1506 - val_mse_loss: 0.0865 - val_kl_loss: 0.0641
# Epoch 84/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1368 - mse_loss: 0.0755 - kl_loss: 0.0612 - val_loss: 0.1439 - val_mse_loss: 0.0828 - val_kl_loss: 0.0611
# Epoch 85/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1379 - mse_loss: 0.0768 - kl_loss: 0.0611 - val_loss: 0.1527 - val_mse_loss: 0.0929 - val_kl_loss: 0.0597
# Epoch 86/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1368 - mse_loss: 0.0759 - kl_loss: 0.0609 - val_loss: 0.1521 - val_mse_loss: 0.0908 - val_kl_loss: 0.0613
# Epoch 87/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1368 - mse_loss: 0.0758 - kl_loss: 0.0610 - val_loss: 0.1436 - val_mse_loss: 0.0821 - val_kl_loss: 0.0615
# Epoch 88/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1375 - mse_loss: 0.0766 - kl_loss: 0.0609 - val_loss: 0.1557 - val_mse_loss: 0.0955 - val_kl_loss: 0.0602
# Epoch 89/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1350 - mse_loss: 0.0744 - kl_loss: 0.0606 - val_loss: 0.1474 - val_mse_loss: 0.0889 - val_kl_loss: 0.0585
# Epoch 90/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1352 - mse_loss: 0.0746 - kl_loss: 0.0607 - val_loss: 0.2479 - val_mse_loss: 0.1833 - val_kl_loss: 0.0646
# Epoch 91/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1369 - mse_loss: 0.0763 - kl_loss: 0.0606 - val_loss: 0.1520 - val_mse_loss: 0.0896 - val_kl_loss: 0.0624
# Epoch 92/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1368 - mse_loss: 0.0761 - kl_loss: 0.0607 - val_loss: 0.1502 - val_mse_loss: 0.0880 - val_kl_loss: 0.0622
# Epoch 93/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1352 - mse_loss: 0.0748 - kl_loss: 0.0604 - val_loss: 0.1938 - val_mse_loss: 0.1350 - val_kl_loss: 0.0588
# Epoch 94/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1363 - mse_loss: 0.0758 - kl_loss: 0.0605 - val_loss: 0.1434 - val_mse_loss: 0.0813 - val_kl_loss: 0.0621
# Epoch 95/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1343 - mse_loss: 0.0740 - kl_loss: 0.0603 - val_loss: 0.1609 - val_mse_loss: 0.1032 - val_kl_loss: 0.0578
# Epoch 96/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1357 - mse_loss: 0.0754 - kl_loss: 0.0603 - val_loss: 0.1437 - val_mse_loss: 0.0840 - val_kl_loss: 0.0597
# Epoch 97/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.1349 - mse_loss: 0.0746 - kl_loss: 0.0604 - val_loss: 0.1447 - val_mse_loss: 0.0848 - val_kl_loss: 0.0599
# Epoch 98/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1366 - mse_loss: 0.0762 - kl_loss: 0.0604 - val_loss: 0.1797 - val_mse_loss: 0.1138 - val_kl_loss: 0.0659
# Epoch 99/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1345 - mse_loss: 0.0741 - kl_loss: 0.0604 - val_loss: 0.1835 - val_mse_loss: 0.1223 - val_kl_loss: 0.0612
# Epoch 100/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.1332 - mse_loss: 0.0732 - kl_loss: 0.0600 - val_loss: 0.1433 - val_mse_loss: 0.0835 - val_kl_loss: 0.0598

# %%
def histplot(history):
    plt.rcParams["figure.figsize"] = (10,7)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, label = 'Training loss')
    plt.plot(epochs, val_loss, label = 'Validation loss')
    plt.axhline( y = min(val_loss), color = 'black', linestyle = 'dotted', label = f'Minimum Validation Loss: {min(val_loss):.4f}')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
histplot(history)

# %%
def showimg(img, ax, title=None, vmin=0, vmax=1):
    ax.imshow(img.squeeze(), vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.axis('off')



def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    input_img = inputs[0][idx]
    #Comp 1 = Central Comp, Comp 2 = Residual
    comp1 = inputs[1][idx]
    comp2 = inputs[2][idx]
    z = encode.predict(input_img)
    output_img = decode.predict([z,comp1])
    comp1.shape, output_img.shape
    fig, ax = plt.subplots(6, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(input_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[0, i].set_title('In Blend')
        ax[0, i].axis('off')
        ax[1, i].imshow(comp1[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[1, i].set_title('In Central Comp')
        ax[1, i].axis('off')
        ax[2, i].imshow(comp2[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[2, i].set_title('In Comp 2')
        ax[2, i].axis('off')
        ax[3, i].imshow(output_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[3, i].set_title(f'Re Central Comp - SSIM: {ssim(output_img[i], comp1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[3, i].axis('off')
        ax[4, i].imshow(input_img[i] - output_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[4, i].set_title(f'Re Residual Comp - SSIM: {ssim((input_img[i] - output_img[i]), comp2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[4, i].axis('off')
        ax[5, i].imshow(abs(comp1[i] - output_img[i]), origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[5, i].set_title('Re Comp Difference')
        ax[5, i].axis('off')
        plt.tight_layout()
    return idx

# %%
n=5
chosen=summary_plot(n,metrics_together,decode)
# Out:
# [ 6414 13523  8374  5256  4405]

# %%
def calc_ssim(inputs,decode):
    ssim_comp1 = np.zeros(test_ngals)
    ssim_comp2 = np.zeros(test_ngals)
    ssim_blends = np.zeros(test_ngals)
    input_img = inputs[0]
    #Comp 1 = Central Comp, Comp 2 = Residual
    comp1 = inputs[1]
    comp2 = inputs[2]
    z = encode.predict(input_img)
    output_img1 = decode.predict([z, comp1])
    for i in range(test_ngals):
        ssim_comp1[i] = ssim(comp1[i], output_img1[i], channel_axis=2, gaussian_weights = True, use_sample_covarience = False)
        ssim_comp2[i] = ssim(comp2[i], (input_img[i] - output_img1[i]), channel_axis=2, gaussian_weights = True, use_sample_covarience = False)
 

    ssim_values = np.array([ssim_comp1, ssim_comp2])
    
    return ssim_values

# %%
ssim_values = calc_ssim(metrics_together, decode)

# %%
#Plot violinplots of the SSIM

n_of_bins = 100
bins = np.linspace(0,1,n_of_bins+1)

c = 'lightgreen'
outline = 'green'


fig, ax = plt.subplots(1, 2, figsize = (13,5))


vp1 = ax[0].hist(ssim_values[0], bins, color = c, ec = outline, alpha = 0.3, lw = 2)

ax[0].set_title('SSIMs of Central Component')
ax[0].set_xlabel('SSIM')
ax[0].set_ylabel('Density')

 

vp2 = ax[1].hist(ssim_values[1], bins,  color = c, ec = outline, alpha = 0.3, lw = 2)

ax[1].set_title('SSIMs of Residual Component')  
ax[1].set_xlabel('SSIM')
ax[1].set_ylabel('Density')
  
ax[0].set_xlim(0, 1) 
ax[1].set_xlim(0, 1) 
plt.tight_layout()

plt.show()

# %%
mean_ssim_comp1 = np.mean(ssim_values[0])
median_ssim_comp1 = np.median(ssim_values[0])
mean_ssim_comp2 = np.mean(ssim_values[1])
median_ssim_comp2 = np.median(ssim_values[1])

# %%
print(f' Mean SSIMs: Central Component: {mean_ssim_comp1:.4f}, Residual Component: {mean_ssim_comp2:.4f}')

print(f' Median SSIMs: Central Component: {median_ssim_comp1:.4f}, Residual Component: {median_ssim_comp2:.4f} ')
# Out:
#  Mean SSIMs: Central Component: 0.9930, Residual Component: 0.9857
#  Median SSIMs: Central Component: 0.9958, Residual Component: 0.9907

# %%
#This function calculates the properties of the input and output images. The ellipticity and flux are stored in arrays 

def calc_properties(inputs,decode):
    
    empty_array = np.zeros(test_ngals)
    
    flux_in_comp1 = np.zeros(test_ngals)
    
    flux_out_comp1 = np.zeros(test_ngals)
    
    elip_in_comp1 = np.zeros(test_ngals)
    
    elip_out_comp1 = np.zeros(test_ngals)
    
    flux_in_comp2 = np.zeros(test_ngals)
    
    flux_out_comp2 = np.zeros(test_ngals)
    
    elip_in_comp2 = np.zeros(test_ngals)

    elip_out_comp2 = np.zeros(test_ngals)
    
    input_img = inputs[0]
    input_img = input_img.reshape(test_ngals, height, width)
    comp1 = inputs[1]
    comp1 = comp1.reshape(test_ngals, height, width)
    comp2 = inputs[2]
    comp2 = comp2.reshape(test_ngals, height, width)
    
    z = encode.predict(input_img)
    output_img1 = decode.predict([z, comp1])
    output_img1 = output_img1.reshape(test_ngals, height, width)
    
    for i in range(test_ngals):
        
        in_comp1_cat = photutils.morphology.data_properties(comp1[i], mask = None, background = 0)
        elip_in_comp1[i] = in_comp1_cat.ellipticity
        flux_in_comp1[i] = in_comp1_cat.segment_flux
            
        out_comp1_cat = photutils.morphology.data_properties(output_img1[i], mask = None, background = 0)
        elip_out_comp1[i] = out_comp1_cat.ellipticity
        flux_out_comp1[i] = out_comp1_cat.segment_flux
        
        in_comp2_cat = photutils.morphology.data_properties(comp2[i], mask = None, background = 0)
        elip_in_comp2[i] = in_comp2_cat.ellipticity
        flux_in_comp2[i] = in_comp2_cat.segment_flux
            
        out_comp2_cat = photutils.morphology.data_properties(input_img[i] - output_img1[i], mask = None, background = 0)
        elip_out_comp2[i] = out_comp2_cat.ellipticity
        flux_out_comp2[i] = out_comp2_cat.segment_flux
        
        parameters = [elip_in_comp1, elip_out_comp1, flux_in_comp1, flux_out_comp1, elip_in_comp2, elip_out_comp2, flux_in_comp2, flux_out_comp2]   
    return parameters

# %%
parameters = calc_properties(metrics_together, decode)

# %%
np.save("c_parameters.npy", parameters)
