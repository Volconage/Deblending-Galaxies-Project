# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import photutils

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

from photutils.detection import DAOStarFinder
from photutils.morphology import data_properties
from numpy.random import normal
from astropy.stats import mad_std

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Dense, Flatten, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

from tensorflow.config import list_logical_devices, list_physical_devices, set_visible_devices
from tensorflow.config.experimental import set_memory_growth

# %%
#Setup notebook so Tensorflow works in a friendly way in a shared multi GPU env

def setup_tensorflow(seed=None):
    try:
        import nvsmi

        gpu_mem_free = np.array([gpu.mem_free for gpu in nvsmi.get_gpus()])
        if len(gpu_mem_free) > 0 and (gpu_mem_free > 0).any():
            idx = np.argmax(gpu_mem_free)
            gpu = list_physical_devices("GPU")[idx]
            set_memory_growth(gpu, True)
            set_visible_devices(gpu, "GPU")
            gpus = list_logical_devices("GPU")
            print(f"Using GPU: {gpus}")
        else:
            raise Exception
    except:
        print(f"Tensorflow using CPU")
    tf.random.set_seed(seed)

# %%
setup_tensorflow()
# Out:
# Using GPU: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-05-21 13:23:36.127499: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#load the image arrays, Size: (ngals, 64, 64), (2, ngals, 64, 64) respectively 

#Blends and components arrays are both noiseless

#Noise is then added to the blends which the network trains on

#Noiseless blends are used for the metrics 

components = np.load("isolatednewdecentred120k.npy")

# %%
def add_noise(img, scale=0.01):
    return img + normal(scale=scale, size=img.shape)

# %%
def asinh_scale(x, a=0.1, inverse=False):
    # This is a common way of scaling astronomical images
    # so that inner and outer regions of galaxies can be seen
    return np.arcsinh(x / a) / np.arcsinh(1 / a)

# %%
#Thresholding the masked areaas 


components[components<0] = -1*components[components<0]

components[components<22.3] = 22.3

# %%
#Scale the components 

components = asinh_scale(components)

#Then make the blends

blends = components[0] + components[1]

# %%
blends.shape, components.shape
# Out:
# ((120000, 64, 64), (2, 120000, 64, 64))

# %%
np.mean(blends), np.mean(components)
# Out:
# (5.402935559923415, 2.701467779961744)

# %%
#Split into training and test set 

#Going to split training and test 80% and 20% respectively 

train_ngals = int(blends.shape[0] * 0.8)
test_ngals = int(blends.shape[0] * 0.2)

train_blends = blends[:train_ngals]
test_blends = blends[train_ngals:]
test_blends_noiseless = blends[train_ngals:]

a, b, c, d, test_components = np.split(components, 5, axis = 1)

train_components = np.concatenate((a, b, c, d), axis = 1)

# %%
#Add noise to the training blends 

train_blends = add_noise(train_blends)

#Making a test_blends with noise to display for the summary plots 

#The noiseless test_blends are used for the metrics 

test_blends = add_noise(test_blends)

# %%
#Now normalise based on maximum value of the arrays

norm_max = np.max([ np.max(train_blends), np.max(test_blends), np.max(train_components), np.max(test_components), np.max(test_blends_noiseless)])

train_blends /= norm_max
test_blends /= norm_max
test_blends_noiseless /= norm_max
train_components /= norm_max
test_components /= norm_max

# %%
np.amax(train_blends), np.amin(train_blends), np.amax(test_blends), np.amin(test_blends), np.amax(test_blends_noiseless), np.amin(test_blends_noiseless)
# Out:
# (1.0,
#  0.3647794737630474,
#  0.982403049827733,
#  0.3651233793432903,
#  0.9809229151177634,
#  0.36990816160173123)

# %%
np.amax(test_components), np.amin(test_components), np.amax(train_components), np.amin(train_components)
# Out:
# (0.5320978250741576,
#  0.18495408080086562,
#  0.5321085684582287,
#  0.18495408080086562)

# %%
height,width=64,64

train_blends = train_blends.reshape(train_ngals, height, width, 1).astype('float32')
train_components = train_components.reshape(2, train_ngals, height, width, 1).astype('float32')

test_blends = test_blends.reshape(test_ngals, height, width, 1).astype('float32')

test_blends_noiseless = test_blends_noiseless.reshape(test_ngals, height, width, 1).astype('float32')
test_components = test_components.reshape(2, test_ngals, height, width, 1).astype('float32')

# %%
batch_size = 32
latent_dimensions = 32

# %%
fig, ax = plt.subplots(2 + 1, 5, figsize=(15, 10))
for i in range(5):
    ax[0, i].imshow(train_blends[i], origin='lower', interpolation='nearest')
    ax[0, i].axis('off')
    ax[1, i].imshow(train_components[0, i], origin='lower', interpolation='nearest')
    ax[1, i].axis('off')
    ax[2, i].imshow(train_components[1, i], origin='lower', interpolation='nearest')
    ax[2, i].axis('off')

# %%
#Will optimise encoder / decoder later
def encoder(x):
    x=Conv2D(32,3,activation='relu', strides = 2, padding='same')(x)
    x=Conv2D(64,3,activation='relu', strides = 2, padding='same')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    return x

# %%
def decoder(x):
    x=UpSampling2D(size=(2,2))(x)
    x=Conv2DTranspose(64,3,activation='relu', strides = 2 ,padding='same')(x)
    x=Conv2DTranspose(32,3,activation='relu', strides = 2 ,padding='same')(x)
    return x

# %%
def sampling(args):
    z_mean,z_log_sigma=args
    epsilon=tf.random.normal(shape=tf.shape(z_mean))
    z=z_mean+tf.exp(0.5*z_log_sigma)*epsilon
    return z

# %%
# encoder
input_blend=Input(shape=(height, width,1))

encoded=encoder(input_blend)
shape=encoded.get_shape()[1:]
encoded=Flatten()(encoded)

z_mean=Dense(latent_dimensions)(encoded)
z_log_sigma=Dense(latent_dimensions)(encoded)
z=Lambda(sampling)([z_mean,z_log_sigma])

# %%
# decoder
input_embed=Input(shape=latent_dimensions)

embed1=Dense(np.prod(shape),activation='relu')(input_embed)
embed1=Reshape(shape)(embed1)
decoded1=decoder(embed1)
output1=Conv2DTranspose(1,3,padding='same')(decoded1)

embed2=Dense(np.prod(shape),activation='relu')(input_embed)
embed2=Reshape(shape)(embed2)
decoded2=decoder(embed2)
output2=Conv2DTranspose(1,3,padding='same')(decoded2)

# %%
encode=Model(input_blend,z)
encode.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           131104      ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_component1 = Input(shape=(height, width, 1))
input_component2 = Input(shape=(height, width, 1))

decode=Model([input_embed, input_component1, input_component2], [output1, output2])
decode.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  dense_2 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  dense_3 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 64)     0           ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 64)     0           ['dense_3[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['reshape[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 64)  0           ['reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  36928       ['up_sampling2d[0][0]']
#  ose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 64)  36928       ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose_3[0][0]']
#  spose)
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_1[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_4[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 381,698
# Trainable params: 381,698
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoding = encode(input_blend)
re1, re2 = decode([encoding, input_component1, input_component2])

vae = Model([input_blend, input_component1, input_component2], [re1, re2])

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model (Functional)             (None, 32)           281024      ['input_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_1 (Functional)           [(None, 64, 64, 1),  381698      ['model[0][0]',
#                                  (None, 64, 64, 1)]               'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 662,722
# Trainable params: 662,722
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
mse_lossA = mse(input_component1, re1) + mse(input_component2, re2)
mse_lossA = tf.reduce_mean(mse_lossA / 2, axis=(1, 2))
mse_lossB = mse(input_component1, re2) + mse(input_component2, re1)
mse_lossB = tf.reduce_mean(mse_lossB / 2, axis=(1, 2))
mse_loss = tf.reduce_mean(tf.minimum(mse_lossA, mse_lossB)) * height * width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss, 'mse_loss')

kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma-tf.square(z_mean)-tf.exp(z_log_sigma)))*0.1
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')


train_together = [train_blends, train_components[0], train_components[1]]
test_together = [test_blends, test_components[0], test_components[1], test_blends_noiseless]

vae.compile(optimizer=Adam())

# %%
val_split_ratio = 0.2
print(val_split_ratio * train_ngals)
# Out:
# 19200.0

# %%
history=vae.fit(train_together, verbose = 1, epochs = 100, batch_size = batch_size, validation_split = val_split_ratio)
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 38s 14ms/step - loss: 5.8450 - mse_loss: 5.5902 - kl_loss: 0.2548 - val_loss: 3.1688 - val_mse_loss: 2.9161 - val_kl_loss: 0.2527
# Epoch 2/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 2.8119 - mse_loss: 2.5505 - kl_loss: 0.2614 - val_loss: 2.5848 - val_mse_loss: 2.3177 - val_kl_loss: 0.2671
# Epoch 3/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 2.4395 - mse_loss: 2.1807 - kl_loss: 0.2588 - val_loss: 2.2600 - val_mse_loss: 2.0027 - val_kl_loss: 0.2573
# Epoch 4/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 2.2182 - mse_loss: 1.9632 - kl_loss: 0.2550 - val_loss: 2.1680 - val_mse_loss: 1.9278 - val_kl_loss: 0.2402
# Epoch 5/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 2.1060 - mse_loss: 1.8535 - kl_loss: 0.2525 - val_loss: 1.9895 - val_mse_loss: 1.7338 - val_kl_loss: 0.2557
# Epoch 6/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.9850 - mse_loss: 1.7344 - kl_loss: 0.2506 - val_loss: 1.9187 - val_mse_loss: 1.6797 - val_kl_loss: 0.2390
# Epoch 7/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.9342 - mse_loss: 1.6868 - kl_loss: 0.2474 - val_loss: 1.8981 - val_mse_loss: 1.6347 - val_kl_loss: 0.2633
# Epoch 8/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.8821 - mse_loss: 1.6362 - kl_loss: 0.2459 - val_loss: 1.7824 - val_mse_loss: 1.5392 - val_kl_loss: 0.2432
# Epoch 9/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.8378 - mse_loss: 1.5926 - kl_loss: 0.2452 - val_loss: 1.7693 - val_mse_loss: 1.5241 - val_kl_loss: 0.2452
# Epoch 10/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.8150 - mse_loss: 1.5729 - kl_loss: 0.2421 - val_loss: 1.7831 - val_mse_loss: 1.5393 - val_kl_loss: 0.2438
# Epoch 11/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.8081 - mse_loss: 1.5670 - kl_loss: 0.2411 - val_loss: 1.7834 - val_mse_loss: 1.5566 - val_kl_loss: 0.2268
# Epoch 12/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.7609 - mse_loss: 1.5226 - kl_loss: 0.2383 - val_loss: 1.7809 - val_mse_loss: 1.5426 - val_kl_loss: 0.2384
# Epoch 13/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.7466 - mse_loss: 1.5070 - kl_loss: 0.2396 - val_loss: 1.7579 - val_mse_loss: 1.5194 - val_kl_loss: 0.2385
# Epoch 14/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.7182 - mse_loss: 1.4808 - kl_loss: 0.2374 - val_loss: 1.7722 - val_mse_loss: 1.5536 - val_kl_loss: 0.2185
# Epoch 15/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.7279 - mse_loss: 1.4913 - kl_loss: 0.2366 - val_loss: 1.7215 - val_mse_loss: 1.4727 - val_kl_loss: 0.2488
# Epoch 16/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6983 - mse_loss: 1.4624 - kl_loss: 0.2358 - val_loss: 1.9108 - val_mse_loss: 1.6637 - val_kl_loss: 0.2471
# Epoch 17/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6910 - mse_loss: 1.4560 - kl_loss: 0.2350 - val_loss: 1.7294 - val_mse_loss: 1.4783 - val_kl_loss: 0.2511
# Epoch 18/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6678 - mse_loss: 1.4339 - kl_loss: 0.2338 - val_loss: 1.6890 - val_mse_loss: 1.4557 - val_kl_loss: 0.2333
# Epoch 19/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.7073 - mse_loss: 1.4731 - kl_loss: 0.2342 - val_loss: 2.1636 - val_mse_loss: 1.9542 - val_kl_loss: 0.2094
# Epoch 20/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6899 - mse_loss: 1.4560 - kl_loss: 0.2339 - val_loss: 1.7015 - val_mse_loss: 1.4653 - val_kl_loss: 0.2362
# Epoch 21/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6281 - mse_loss: 1.3937 - kl_loss: 0.2344 - val_loss: 1.6606 - val_mse_loss: 1.4371 - val_kl_loss: 0.2235
# Epoch 22/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6568 - mse_loss: 1.4224 - kl_loss: 0.2344 - val_loss: 1.6542 - val_mse_loss: 1.4229 - val_kl_loss: 0.2314
# Epoch 23/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6444 - mse_loss: 1.4112 - kl_loss: 0.2332 - val_loss: 1.6555 - val_mse_loss: 1.4342 - val_kl_loss: 0.2212
# Epoch 24/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6279 - mse_loss: 1.3951 - kl_loss: 0.2328 - val_loss: 1.6517 - val_mse_loss: 1.4149 - val_kl_loss: 0.2369
# Epoch 25/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6442 - mse_loss: 1.4097 - kl_loss: 0.2346 - val_loss: 1.6842 - val_mse_loss: 1.4496 - val_kl_loss: 0.2346
# Epoch 26/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6362 - mse_loss: 1.4043 - kl_loss: 0.2319 - val_loss: 1.6551 - val_mse_loss: 1.4193 - val_kl_loss: 0.2359
# Epoch 27/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6322 - mse_loss: 1.3981 - kl_loss: 0.2341 - val_loss: 1.6318 - val_mse_loss: 1.3915 - val_kl_loss: 0.2403
# Epoch 28/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6029 - mse_loss: 1.3718 - kl_loss: 0.2311 - val_loss: 1.5680 - val_mse_loss: 1.3415 - val_kl_loss: 0.2265
# Epoch 29/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6107 - mse_loss: 1.3800 - kl_loss: 0.2307 - val_loss: 1.6177 - val_mse_loss: 1.3842 - val_kl_loss: 0.2335
# Epoch 30/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6326 - mse_loss: 1.4001 - kl_loss: 0.2325 - val_loss: 1.6363 - val_mse_loss: 1.4035 - val_kl_loss: 0.2328
# Epoch 31/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6031 - mse_loss: 1.3722 - kl_loss: 0.2309 - val_loss: 1.6132 - val_mse_loss: 1.3817 - val_kl_loss: 0.2315
# Epoch 32/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5930 - mse_loss: 1.3606 - kl_loss: 0.2325 - val_loss: 1.6929 - val_mse_loss: 1.4553 - val_kl_loss: 0.2376
# Epoch 33/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6280 - mse_loss: 1.3941 - kl_loss: 0.2340 - val_loss: 1.6455 - val_mse_loss: 1.4115 - val_kl_loss: 0.2340
# Epoch 34/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5731 - mse_loss: 1.3415 - kl_loss: 0.2316 - val_loss: 1.5860 - val_mse_loss: 1.3573 - val_kl_loss: 0.2287
# Epoch 35/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5707 - mse_loss: 1.3397 - kl_loss: 0.2310 - val_loss: 1.5872 - val_mse_loss: 1.3548 - val_kl_loss: 0.2324
# Epoch 36/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5671 - mse_loss: 1.3365 - kl_loss: 0.2307 - val_loss: 1.6109 - val_mse_loss: 1.3860 - val_kl_loss: 0.2249
# Epoch 37/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5708 - mse_loss: 1.3404 - kl_loss: 0.2304 - val_loss: 1.6145 - val_mse_loss: 1.3794 - val_kl_loss: 0.2351
# Epoch 38/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5601 - mse_loss: 1.3287 - kl_loss: 0.2313 - val_loss: 1.5648 - val_mse_loss: 1.3280 - val_kl_loss: 0.2368
# Epoch 39/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5538 - mse_loss: 1.3234 - kl_loss: 0.2304 - val_loss: 1.5575 - val_mse_loss: 1.3307 - val_kl_loss: 0.2268
# Epoch 40/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5510 - mse_loss: 1.3194 - kl_loss: 0.2317 - val_loss: 1.5985 - val_mse_loss: 1.3727 - val_kl_loss: 0.2258
# Epoch 41/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5622 - mse_loss: 1.3302 - kl_loss: 0.2320 - val_loss: 1.5488 - val_mse_loss: 1.3050 - val_kl_loss: 0.2439
# Epoch 42/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5422 - mse_loss: 1.3115 - kl_loss: 0.2307 - val_loss: 1.6212 - val_mse_loss: 1.3955 - val_kl_loss: 0.2256
# Epoch 43/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5568 - mse_loss: 1.3242 - kl_loss: 0.2325 - val_loss: 1.6095 - val_mse_loss: 1.3770 - val_kl_loss: 0.2326
# Epoch 44/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5491 - mse_loss: 1.3192 - kl_loss: 0.2299 - val_loss: 1.5651 - val_mse_loss: 1.3310 - val_kl_loss: 0.2341
# Epoch 45/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5378 - mse_loss: 1.3064 - kl_loss: 0.2314 - val_loss: 1.5242 - val_mse_loss: 1.2961 - val_kl_loss: 0.2281
# Epoch 46/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5470 - mse_loss: 1.3166 - kl_loss: 0.2304 - val_loss: 1.6281 - val_mse_loss: 1.3899 - val_kl_loss: 0.2382
# Epoch 47/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5367 - mse_loss: 1.3083 - kl_loss: 0.2284 - val_loss: 1.5619 - val_mse_loss: 1.3320 - val_kl_loss: 0.2299
# Epoch 48/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5427 - mse_loss: 1.3124 - kl_loss: 0.2302 - val_loss: 1.5880 - val_mse_loss: 1.3687 - val_kl_loss: 0.2192
# Epoch 49/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5295 - mse_loss: 1.2998 - kl_loss: 0.2297 - val_loss: 1.5254 - val_mse_loss: 1.2996 - val_kl_loss: 0.2258
# Epoch 50/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5275 - mse_loss: 1.2964 - kl_loss: 0.2311 - val_loss: 1.6386 - val_mse_loss: 1.4130 - val_kl_loss: 0.2256
# Epoch 51/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5233 - mse_loss: 1.2953 - kl_loss: 0.2280 - val_loss: 1.5673 - val_mse_loss: 1.3434 - val_kl_loss: 0.2239
# Epoch 52/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5152 - mse_loss: 1.2862 - kl_loss: 0.2290 - val_loss: 1.5227 - val_mse_loss: 1.2958 - val_kl_loss: 0.2269
# Epoch 53/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5112 - mse_loss: 1.2805 - kl_loss: 0.2307 - val_loss: 1.5918 - val_mse_loss: 1.3718 - val_kl_loss: 0.2200
# Epoch 54/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5738 - mse_loss: 1.3437 - kl_loss: 0.2301 - val_loss: 1.6090 - val_mse_loss: 1.3874 - val_kl_loss: 0.2216
# Epoch 55/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5239 - mse_loss: 1.2954 - kl_loss: 0.2285 - val_loss: 1.6138 - val_mse_loss: 1.3833 - val_kl_loss: 0.2305
# Epoch 56/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5171 - mse_loss: 1.2882 - kl_loss: 0.2290 - val_loss: 1.6343 - val_mse_loss: 1.4076 - val_kl_loss: 0.2266
# Epoch 57/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6253 - mse_loss: 1.3971 - kl_loss: 0.2282 - val_loss: 1.6250 - val_mse_loss: 1.3973 - val_kl_loss: 0.2277
# Epoch 58/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5535 - mse_loss: 1.3221 - kl_loss: 0.2313 - val_loss: 1.5468 - val_mse_loss: 1.2979 - val_kl_loss: 0.2489
# Epoch 59/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5135 - mse_loss: 1.2835 - kl_loss: 0.2300 - val_loss: 1.5410 - val_mse_loss: 1.3102 - val_kl_loss: 0.2308
# Epoch 60/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4979 - mse_loss: 1.2683 - kl_loss: 0.2296 - val_loss: 1.5842 - val_mse_loss: 1.3439 - val_kl_loss: 0.2403
# Epoch 61/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4986 - mse_loss: 1.2698 - kl_loss: 0.2288 - val_loss: 1.5822 - val_mse_loss: 1.3529 - val_kl_loss: 0.2293
# Epoch 62/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5018 - mse_loss: 1.2717 - kl_loss: 0.2301 - val_loss: 1.5107 - val_mse_loss: 1.2866 - val_kl_loss: 0.2241
# Epoch 63/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5081 - mse_loss: 1.2805 - kl_loss: 0.2276 - val_loss: 1.5145 - val_mse_loss: 1.2878 - val_kl_loss: 0.2267
# Epoch 64/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4953 - mse_loss: 1.2674 - kl_loss: 0.2280 - val_loss: 1.5857 - val_mse_loss: 1.3514 - val_kl_loss: 0.2343
# Epoch 65/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5025 - mse_loss: 1.2720 - kl_loss: 0.2305 - val_loss: 1.5594 - val_mse_loss: 1.3245 - val_kl_loss: 0.2349
# Epoch 66/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5103 - mse_loss: 1.2797 - kl_loss: 0.2306 - val_loss: 1.4823 - val_mse_loss: 1.2516 - val_kl_loss: 0.2307
# Epoch 67/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5393 - mse_loss: 1.3125 - kl_loss: 0.2268 - val_loss: 1.7712 - val_mse_loss: 1.5343 - val_kl_loss: 0.2368
# Epoch 68/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5941 - mse_loss: 1.3628 - kl_loss: 0.2313 - val_loss: 1.5818 - val_mse_loss: 1.3576 - val_kl_loss: 0.2242
# Epoch 69/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5026 - mse_loss: 1.2727 - kl_loss: 0.2299 - val_loss: 1.5474 - val_mse_loss: 1.3167 - val_kl_loss: 0.2306
# Epoch 70/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4831 - mse_loss: 1.2534 - kl_loss: 0.2298 - val_loss: 1.5097 - val_mse_loss: 1.2836 - val_kl_loss: 0.2261
# Epoch 71/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4981 - mse_loss: 1.2683 - kl_loss: 0.2298 - val_loss: 1.5285 - val_mse_loss: 1.3025 - val_kl_loss: 0.2260
# Epoch 72/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5079 - mse_loss: 1.2787 - kl_loss: 0.2292 - val_loss: 1.5184 - val_mse_loss: 1.2914 - val_kl_loss: 0.2270
# Epoch 73/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5426 - mse_loss: 1.3125 - kl_loss: 0.2302 - val_loss: 1.5491 - val_mse_loss: 1.3259 - val_kl_loss: 0.2232
# Epoch 74/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5259 - mse_loss: 1.2947 - kl_loss: 0.2312 - val_loss: 1.6034 - val_mse_loss: 1.3779 - val_kl_loss: 0.2255
# Epoch 75/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5042 - mse_loss: 1.2747 - kl_loss: 0.2295 - val_loss: 1.5509 - val_mse_loss: 1.3280 - val_kl_loss: 0.2229
# Epoch 76/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4821 - mse_loss: 1.2545 - kl_loss: 0.2277 - val_loss: 1.4610 - val_mse_loss: 1.2365 - val_kl_loss: 0.2246
# Epoch 77/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4851 - mse_loss: 1.2576 - kl_loss: 0.2275 - val_loss: 1.6141 - val_mse_loss: 1.3871 - val_kl_loss: 0.2269
# Epoch 78/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5030 - mse_loss: 1.2744 - kl_loss: 0.2287 - val_loss: 1.5046 - val_mse_loss: 1.2862 - val_kl_loss: 0.2184
# Epoch 79/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5305 - mse_loss: 1.3010 - kl_loss: 0.2295 - val_loss: 1.5570 - val_mse_loss: 1.3223 - val_kl_loss: 0.2347
# Epoch 80/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.6093 - mse_loss: 1.3830 - kl_loss: 0.2263 - val_loss: 1.5829 - val_mse_loss: 1.3539 - val_kl_loss: 0.2290
# Epoch 81/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5459 - mse_loss: 1.3178 - kl_loss: 0.2281 - val_loss: 1.5693 - val_mse_loss: 1.3438 - val_kl_loss: 0.2255
# Epoch 82/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5199 - mse_loss: 1.2924 - kl_loss: 0.2276 - val_loss: 1.6277 - val_mse_loss: 1.3959 - val_kl_loss: 0.2318
# Epoch 83/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5143 - mse_loss: 1.2835 - kl_loss: 0.2307 - val_loss: 1.5858 - val_mse_loss: 1.3525 - val_kl_loss: 0.2333
# Epoch 84/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5038 - mse_loss: 1.2737 - kl_loss: 0.2301 - val_loss: 1.5380 - val_mse_loss: 1.3162 - val_kl_loss: 0.2218
# Epoch 85/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4898 - mse_loss: 1.2624 - kl_loss: 0.2274 - val_loss: 1.7464 - val_mse_loss: 1.5297 - val_kl_loss: 0.2167
# Epoch 86/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5927 - mse_loss: 1.3660 - kl_loss: 0.2267 - val_loss: 1.6907 - val_mse_loss: 1.4766 - val_kl_loss: 0.2141
# Epoch 87/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5397 - mse_loss: 1.3137 - kl_loss: 0.2259 - val_loss: 1.5158 - val_mse_loss: 1.2792 - val_kl_loss: 0.2367
# Epoch 88/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4785 - mse_loss: 1.2505 - kl_loss: 0.2280 - val_loss: 1.5012 - val_mse_loss: 1.2694 - val_kl_loss: 0.2319
# Epoch 89/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4693 - mse_loss: 1.2391 - kl_loss: 0.2302 - val_loss: 1.6598 - val_mse_loss: 1.4092 - val_kl_loss: 0.2506
# Epoch 90/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5022 - mse_loss: 1.2732 - kl_loss: 0.2290 - val_loss: 1.5736 - val_mse_loss: 1.3532 - val_kl_loss: 0.2204
# Epoch 91/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5174 - mse_loss: 1.2907 - kl_loss: 0.2266 - val_loss: 1.5516 - val_mse_loss: 1.3254 - val_kl_loss: 0.2263
# Epoch 92/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4641 - mse_loss: 1.2372 - kl_loss: 0.2269 - val_loss: 1.4647 - val_mse_loss: 1.2355 - val_kl_loss: 0.2291
# Epoch 93/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5166 - mse_loss: 1.2904 - kl_loss: 0.2262 - val_loss: 1.5489 - val_mse_loss: 1.3266 - val_kl_loss: 0.2224
# Epoch 94/100
# 2400/2400 [==============================] - 30s 12ms/step - loss: 1.5309 - mse_loss: 1.3031 - kl_loss: 0.2278 - val_loss: 1.5817 - val_mse_loss: 1.3565 - val_kl_loss: 0.2253
# Epoch 95/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5161 - mse_loss: 1.2921 - kl_loss: 0.2240 - val_loss: 1.6445 - val_mse_loss: 1.4081 - val_kl_loss: 0.2365
# Epoch 96/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4905 - mse_loss: 1.2652 - kl_loss: 0.2253 - val_loss: 1.6096 - val_mse_loss: 1.3829 - val_kl_loss: 0.2267
# Epoch 97/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4705 - mse_loss: 1.2442 - kl_loss: 0.2263 - val_loss: 1.6074 - val_mse_loss: 1.3891 - val_kl_loss: 0.2184
# Epoch 98/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4906 - mse_loss: 1.2627 - kl_loss: 0.2279 - val_loss: 1.5038 - val_mse_loss: 1.2808 - val_kl_loss: 0.2230
# Epoch 99/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4817 - mse_loss: 1.2549 - kl_loss: 0.2268 - val_loss: 1.4706 - val_mse_loss: 1.2446 - val_kl_loss: 0.2261
# Epoch 100/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.4996 - mse_loss: 1.2731 - kl_loss: 0.2265 - val_loss: 1.5354 - val_mse_loss: 1.3103 - val_kl_loss: 0.2251

# %%
def histplot(history):
    plt.rcParams["figure.figsize"] = (10,7)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, label = 'Training loss')
    plt.plot(epochs, val_loss, label = 'Validation loss')
    plt.axhline( y = min(val_loss), color = 'black', linestyle = 'dotted', label = f'Minimum Validation Loss: {min(val_loss):.4f}')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
histplot(history)

# %%
def showimg(img, ax, title=None, vmin=0, vmax=1):
    ax.imshow(img.squeeze(), vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.axis('off')

def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    noisy_input_img = inputs[0][idx]
    comp1 = inputs[1][idx]
    comp2 = inputs[2][idx]
    noiseless_input_img = inputs[3][idx]
    z = encode.predict(noisy_input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    fig, ax = plt.subplots(7, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(noisy_input_img[i], origin='lower', interpolation='nearest')
        ax[0, i].set_title('In Blend')
        ax[0, i].axis('off')
        ax[1, i].imshow(comp1[i], origin='lower', interpolation='nearest' )
        ax[1, i].set_title('In Comp 1')
        ax[1, i].axis('off')
        ax[2, i].imshow(comp2[i], origin='lower', interpolation='nearest')
        ax[2, i].set_title('In Comp 2')
        ax[2, i].axis('off')
        ax[3, i].imshow(output_img1[i], origin='lower', interpolation='nearest')
        ax[3, i].set_title(f'Re Comp 1 - SSIM:{ssim(comp1[i], output_img1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[3, i].axis('off')
        ax[4, i].imshow(output_img2[i], origin='lower', interpolation='nearest')
        ax[4, i].set_title(f'Re Comp 2 - SSIM: {ssim(comp2[i], output_img2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[4, i].axis('off')
        ax[5, i].imshow((output_img1[i] + output_img2[i]) , origin='lower', interpolation='nearest')
        ax[5, i].set_title(f'Re Blend - SSIM: {ssim(noiseless_input_img[i], (output_img1[i] + output_img2[i]), channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[5, i].axis('off')
        ax[6, i].imshow(abs(noiseless_input_img[i] -(output_img1[i] + output_img2[i])) , origin='lower', interpolation='nearest')
        ax[6, i].set_title('Blend Difference')
        ax[6, i].axis('off')
        plt.tight_layout()
    return idx

# %%
n=5
chosen=summary_plot(n,test_together,decode)
# Out:
# [ 6414 13523  8374  5256  4405]

# %%
def calc_ssim(inputs,decode):
    ssim_comp1 = np.zeros(test_ngals)
    ssim_comp2 = np.zeros(test_ngals)
    ssim_blends = np.zeros(test_ngals)
    noisy_input_img = inputs[0]
    comp1 = inputs[1]
    comp2 = inputs[2]
    noiseless_input_img = inputs[3]
    z = encode.predict(noisy_input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    for i in range(test_ngals):
        ssim_comp1[i] = ssim(comp1[i], output_img1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False)
        ssim_comp2[i] = ssim(comp2[i], output_img2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False)
        ssim_blends[i] = ssim(noiseless_input_img[i], (output_img1[i] + output_img2[i]), channel_axis = 2, gaussian_weights = True, use_sample_covarience = False)
    
    ssim_values = np.array([ssim_comp1, ssim_comp2, ssim_blends])
    
    return ssim_values

# %%
ssim_values = calc_ssim(test_together, decode)

# %%
#Plot violinplots of the SSIM

n_of_bins = 100
bins = np.linspace(0,1,n_of_bins+1)

c = 'lightblue'
outline = 'cornflowerblue'


fig, ax = plt.subplots(1, 2, figsize = (13,5))


vp1 = ax[0].hist(ssim_values[0], bins, color = c, ec = outline, alpha = 0.3, lw = 2)

ax[0].set_title('SSIMs of Component 1')
ax[0].set_xlabel('SSIM')
ax[0].set_ylabel('Density')

 

vp2 = ax[1].hist(ssim_values[1], bins,  color = c, ec = outline, alpha = 0.3, lw = 2)

ax[1].set_title('SSIMs of Component 2')  
ax[1].set_xlabel('SSIM')
ax[1].set_ylabel('Density')
  
ax[0].set_xlim(0, 1) 
ax[1].set_xlim(0, 1) 
plt.tight_layout()

plt.show()

# %%
mean_ssim_comp1 = np.mean(ssim_values[0])
median_ssim_comp1 = np.median(ssim_values[0])
mean_ssim_comp2 = np.mean(ssim_values[1])
median_ssim_comp2 = np.median(ssim_values[1])
mean_ssim_blends = np.mean(ssim_values[2])
median_ssim_blends = np.median(ssim_values[2])

# %%
print(f' Mean SSIMs: Component 1: {mean_ssim_comp1:.4f}, Component 2: {mean_ssim_comp2:.4f}, Blends: {mean_ssim_blends:.4f}')

print(f' Median SSIMs: Component 1: {median_ssim_comp1:.4f}, Component 2: {median_ssim_comp2:.4f}, Blends: {median_ssim_blends:.4f}')
# Out:
#  Mean SSIMs: Component 1: 0.9415, Component 2: 0.9430, Blends: 0.9660
#  Median SSIMs: Component 1: 0.9585, Component 2: 0.9585, Blends: 0.9696

# %%
#This function calculates the properties of the input and output images. The ellipticity and flux are stored in arrays 

def calc_properties(inputs,decode):
    
    empty_array = np.zeros(test_ngals)
    
    flux_in_comp1 = np.zeros(test_ngals)
    flux_in_comp2 = np.zeros(test_ngals)
    flux_in_blends = np.zeros(test_ngals)
    
    flux_out_comp1 = np.zeros(test_ngals)
    flux_out_comp2 = np.zeros(test_ngals)
    flux_out_blends = np.zeros(test_ngals)
    
    
    elip_in_comp1 = np.zeros(test_ngals)
    elip_in_comp2 = np.zeros(test_ngals)
    
    elip_out_comp1 = np.zeros(test_ngals)
    elip_out_comp2 = np.zeros(test_ngals)
    
    noisy_input_img = inputs[0]
    noisy_input_img = noisy_input_img.reshape(test_ngals, height, width)
    comp1 = inputs[1]
    comp1 = comp1.reshape(test_ngals, height, width)
    comp2 = inputs[2]
    comp2 = comp2.reshape(test_ngals, height,width)
    noiseless_input_img = inputs[3]
    noiseless_input_img = noiseless_input_img.reshape(test_ngals, height, width)

    z = encode.predict(noisy_input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    output_img1 = output_img1.reshape(test_ngals, height, width)
    output_img2 = output_img2.reshape(test_ngals, height, width)
    
    output_blend = output_img1 + output_img2  
    
    for i in range(test_ngals):
        
        in_comp1_cat = photutils.morphology.data_properties(comp1[i], mask = None, background = 0)
        elip_in_comp1[i] = in_comp1_cat.ellipticity
        flux_in_comp1[i] = in_comp1_cat.segment_flux
        
        in_comp2_cat = photutils.morphology.data_properties(comp2[i], mask = None, background = 0)
  
        elip_in_comp2[i] = in_comp2_cat.ellipticity
        flux_in_comp2[i] = in_comp2_cat.segment_flux
        
        in_blends_cat = photutils.morphology.data_properties(noiseless_input_img[i], mask = None, background = 0)
        flux_in_blends[i] = in_blends_cat.segment_flux

            
        out_comp1_cat = photutils.morphology.data_properties(output_img1[i], mask = None, background = 0)
        elip_out_comp1[i] = out_comp1_cat.ellipticity
        flux_out_comp1[i] = out_comp1_cat.segment_flux
        
        out_comp2_cat = photutils.morphology.data_properties(output_img2[i], mask = None, background = 0)
        elip_out_comp2[i] = out_comp2_cat.ellipticity
        flux_out_comp2[i] = out_comp2_cat.segment_flux
        
        out_blends_cat = photutils.morphology.data_properties(output_blend[i], mask = None, background = 0)
        flux_out_blends[i] = out_blends_cat.segment_flux
        
        parameters = [elip_in_comp1, elip_out_comp1, flux_in_comp1, flux_out_comp1, elip_in_comp2, elip_out_comp2, flux_in_comp2, flux_out_comp2, flux_in_blends, flux_out_blends]   
    return parameters

# %%
parameters = calc_properties(test_together, decode)

# %%
np.save("real_nc_parameters", parameters)
