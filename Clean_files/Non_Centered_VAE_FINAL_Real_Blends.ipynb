# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import photutils

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

from photutils.detection import DAOStarFinder
from photutils.morphology import data_properties
from numpy.random import normal
from astropy.stats import mad_std

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Dense, Flatten, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

from tensorflow.config import list_logical_devices, list_physical_devices, set_visible_devices
from tensorflow.config.experimental import set_memory_growth

# %%
#Setup notebook so Tensorflow works in a friendly way in a shared multi GPU env

def setup_tensorflow(seed=None):
    try:
        import nvsmi

        gpu_mem_free = np.array([gpu.mem_free for gpu in nvsmi.get_gpus()])
        if len(gpu_mem_free) > 0 and (gpu_mem_free > 0).any():
            idx = np.argmax(gpu_mem_free)
            gpu = list_physical_devices("GPU")[idx]
            set_memory_growth(gpu, True)
            set_visible_devices(gpu, "GPU")
            gpus = list_logical_devices("GPU")
            print(f"Using GPU: {gpus}")
        else:
            raise Exception
    except:
        print(f"Tensorflow using CPU")
    tf.random.set_seed(seed)

# %%
setup_tensorflow()
# Out:
# Using GPU: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-05-23 20:55:39.679682: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#load the image arrays, Size: (ngals, 64, 64), (2, ngals, 64, 64) respectively 

#Blends and components arrays are both noiseless

#Noise is then added to the blends which the network trains on

#Noiseless blends are used for the metrics 

components = np.load("isolatednewdecentred120k.npy")

# %%
def add_noise(img, scale=0.01):
    return img + normal(scale=scale, size=img.shape)

# %%
def asinh_scale(x, a=0.1, inverse=False):
    # This is a common way of scaling astronomical images
    # so that inner and outer regions of galaxies can be seen
    return np.arcsinh(x / a) / np.arcsinh(1 / a)

# %%
#Thresholding the masked areaas 


components[components<0] = -1*components[components<0]

components[components<22.3] = 22.3

# %%
#Scale the components 

components = asinh_scale(components)

#Then make the blends

blends = components[0] + components[1]

# %%
blends.shape, components.shape
# Out:
# ((120000, 64, 64), (2, 120000, 64, 64))

# %%
np.mean(blends), np.mean(components)
# Out:
# (5.402935559923415, 2.701467779961744)

# %%
#Split into training and test set 

#Going to split training and test 80% and 20% respectively 

train_ngals = int(blends.shape[0] * 0.8)
test_ngals = int(blends.shape[0] * 0.2)

train_blends = blends[:train_ngals]
test_blends = blends[train_ngals:]
test_blends_noiseless = blends[train_ngals:]

a, b, c, d, test_components = np.split(components, 5, axis = 1)

train_components = np.concatenate((a, b, c, d), axis = 1)

# %%
#Add noise to the training blends 

train_blends = add_noise(train_blends)

#Making a test_blends with noise to display for the summary plots 

#The noiseless test_blends are used for the metrics 

test_blends = add_noise(test_blends)

# %%
#Now normalise based on maximum value of the arrays

norm_max = np.max([ np.max(train_blends), np.max(test_blends), np.max(train_components), np.max(test_components), np.max(test_blends_noiseless)])

train_blends /= norm_max
test_blends /= norm_max
test_blends_noiseless /= norm_max
train_components /= norm_max
test_components /= norm_max

# %%
np.amax(train_blends), np.amin(train_blends), np.amax(test_blends), np.amin(test_blends), np.amax(test_blends_noiseless), np.amin(test_blends_noiseless)
# Out:
# (1.0,
#  0.36487805919881433,
#  0.9803146440803211,
#  0.36534478688027733,
#  0.9815264730675457,
#  0.3701357646153659)

# %%
np.amax(test_components), np.amin(test_components), np.amax(train_components), np.amin(train_components)
# Out:
# (0.5324252227395969,
#  0.18506788230768295,
#  0.5324359727340293,
#  0.18506788230768295)

# %%
height,width=64,64

train_blends = train_blends.reshape(train_ngals, height, width, 1).astype('float32')
train_components = train_components.reshape(2, train_ngals, height, width, 1).astype('float32')

test_blends = test_blends.reshape(test_ngals, height, width, 1).astype('float32')

test_blends_noiseless = test_blends_noiseless.reshape(test_ngals, height, width, 1).astype('float32')
test_components = test_components.reshape(2, test_ngals, height, width, 1).astype('float32')

# %%
batch_size = 32
latent_dimensions = 32

# %%
fig, ax = plt.subplots(2 + 1, 5, figsize=(15, 10))
for i in range(5):
    ax[0, i].imshow(train_blends[i], origin='lower', interpolation='nearest')
    ax[0, i].axis('off')
    ax[1, i].imshow(train_components[0, i], origin='lower', interpolation='nearest')
    ax[1, i].axis('off')
    ax[2, i].imshow(train_components[1, i], origin='lower', interpolation='nearest')
    ax[2, i].axis('off')

# %%
#Will optimise encoder / decoder later
def encoder(x):
    x=Conv2D(32,3,activation='relu', strides = 2, padding='same')(x)
    x=Conv2D(64,3,activation='relu', strides = 2, padding='same')(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    return x

# %%
def decoder(x):
    x=UpSampling2D(size=(2,2))(x)
    x=Conv2DTranspose(64,3,activation='relu', strides = 2 ,padding='same')(x)
    x=Conv2DTranspose(32,3,activation='relu', strides = 2 ,padding='same')(x)
    return x

# %%
def sampling(args):
    z_mean,z_log_sigma=args
    epsilon=tf.random.normal(shape=tf.shape(z_mean))
    z=z_mean+tf.exp(0.5*z_log_sigma)*epsilon
    return z

# %%
# encoder
input_blend=Input(shape=(height, width,1))

encoded=encoder(input_blend)
shape=encoded.get_shape()[1:]
encoded=Flatten()(encoded)

z_mean=Dense(latent_dimensions)(encoded)
z_log_sigma=Dense(latent_dimensions)(encoded)
z=Lambda(sampling)([z_mean,z_log_sigma])

# %%
# decoder
input_embed=Input(shape=latent_dimensions)

embed1=Dense(np.prod(shape),activation='relu')(input_embed)
embed1=Reshape(shape)(embed1)
decoded1=decoder(embed1)
output1=Conv2DTranspose(1,3,padding='same')(decoded1)

embed2=Dense(np.prod(shape),activation='relu')(input_embed)
embed2=Reshape(shape)(embed2)
decoded2=decoder(embed2)
output2=Conv2DTranspose(1,3,padding='same')(decoded2)

# %%
encode=Model(input_blend,z)
encode.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           131104      ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_component1 = Input(shape=(height, width, 1))
input_component2 = Input(shape=(height, width, 1))

decode=Model([input_embed, input_component1, input_component2], [output1, output2])
decode.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  dense_2 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  dense_3 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 64)     0           ['dense_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 64)     0           ['dense_3[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['reshape[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 64)  0           ['reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  36928       ['up_sampling2d[0][0]']
#  ose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 64)  36928       ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose_3[0][0]']
#  spose)
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_1[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_4[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 381,698
# Trainable params: 381,698
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoding = encode(input_blend)
re1, re2 = decode([encoding, input_component1, input_component2])

vae = Model([input_blend, input_component1, input_component2], [re1, re2])

# %%
vae.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model (Functional)             (None, 32)           281024      ['input_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_1 (Functional)           [(None, 64, 64, 1),  381698      ['model[0][0]',
#                                  (None, 64, 64, 1)]               'input_3[0][0]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 662,722
# Trainable params: 662,722
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
mse_lossA = mse(input_component1, re1) + mse(input_component2, re2)
mse_lossA = tf.reduce_mean(mse_lossA / 2, axis=(1, 2))
mse_lossB = mse(input_component1, re2) + mse(input_component2, re1)
mse_lossB = tf.reduce_mean(mse_lossB / 2, axis=(1, 2))
mse_loss = tf.reduce_mean(tf.minimum(mse_lossA, mse_lossB)) * height * width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss, 'mse_loss')

kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma-tf.square(z_mean)-tf.exp(z_log_sigma)))*0.1
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')


train_together = [train_blends, train_components[0], train_components[1]]
test_together = [test_blends, test_components[0], test_components[1], test_blends_noiseless]

vae.compile(optimizer=Adam())

# %%
val_split_ratio = 0.2
print(val_split_ratio * train_ngals)
# Out:
# 19200.0

# %%
history=vae.fit(train_together, verbose = 1, epochs = 100, batch_size = batch_size, validation_split = val_split_ratio)
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 39s 14ms/step - loss: 6.2410 - mse_loss: 6.0394 - kl_loss: 0.2016 - val_loss: 3.4741 - val_mse_loss: 3.2392 - val_kl_loss: 0.2349
# Epoch 2/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 3.0370 - mse_loss: 2.8062 - kl_loss: 0.2308 - val_loss: 2.8026 - val_mse_loss: 2.5724 - val_kl_loss: 0.2303
# Epoch 3/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 2.5837 - mse_loss: 2.3494 - kl_loss: 0.2343 - val_loss: 2.4133 - val_mse_loss: 2.1687 - val_kl_loss: 0.2446
# Epoch 4/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 2.3938 - mse_loss: 2.1515 - kl_loss: 0.2423 - val_loss: 2.4338 - val_mse_loss: 2.1868 - val_kl_loss: 0.2470
# Epoch 5/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 2.2320 - mse_loss: 1.9881 - kl_loss: 0.2438 - val_loss: 2.1719 - val_mse_loss: 1.9144 - val_kl_loss: 0.2575
# Epoch 6/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 2.1317 - mse_loss: 1.8879 - kl_loss: 0.2438 - val_loss: 2.0052 - val_mse_loss: 1.7565 - val_kl_loss: 0.2487
# Epoch 7/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 2.0616 - mse_loss: 1.8180 - kl_loss: 0.2436 - val_loss: 2.0038 - val_mse_loss: 1.7669 - val_kl_loss: 0.2369
# Epoch 8/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 2.0124 - mse_loss: 1.7694 - kl_loss: 0.2430 - val_loss: 1.9866 - val_mse_loss: 1.7635 - val_kl_loss: 0.2231
# Epoch 9/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.9530 - mse_loss: 1.7132 - kl_loss: 0.2398 - val_loss: 1.9203 - val_mse_loss: 1.6836 - val_kl_loss: 0.2368
# Epoch 10/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.9435 - mse_loss: 1.7036 - kl_loss: 0.2400 - val_loss: 1.9019 - val_mse_loss: 1.6521 - val_kl_loss: 0.2498
# Epoch 11/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.8895 - mse_loss: 1.6523 - kl_loss: 0.2372 - val_loss: 1.8879 - val_mse_loss: 1.6649 - val_kl_loss: 0.2229
# Epoch 12/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.8631 - mse_loss: 1.6259 - kl_loss: 0.2372 - val_loss: 1.8883 - val_mse_loss: 1.6537 - val_kl_loss: 0.2346
# Epoch 13/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.8453 - mse_loss: 1.6097 - kl_loss: 0.2356 - val_loss: 1.8511 - val_mse_loss: 1.6202 - val_kl_loss: 0.2309
# Epoch 14/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.8397 - mse_loss: 1.6050 - kl_loss: 0.2348 - val_loss: 1.7884 - val_mse_loss: 1.5438 - val_kl_loss: 0.2446
# Epoch 15/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7959 - mse_loss: 1.5615 - kl_loss: 0.2343 - val_loss: 1.8622 - val_mse_loss: 1.6362 - val_kl_loss: 0.2260
# Epoch 16/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7800 - mse_loss: 1.5466 - kl_loss: 0.2334 - val_loss: 1.8427 - val_mse_loss: 1.6141 - val_kl_loss: 0.2286
# Epoch 17/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7936 - mse_loss: 1.5602 - kl_loss: 0.2334 - val_loss: 1.7786 - val_mse_loss: 1.5424 - val_kl_loss: 0.2362
# Epoch 18/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7633 - mse_loss: 1.5294 - kl_loss: 0.2339 - val_loss: 1.8000 - val_mse_loss: 1.5605 - val_kl_loss: 0.2396
# Epoch 19/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7437 - mse_loss: 1.5105 - kl_loss: 0.2332 - val_loss: 1.7705 - val_mse_loss: 1.5298 - val_kl_loss: 0.2407
# Epoch 20/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7517 - mse_loss: 1.5187 - kl_loss: 0.2331 - val_loss: 1.8533 - val_mse_loss: 1.6228 - val_kl_loss: 0.2304
# Epoch 21/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7345 - mse_loss: 1.5012 - kl_loss: 0.2333 - val_loss: 1.8036 - val_mse_loss: 1.5869 - val_kl_loss: 0.2167
# Epoch 22/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7163 - mse_loss: 1.4840 - kl_loss: 0.2324 - val_loss: 1.7053 - val_mse_loss: 1.4683 - val_kl_loss: 0.2370
# Epoch 23/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6942 - mse_loss: 1.4608 - kl_loss: 0.2333 - val_loss: 1.7903 - val_mse_loss: 1.5503 - val_kl_loss: 0.2400
# Epoch 24/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6923 - mse_loss: 1.4608 - kl_loss: 0.2315 - val_loss: 1.7492 - val_mse_loss: 1.5091 - val_kl_loss: 0.2401
# Epoch 25/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.7013 - mse_loss: 1.4695 - kl_loss: 0.2318 - val_loss: 1.8112 - val_mse_loss: 1.5792 - val_kl_loss: 0.2320
# Epoch 26/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6949 - mse_loss: 1.4642 - kl_loss: 0.2308 - val_loss: 1.6915 - val_mse_loss: 1.4628 - val_kl_loss: 0.2287
# Epoch 27/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6840 - mse_loss: 1.4525 - kl_loss: 0.2315 - val_loss: 1.6938 - val_mse_loss: 1.4624 - val_kl_loss: 0.2314
# Epoch 28/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6831 - mse_loss: 1.4518 - kl_loss: 0.2313 - val_loss: 1.7692 - val_mse_loss: 1.5350 - val_kl_loss: 0.2342
# Epoch 29/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6760 - mse_loss: 1.4458 - kl_loss: 0.2302 - val_loss: 1.8097 - val_mse_loss: 1.5814 - val_kl_loss: 0.2284
# Epoch 30/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6747 - mse_loss: 1.4424 - kl_loss: 0.2323 - val_loss: 1.6501 - val_mse_loss: 1.4154 - val_kl_loss: 0.2347
# Epoch 31/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6842 - mse_loss: 1.4522 - kl_loss: 0.2320 - val_loss: 1.6751 - val_mse_loss: 1.4400 - val_kl_loss: 0.2351
# Epoch 32/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6464 - mse_loss: 1.4152 - kl_loss: 0.2312 - val_loss: 1.6767 - val_mse_loss: 1.4519 - val_kl_loss: 0.2249
# Epoch 33/100
# 2400/2400 [==============================] - 35s 15ms/step - loss: 1.6504 - mse_loss: 1.4194 - kl_loss: 0.2310 - val_loss: 1.6912 - val_mse_loss: 1.4646 - val_kl_loss: 0.2266
# Epoch 34/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6513 - mse_loss: 1.4217 - kl_loss: 0.2296 - val_loss: 1.6826 - val_mse_loss: 1.4489 - val_kl_loss: 0.2336
# Epoch 35/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6454 - mse_loss: 1.4137 - kl_loss: 0.2318 - val_loss: 1.7106 - val_mse_loss: 1.4765 - val_kl_loss: 0.2341
# Epoch 36/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6392 - mse_loss: 1.4059 - kl_loss: 0.2333 - val_loss: 1.7145 - val_mse_loss: 1.4683 - val_kl_loss: 0.2462
# Epoch 37/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6342 - mse_loss: 1.4045 - kl_loss: 0.2297 - val_loss: 1.6193 - val_mse_loss: 1.3953 - val_kl_loss: 0.2240
# Epoch 38/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6331 - mse_loss: 1.4027 - kl_loss: 0.2304 - val_loss: 1.6172 - val_mse_loss: 1.3945 - val_kl_loss: 0.2227
# Epoch 39/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6297 - mse_loss: 1.4007 - kl_loss: 0.2290 - val_loss: 1.6542 - val_mse_loss: 1.4369 - val_kl_loss: 0.2172
# Epoch 40/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6451 - mse_loss: 1.4124 - kl_loss: 0.2326 - val_loss: 1.6412 - val_mse_loss: 1.4111 - val_kl_loss: 0.2301
# Epoch 41/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5974 - mse_loss: 1.3670 - kl_loss: 0.2304 - val_loss: 1.7016 - val_mse_loss: 1.4780 - val_kl_loss: 0.2236
# Epoch 42/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6249 - mse_loss: 1.3923 - kl_loss: 0.2325 - val_loss: 1.6332 - val_mse_loss: 1.3985 - val_kl_loss: 0.2347
# Epoch 43/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6158 - mse_loss: 1.3861 - kl_loss: 0.2296 - val_loss: 1.7583 - val_mse_loss: 1.5327 - val_kl_loss: 0.2256
# Epoch 44/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6191 - mse_loss: 1.3902 - kl_loss: 0.2290 - val_loss: 1.6462 - val_mse_loss: 1.4157 - val_kl_loss: 0.2305
# Epoch 45/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5984 - mse_loss: 1.3679 - kl_loss: 0.2305 - val_loss: 1.6292 - val_mse_loss: 1.3957 - val_kl_loss: 0.2334
# Epoch 46/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5954 - mse_loss: 1.3656 - kl_loss: 0.2298 - val_loss: 1.6159 - val_mse_loss: 1.3851 - val_kl_loss: 0.2308
# Epoch 47/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6147 - mse_loss: 1.3852 - kl_loss: 0.2295 - val_loss: 1.6068 - val_mse_loss: 1.3758 - val_kl_loss: 0.2310
# Epoch 48/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6317 - mse_loss: 1.4016 - kl_loss: 0.2301 - val_loss: 1.6679 - val_mse_loss: 1.4405 - val_kl_loss: 0.2274
# Epoch 49/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5949 - mse_loss: 1.3638 - kl_loss: 0.2312 - val_loss: 1.6246 - val_mse_loss: 1.3983 - val_kl_loss: 0.2263
# Epoch 50/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5816 - mse_loss: 1.3518 - kl_loss: 0.2298 - val_loss: 1.5601 - val_mse_loss: 1.3360 - val_kl_loss: 0.2241
# Epoch 51/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5753 - mse_loss: 1.3454 - kl_loss: 0.2298 - val_loss: 1.5845 - val_mse_loss: 1.3470 - val_kl_loss: 0.2375
# Epoch 52/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5782 - mse_loss: 1.3480 - kl_loss: 0.2303 - val_loss: 1.6354 - val_mse_loss: 1.4006 - val_kl_loss: 0.2348
# Epoch 53/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5888 - mse_loss: 1.3578 - kl_loss: 0.2309 - val_loss: 1.6720 - val_mse_loss: 1.4401 - val_kl_loss: 0.2319
# Epoch 54/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5754 - mse_loss: 1.3443 - kl_loss: 0.2311 - val_loss: 1.5925 - val_mse_loss: 1.3698 - val_kl_loss: 0.2227
# Epoch 55/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5620 - mse_loss: 1.3320 - kl_loss: 0.2300 - val_loss: 1.7072 - val_mse_loss: 1.4808 - val_kl_loss: 0.2264
# Epoch 56/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5728 - mse_loss: 1.3421 - kl_loss: 0.2307 - val_loss: 1.7110 - val_mse_loss: 1.4922 - val_kl_loss: 0.2188
# Epoch 57/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5679 - mse_loss: 1.3384 - kl_loss: 0.2295 - val_loss: 1.6295 - val_mse_loss: 1.3943 - val_kl_loss: 0.2351
# Epoch 58/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5841 - mse_loss: 1.3532 - kl_loss: 0.2309 - val_loss: 1.6650 - val_mse_loss: 1.4441 - val_kl_loss: 0.2209
# Epoch 59/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5586 - mse_loss: 1.3289 - kl_loss: 0.2298 - val_loss: 1.6054 - val_mse_loss: 1.3809 - val_kl_loss: 0.2245
# Epoch 60/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5561 - mse_loss: 1.3259 - kl_loss: 0.2302 - val_loss: 1.6267 - val_mse_loss: 1.3934 - val_kl_loss: 0.2332
# Epoch 61/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5493 - mse_loss: 1.3179 - kl_loss: 0.2314 - val_loss: 1.6732 - val_mse_loss: 1.4426 - val_kl_loss: 0.2306
# Epoch 62/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5953 - mse_loss: 1.3646 - kl_loss: 0.2307 - val_loss: 1.7979 - val_mse_loss: 1.5658 - val_kl_loss: 0.2321
# Epoch 63/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.6195 - mse_loss: 1.3893 - kl_loss: 0.2302 - val_loss: 1.5920 - val_mse_loss: 1.3555 - val_kl_loss: 0.2365
# Epoch 64/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5445 - mse_loss: 1.3168 - kl_loss: 0.2278 - val_loss: 1.5443 - val_mse_loss: 1.3230 - val_kl_loss: 0.2213
# Epoch 65/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5619 - mse_loss: 1.3314 - kl_loss: 0.2306 - val_loss: 1.6982 - val_mse_loss: 1.4564 - val_kl_loss: 0.2418
# Epoch 66/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5679 - mse_loss: 1.3376 - kl_loss: 0.2303 - val_loss: 1.7162 - val_mse_loss: 1.5050 - val_kl_loss: 0.2112
# Epoch 67/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5508 - mse_loss: 1.3211 - kl_loss: 0.2297 - val_loss: 1.6901 - val_mse_loss: 1.4701 - val_kl_loss: 0.2200
# Epoch 68/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5513 - mse_loss: 1.3215 - kl_loss: 0.2298 - val_loss: 1.7949 - val_mse_loss: 1.5414 - val_kl_loss: 0.2535
# Epoch 69/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5354 - mse_loss: 1.3058 - kl_loss: 0.2296 - val_loss: 1.7119 - val_mse_loss: 1.4878 - val_kl_loss: 0.2241
# Epoch 70/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5596 - mse_loss: 1.3296 - kl_loss: 0.2301 - val_loss: 1.5558 - val_mse_loss: 1.3316 - val_kl_loss: 0.2242
# Epoch 71/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5580 - mse_loss: 1.3277 - kl_loss: 0.2303 - val_loss: 1.5338 - val_mse_loss: 1.3003 - val_kl_loss: 0.2335
# Epoch 72/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5358 - mse_loss: 1.3067 - kl_loss: 0.2290 - val_loss: 1.5503 - val_mse_loss: 1.3240 - val_kl_loss: 0.2264
# Epoch 73/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5385 - mse_loss: 1.3085 - kl_loss: 0.2300 - val_loss: 1.5741 - val_mse_loss: 1.3430 - val_kl_loss: 0.2311
# Epoch 74/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5275 - mse_loss: 1.2962 - kl_loss: 0.2313 - val_loss: 1.5980 - val_mse_loss: 1.3776 - val_kl_loss: 0.2203
# Epoch 75/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5243 - mse_loss: 1.2952 - kl_loss: 0.2291 - val_loss: 1.5388 - val_mse_loss: 1.3170 - val_kl_loss: 0.2218
# Epoch 76/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5503 - mse_loss: 1.3206 - kl_loss: 0.2297 - val_loss: 1.5604 - val_mse_loss: 1.3376 - val_kl_loss: 0.2229
# Epoch 77/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5265 - mse_loss: 1.2960 - kl_loss: 0.2305 - val_loss: 1.6078 - val_mse_loss: 1.3797 - val_kl_loss: 0.2281
# Epoch 78/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5289 - mse_loss: 1.3004 - kl_loss: 0.2286 - val_loss: 1.5549 - val_mse_loss: 1.3331 - val_kl_loss: 0.2218
# Epoch 79/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5375 - mse_loss: 1.3086 - kl_loss: 0.2289 - val_loss: 1.6169 - val_mse_loss: 1.3943 - val_kl_loss: 0.2226
# Epoch 80/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5294 - mse_loss: 1.2995 - kl_loss: 0.2300 - val_loss: 1.5437 - val_mse_loss: 1.3143 - val_kl_loss: 0.2294
# Epoch 81/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5223 - mse_loss: 1.2935 - kl_loss: 0.2288 - val_loss: 1.5419 - val_mse_loss: 1.3191 - val_kl_loss: 0.2228
# Epoch 82/100
# 2400/2400 [==============================] - 33s 14ms/step - loss: 1.5297 - mse_loss: 1.2994 - kl_loss: 0.2303 - val_loss: 1.6142 - val_mse_loss: 1.3887 - val_kl_loss: 0.2255
# Epoch 83/100
# 2400/2400 [==============================] - 34s 14ms/step - loss: 1.5665 - mse_loss: 1.3348 - kl_loss: 0.2317 - val_loss: 1.6697 - val_mse_loss: 1.4351 - val_kl_loss: 0.2346
# Epoch 84/100
# 2400/2400 [==============================] - 31s 13ms/step - loss: 1.5287 - mse_loss: 1.2982 - kl_loss: 0.2305 - val_loss: 1.5506 - val_mse_loss: 1.3254 - val_kl_loss: 0.2252
# Epoch 85/100
# 2400/2400 [==============================] - 28s 12ms/step - loss: 1.4957 - mse_loss: 1.2648 - kl_loss: 0.2309 - val_loss: 1.5473 - val_mse_loss: 1.3195 - val_kl_loss: 0.2278
# Epoch 86/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5207 - mse_loss: 1.2904 - kl_loss: 0.2302 - val_loss: 1.5859 - val_mse_loss: 1.3508 - val_kl_loss: 0.2351
# Epoch 87/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5137 - mse_loss: 1.2846 - kl_loss: 0.2291 - val_loss: 1.5752 - val_mse_loss: 1.3396 - val_kl_loss: 0.2357
# Epoch 88/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5054 - mse_loss: 1.2749 - kl_loss: 0.2305 - val_loss: 1.6390 - val_mse_loss: 1.4219 - val_kl_loss: 0.2171
# Epoch 89/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5108 - mse_loss: 1.2805 - kl_loss: 0.2304 - val_loss: 1.5312 - val_mse_loss: 1.2938 - val_kl_loss: 0.2374
# Epoch 90/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5337 - mse_loss: 1.3028 - kl_loss: 0.2310 - val_loss: 1.5105 - val_mse_loss: 1.2733 - val_kl_loss: 0.2372
# Epoch 91/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5023 - mse_loss: 1.2726 - kl_loss: 0.2297 - val_loss: 1.5664 - val_mse_loss: 1.3306 - val_kl_loss: 0.2358
# Epoch 92/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5137 - mse_loss: 1.2845 - kl_loss: 0.2292 - val_loss: 1.5854 - val_mse_loss: 1.3499 - val_kl_loss: 0.2355
# Epoch 93/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5317 - mse_loss: 1.3022 - kl_loss: 0.2295 - val_loss: 1.6075 - val_mse_loss: 1.3857 - val_kl_loss: 0.2217
# Epoch 94/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5337 - mse_loss: 1.3037 - kl_loss: 0.2300 - val_loss: 1.6327 - val_mse_loss: 1.3966 - val_kl_loss: 0.2362
# Epoch 95/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5178 - mse_loss: 1.2876 - kl_loss: 0.2302 - val_loss: 1.5111 - val_mse_loss: 1.2893 - val_kl_loss: 0.2218
# Epoch 96/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5035 - mse_loss: 1.2745 - kl_loss: 0.2289 - val_loss: 1.5867 - val_mse_loss: 1.3555 - val_kl_loss: 0.2312
# Epoch 97/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5131 - mse_loss: 1.2869 - kl_loss: 0.2262 - val_loss: 1.6072 - val_mse_loss: 1.3719 - val_kl_loss: 0.2353
# Epoch 98/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.4933 - mse_loss: 1.2663 - kl_loss: 0.2270 - val_loss: 1.5877 - val_mse_loss: 1.3600 - val_kl_loss: 0.2277
# Epoch 99/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5168 - mse_loss: 1.2893 - kl_loss: 0.2275 - val_loss: 1.5376 - val_mse_loss: 1.3093 - val_kl_loss: 0.2283
# Epoch 100/100
# 2400/2400 [==============================] - 29s 12ms/step - loss: 1.5138 - mse_loss: 1.2852 - kl_loss: 0.2286 - val_loss: 1.6439 - val_mse_loss: 1.4028 - val_kl_loss: 0.2411

# %%
def histplot(history):
    plt.rcParams["figure.figsize"] = (10,7)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, label = 'Training loss')
    plt.plot(epochs, val_loss, label = 'Validation loss')
    plt.axhline( y = min(val_loss), color = 'black', linestyle = 'dotted', label = f'Minimum Validation Loss: {min(val_loss):.4f}')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
histplot(history)

# %%
def showimg(img, ax, title=None, vmin=0, vmax=1):
    ax.imshow(img.squeeze(), vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.axis('off')

def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    noisy_input_img = inputs[0][idx]
    comp1 = inputs[1][idx]
    comp2 = inputs[2][idx]
    noiseless_input_img = inputs[3][idx]
    z = encode.predict(noisy_input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    print(output_img1.shape)
    fig, ax = plt.subplots(7, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(noisy_input_img[i], origin='lower', interpolation='nearest')
        ax[0, i].set_title('In Blend')
        ax[0, i].axis('off')
        ax[1, i].imshow(comp1[i], origin='lower', interpolation='nearest')
        ax[1, i].set_title('In Comp 1')
        ax[1, i].axis('off')
        ax[2, i].imshow(comp2[i], origin='lower', interpolation='nearest')
        ax[2, i].set_title('In Comp 2')
        ax[2, i].axis('off')
        ax[3, i].imshow(output_img1[i], origin='lower', interpolation='nearest')
        ax[3, i].set_title(f'Re Comp 1 - SSIM:{max(ssim(comp1[i], output_img1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False), ssim(comp1[i], output_img2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False)):.2f}')
        ax[3, i].axis('off')
        ax[4, i].imshow(output_img2[i], origin='lower', interpolation='nearest')
        ax[4, i].set_title(f'Re Comp 2 - SSIM: {max(ssim(comp2[i], output_img2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False), ssim(comp2[i], output_img1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False)):.2f}')
        ax[4, i].axis('off')
        ax[5, i].imshow((output_img1[i] + output_img2[i]) , origin='lower', interpolation='nearest')
        ax[5, i].set_title(f'Re Blend - SSIM: {ssim(noiseless_input_img[i], (output_img1[i] + output_img2[i]), channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[5, i].axis('off')
        ax[6, i].imshow(abs(noiseless_input_img[i] -(output_img1[i] + output_img2[i])) , origin='lower', interpolation='nearest')
        ax[6, i].set_title('Blend Difference')
        ax[6, i].axis('off')
        plt.tight_layout()
    return idx

# %%
n=5
chosen=summary_plot(n,test_together,decode)
# Out:
# [ 6414 13523  8374  5256  4405]
# (5, 64, 64, 1)

# %%
def calc_ssim(inputs,decode):
    ssim_comp1 = np.zeros(test_ngals)
    ssim_comp2 = np.zeros(test_ngals)
    ssim_blends = np.zeros(test_ngals)
    noisy_input_img = inputs[0]
    comp1 = inputs[1]
    comp2 = inputs[2]
    noiseless_input_img = inputs[3]
    z = encode.predict(noisy_input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    for i in range(test_ngals):
        ssim_comp1[i] = max(ssim(comp1[i], output_img1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False), ssim(comp1[i], output_img2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False))
        ssim_comp2[i] = max(ssim(comp2[i], output_img2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False), ssim(comp2[i], output_img1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False))
        ssim_blends[i] = ssim(noiseless_input_img[i], (output_img1[i] + output_img2[i]), channel_axis = 2, gaussian_weights = True, use_sample_covarience = False)
    
    ssim_values = np.array([ssim_comp1, ssim_comp2, ssim_blends])
    
    return ssim_values

# %%
ssim_values = calc_ssim(test_together, decode)

# %%
#Plot violinplots of the SSIM

n_of_bins = 100
bins = np.linspace(0,1,n_of_bins+1)

c = 'lightblue'
outline = 'cornflowerblue'


fig, ax = plt.subplots(1, 2, figsize = (13,5))


vp1 = ax[0].hist(ssim_values[0], bins, color = c, ec = outline, alpha = 0.3, lw = 2)

ax[0].set_title('SSIMs of Component 1')
ax[0].set_xlabel('SSIM')
ax[0].set_ylabel('Density')

 

vp2 = ax[1].hist(ssim_values[1], bins,  color = c, ec = outline, alpha = 0.3, lw = 2)

ax[1].set_title('SSIMs of Component 2')  
ax[1].set_xlabel('SSIM')
ax[1].set_ylabel('Density')
  
ax[0].set_xlim(0, 1) 
ax[1].set_xlim(0, 1) 
plt.tight_layout()

plt.show()

# %%
mean_ssim_comp1 = np.mean(ssim_values[0])
median_ssim_comp1 = np.median(ssim_values[0])
mean_ssim_comp2 = np.mean(ssim_values[1])
median_ssim_comp2 = np.median(ssim_values[1])
mean_ssim_blends = np.mean(ssim_values[2])
median_ssim_blends = np.median(ssim_values[2])

# %%
print(f' Mean SSIMs: Component 1: {mean_ssim_comp1:.4f}, Component 2: {mean_ssim_comp2:.4f}, Blends: {mean_ssim_blends:.4f}')

print(f' Median SSIMs: Component 1: {median_ssim_comp1:.4f}, Component 2: {median_ssim_comp2:.4f}, Blends: {median_ssim_blends:.4f}')
# Out:
#  Mean SSIMs: Component 1: 0.9767, Component 2: 0.9768, Blends: 0.9648
#  Median SSIMs: Component 1: 0.9808, Component 2: 0.9809, Blends: 0.9685

# %%
#This function calculates the properties of the input and output images. The ellipticity and flux are stored in arrays 

def calc_properties(inputs,decode):
    
    empty_array = np.zeros(test_ngals)
    
    flux_in_comp1 = np.zeros(test_ngals)
    flux_in_comp2 = np.zeros(test_ngals)
    flux_in_blends = np.zeros(test_ngals)
    
    flux_out_comp1 = np.zeros(test_ngals)
    flux_out_comp2 = np.zeros(test_ngals)
    flux_out_blends = np.zeros(test_ngals)
    
    
    elip_in_comp1 = np.zeros(test_ngals)
    elip_in_comp2 = np.zeros(test_ngals)
    
    elip_out_comp1 = np.zeros(test_ngals)
    elip_out_comp2 = np.zeros(test_ngals)
    
    output_blends = np.zeros(test_ngals)
    
    noisy_input_img = inputs[0]
    noisy_input_img = noisy_input_img.reshape(test_ngals, height, width)
    comp1 = inputs[1]
    comp1 = comp1.reshape(test_ngals, height, width)
    comp2 = inputs[2]
    comp2 = comp2.reshape(test_ngals, height,width)
    noiseless_input_img = inputs[3]
    noiseless_input_img = noiseless_input_img.reshape(test_ngals, height, width)

    z = encode.predict(noisy_input_img)
    output_img1, output_img2 = decode.predict([z, comp1, comp2])
    
    output_img1 = output_img1.reshape(test_ngals, height, width)
    output_img2 = output_img2.reshape(test_ngals, height, width,)
        
    output_blends = output_img1 + output_img2 
    
    for i in range(test_ngals):
        
        #Need to determine which output image corresponds to what blob 
        
        img1_ssim_array =  [ssim(comp1[i], output_img1[i],gaussian_weights = True, use_sample_covarience = False), ssim(comp1[i], output_img2[i], gaussian_weights = True, use_sample_covarience = False)]
        img1_max_value = max(img1_ssim_array)
        img1_index = np.where(img1_ssim_array == img1_max_value)
        
        #Swap them if the outputs are the wrong way round
                             
        if img1_index[0] == 1:
            temp_oimg1 = output_img1[i].copy()
            output_img1[i] = output_img2[i]
            output_img2[i] = temp_oimg1

        
        in_comp1_cat = photutils.morphology.data_properties(comp1[i], mask = None, background = 0)
        elip_in_comp1[i] = in_comp1_cat.ellipticity
        flux_in_comp1[i] = in_comp1_cat.segment_flux
        
        in_comp2_cat = photutils.morphology.data_properties(comp2[i], mask = None, background = 0)
  
        elip_in_comp2[i] = in_comp2_cat.ellipticity
        flux_in_comp2[i] = in_comp2_cat.segment_flux
        
        
        in_blends_cat = photutils.morphology.data_properties(noiseless_input_img[i], mask = None, background = 0)
        flux_in_blends[i] = in_blends_cat.segment_flux

            
        out_comp1_cat = photutils.morphology.data_properties(output_img1[i], mask = None, background = 0)
        elip_out_comp1[i] = out_comp1_cat.ellipticity
        flux_out_comp1[i] = out_comp1_cat.segment_flux
        
        out_comp2_cat = photutils.morphology.data_properties(output_img2[i], mask = None, background = 0)
        elip_out_comp2[i] = out_comp2_cat.ellipticity
        flux_out_comp2[i] = out_comp2_cat.segment_flux
        
        out_blends_cat = photutils.morphology.data_properties(output_blends[i], mask = None, background = 0)
        flux_out_blends[i] = out_blends_cat.segment_flux
        
        parameters = [elip_in_comp1, elip_out_comp1, flux_in_comp1, flux_out_comp1, elip_in_comp2, elip_out_comp2, flux_in_comp2, flux_out_comp2, flux_in_blends, flux_out_blends]   
    return parameters

# %%
parameters = calc_properties(test_together, decode)

# %%
np.save("real_nc_parameters", parameters)
