# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import photutils

from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

from photutils.detection import DAOStarFinder
from photutils.morphology import data_properties
from astropy.stats import mad_std
from numpy.random import normal

from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Dense, Flatten, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

from tensorflow.config import list_logical_devices, list_physical_devices, set_visible_devices
from tensorflow.config.experimental import set_memory_growth

# %%
#Setup notebook so Tensorflow works in a friendly way in a shared multi GPU env

def setup_tensorflow(seed=None):
    try:
        import nvsmi
        gpu_mem_free = np.array([gpu.mem_free for gpu in nvsmi.get_gpus()])
        if len(gpu_mem_free) > 0 and (gpu_mem_free > 0).any():
            idx = np.argmax(gpu_mem_free)
            gpu = list_physical_devices("GPU")[idx]
            set_memory_growth(gpu, True)
            set_visible_devices(gpu, "GPU")
            gpus = list_logical_devices("GPU")
            print(f"Using GPU: {gpus}")
        else:
            raise Exception
    except:
        print(f"Tensorflow using CPU")
    tf.random.set_seed(seed)

# %%
#If working in a multiply GPU setup run setup_tensorflow()

setup_tensorflow()
# Out:
# Using GPU: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# 2022-05-19 13:55:09.268943: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#load the image arrays, Size: (ngals, 64, 64), (2, ngals, 64, 64) respectively 

#Blends and components arrays are both noiseless

#Noise is then added to the blends which the network trains on

#Noiseless blends are used for the metrics 

blends = np.load("c_blends.npy")
components = np.load("c_components.npy")

# %%
def add_noise(img, scale=0.01):
    return img + normal(scale=scale, size=img.shape)

# %%
blends.shape, components.shape
# Out:
# ((120000, 64, 64), (2, 120000, 64, 64))

# %%
np.mean(blends), np.mean(components)
# Out:
# (0.3124135834937247, 0.15620679174686417)

# %%
def showimg(img, ax, title=None, vmin=0, vmax=1):
    ax.imshow(img.squeeze(), vmin=vmin, vmax=vmax)
    ax.set_title(title)
    ax.axis('off')

# %%
"""
def loss_plot(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['mse_loss'])
    plt.plot(history.history['val_loss'])
    plt.plot(history.history['kl_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['loss','mse_loss','val_loss','kl_loss'])
"""
# Out:
# "\ndef loss_plot(history):\n    plt.plot(history.history['loss'])\n    plt.plot(history.history['mse_loss'])\n    plt.plot(history.history['val_loss'])\n    plt.plot(history.history['kl_loss'])\n    plt.title('model loss')\n    plt.ylabel('loss')\n    plt.xlabel('epoch')\n    plt.legend(['loss','mse_loss','val_loss','kl_loss'])\n"

# %%
def histplot(history):
    plt.rcParams["figure.figsize"] = (10,7)
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, label = 'Training loss')
    plt.plot(epochs, val_loss, label = 'Validation loss')
    plt.axhline( y = min(val_loss), color = 'black', linestyle = 'dotted', label = f'Minimum Validation Loss: {min(val_loss):.4f}')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
height,width=64,64

#train_buffer=60000
#test_buffer=10000

#batch_size=10
#latent_dimensions=16

num=4000
comps=2

beta=0.1

# %%
#Split into training and test set 

#Going to split training and test 80% and 20% respectively 

train_ngals = int(blends.shape[0] * 0.8)
test_ngals = int(blends.shape[0] * 0.2)

train_blends = blends[:train_ngals]
test_blends = blends[train_ngals:]

a, b, c, d, test_components = np.split(components, 5, axis = 1)

train_components = np.concatenate((a, b, c, d), axis = 1)

# %%
#Add noise to the training blends 

#Note we have split them up before encase later on we would like to change if our train / test blends have noise

train_blends = add_noise(train_blends)
test_blends = add_noise(test_blends)

# %%
#Now normalise based on maximum value of the arrays

norm_max = np.max([ np.max(train_blends), np.max(test_blends), np.max(train_components), np.max(test_components)])

train_blends /= norm_max
test_blends /= norm_max
train_components /= norm_max
test_components /= norm_max

# %%
train_components.shape, test_components.shape
# Out:
# ((2, 96000, 64, 64), (2, 24000, 64, 64))

# %%
train_blends.shape, test_blends.shape
# Out:
# ((96000, 64, 64), (24000, 64, 64))

# %%
np.amax(train_blends), np.amin(train_blends), np.amax(test_blends), np.amin(test_blends)
# Out:
# (1.0, -0.01048933975942797, 0.9251459672372343, -0.010746754965036085)

# %%
height,width=64,64

train_blends = train_blends.reshape(train_ngals, height, width, 1).astype('float32')
train_components = train_components.reshape(2, train_ngals, height, width, 1).astype('float32')

test_blends = test_blends.reshape(test_ngals, height, width, 1).astype('float32')
test_components = test_components.reshape(2, test_ngals, height, width, 1).astype('float32')

# %%
batch_size = 32
latent_dimensions = 32

# %%
n=5
fig,ax=plt.subplots(3,n,figsize=(3*n, 10))
for i in range(n):
    showimg(train_blends[i],ax[0,i],f'blend {i}')
    for j in range(comps):
        showimg(train_components[j,i],ax[j+1,i],f'component {j}')

# %%
def encoder(x):
    x=Conv2D(32,3,activation='relu',padding='same',strides=2)(x)
    x=Conv2D(64,3,activation='relu',padding='same',strides=2)(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    return x

# %%
def decoder(x):
    x=UpSampling2D(size=(2,2))(x)
    x=Conv2DTranspose(64,3,activation='relu',padding='same',strides=2)(x)
    x=Conv2DTranspose(32,3,activation='relu',padding='same',strides=2)(x)
    return x

# %%
def sampling(args):
    z_mean,z_log_sigma=args
    epsilon=tf.random.normal(shape=tf.shape(z_mean))
    z=z_mean+tf.exp(0.5*z_log_sigma)*epsilon
    return z

# %%
#encoder
inputs=Input(shape=(height,width,1))

encoded=encoder(inputs)
shape=encoded.get_shape()[1:]
encoded=Flatten()(encoded)

z_mean=Dense(latent_dimensions)(encoded)
z_log_sigma=Dense(latent_dimensions)(encoded)
z=Lambda(sampling)([z_mean,z_log_sigma])

#decoder
input_embed=Input(shape=latent_dimensions)

embed1=Dense(np.prod(shape),activation='relu')(input_embed)
embed1=Reshape(shape)(embed1)
decoded1=decoder(embed1)
output1=Conv2DTranspose(1,3,padding='same')(decoded1)

# %%
encode=Model(inputs,z)
encode.summary()

decode=Model([input_embed],[output1])
decode.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 32)           131104      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 32)           131104      ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32)]              0
#
#  dense_2 (Dense)             (None, 4096)              135168
#
#  reshape (Reshape)           (None, 8, 8, 64)          0
#
#  up_sampling2d (UpSampling2D  (None, 16, 16, 64)       0
#  )
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 64, 64, 32)       18464
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 64, 64, 1)        289
#  ranspose)
#
# =================================================================
# Total params: 190,849
# Trainable params: 190,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoding=encode(inputs) #define the network
re=decode([encoding])

vae=Model([inputs],[re]) #adds methods of the network
vae.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  model (Functional)          (None, 32)                281024
#
#  model_1 (Functional)        (None, 64, 64, 1)         190849
#
# =================================================================
# Total params: 471,873
# Trainable params: 471,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
mse_loss=tf.reduce_mean(mse(inputs,re))*height*width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss,'mse_loss')

kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma-tf.square(z_mean)-tf.exp(z_log_sigma)))*beta
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')

vae.compile(optimizer=Adam(learning_rate=0.001))

# %%
val_split_ratio = 0.2
print(val_split_ratio * train_ngals)
# Out:
# 19200.0

# %%
history=vae.fit(train_components[0],verbose=1,epochs=100,batch_size=batch_size,validation_split=val_split_ratio)
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 30s 10ms/step - loss: 0.2649 - mse_loss: 0.1743 - kl_loss: 0.0907 - val_loss: 0.0889 - val_mse_loss: 0.0324 - val_kl_loss: 0.0564
# Epoch 2/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.0773 - mse_loss: 0.0290 - kl_loss: 0.0483 - val_loss: 0.0658 - val_mse_loss: 0.0203 - val_kl_loss: 0.0455
# Epoch 3/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0669 - mse_loss: 0.0230 - kl_loss: 0.0439 - val_loss: 0.0587 - val_mse_loss: 0.0165 - val_kl_loss: 0.0422
# Epoch 4/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0620 - mse_loss: 0.0205 - kl_loss: 0.0415 - val_loss: 0.0623 - val_mse_loss: 0.0214 - val_kl_loss: 0.0409
# Epoch 5/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0590 - mse_loss: 0.0197 - kl_loss: 0.0392 - val_loss: 0.0554 - val_mse_loss: 0.0172 - val_kl_loss: 0.0382
# Epoch 6/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0555 - mse_loss: 0.0185 - kl_loss: 0.0371 - val_loss: 0.0525 - val_mse_loss: 0.0167 - val_kl_loss: 0.0358
# Epoch 7/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0528 - mse_loss: 0.0178 - kl_loss: 0.0350 - val_loss: 0.0492 - val_mse_loss: 0.0150 - val_kl_loss: 0.0341
# Epoch 8/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0503 - mse_loss: 0.0166 - kl_loss: 0.0338 - val_loss: 0.0475 - val_mse_loss: 0.0133 - val_kl_loss: 0.0342
# Epoch 9/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0492 - mse_loss: 0.0160 - kl_loss: 0.0332 - val_loss: 0.0503 - val_mse_loss: 0.0177 - val_kl_loss: 0.0326
# Epoch 10/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0485 - mse_loss: 0.0157 - kl_loss: 0.0328 - val_loss: 0.0472 - val_mse_loss: 0.0147 - val_kl_loss: 0.0325
# Epoch 11/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0480 - mse_loss: 0.0154 - kl_loss: 0.0326 - val_loss: 0.0474 - val_mse_loss: 0.0146 - val_kl_loss: 0.0327
# Epoch 12/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0472 - mse_loss: 0.0147 - kl_loss: 0.0324 - val_loss: 0.0501 - val_mse_loss: 0.0174 - val_kl_loss: 0.0327
# Epoch 13/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0472 - mse_loss: 0.0148 - kl_loss: 0.0324 - val_loss: 0.0577 - val_mse_loss: 0.0249 - val_kl_loss: 0.0328
# Epoch 14/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.0469 - mse_loss: 0.0146 - kl_loss: 0.0323 - val_loss: 0.0456 - val_mse_loss: 0.0132 - val_kl_loss: 0.0324
# Epoch 15/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0465 - mse_loss: 0.0142 - kl_loss: 0.0323 - val_loss: 0.0447 - val_mse_loss: 0.0126 - val_kl_loss: 0.0321
# Epoch 16/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0462 - mse_loss: 0.0139 - kl_loss: 0.0322 - val_loss: 0.0443 - val_mse_loss: 0.0122 - val_kl_loss: 0.0321
# Epoch 17/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0458 - mse_loss: 0.0137 - kl_loss: 0.0321 - val_loss: 0.0455 - val_mse_loss: 0.0130 - val_kl_loss: 0.0326
# Epoch 18/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0460 - mse_loss: 0.0138 - kl_loss: 0.0321 - val_loss: 0.0442 - val_mse_loss: 0.0120 - val_kl_loss: 0.0322
# Epoch 19/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0458 - mse_loss: 0.0137 - kl_loss: 0.0321 - val_loss: 0.0480 - val_mse_loss: 0.0160 - val_kl_loss: 0.0321
# Epoch 20/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0454 - mse_loss: 0.0134 - kl_loss: 0.0320 - val_loss: 0.0444 - val_mse_loss: 0.0126 - val_kl_loss: 0.0318
# Epoch 21/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0454 - mse_loss: 0.0133 - kl_loss: 0.0320 - val_loss: 0.0435 - val_mse_loss: 0.0114 - val_kl_loss: 0.0321
# Epoch 22/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0451 - mse_loss: 0.0131 - kl_loss: 0.0320 - val_loss: 0.0442 - val_mse_loss: 0.0121 - val_kl_loss: 0.0321
# Epoch 23/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0451 - mse_loss: 0.0132 - kl_loss: 0.0319 - val_loss: 0.0442 - val_mse_loss: 0.0122 - val_kl_loss: 0.0320
# Epoch 24/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0450 - mse_loss: 0.0130 - kl_loss: 0.0320 - val_loss: 0.0442 - val_mse_loss: 0.0124 - val_kl_loss: 0.0318
# Epoch 25/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0449 - mse_loss: 0.0130 - kl_loss: 0.0319 - val_loss: 0.0440 - val_mse_loss: 0.0124 - val_kl_loss: 0.0316
# Epoch 26/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0449 - mse_loss: 0.0130 - kl_loss: 0.0320 - val_loss: 0.0474 - val_mse_loss: 0.0153 - val_kl_loss: 0.0321
# Epoch 27/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0446 - mse_loss: 0.0127 - kl_loss: 0.0319 - val_loss: 0.0434 - val_mse_loss: 0.0121 - val_kl_loss: 0.0312
# Epoch 28/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0448 - mse_loss: 0.0129 - kl_loss: 0.0319 - val_loss: 0.0437 - val_mse_loss: 0.0118 - val_kl_loss: 0.0319
# Epoch 29/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0446 - mse_loss: 0.0127 - kl_loss: 0.0319 - val_loss: 0.0443 - val_mse_loss: 0.0118 - val_kl_loss: 0.0325
# Epoch 30/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0446 - mse_loss: 0.0127 - kl_loss: 0.0319 - val_loss: 0.0435 - val_mse_loss: 0.0111 - val_kl_loss: 0.0324
# Epoch 31/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0443 - mse_loss: 0.0124 - kl_loss: 0.0319 - val_loss: 0.0437 - val_mse_loss: 0.0118 - val_kl_loss: 0.0319
# Epoch 32/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0444 - mse_loss: 0.0125 - kl_loss: 0.0319 - val_loss: 0.0473 - val_mse_loss: 0.0156 - val_kl_loss: 0.0317
# Epoch 33/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0444 - mse_loss: 0.0125 - kl_loss: 0.0319 - val_loss: 0.0432 - val_mse_loss: 0.0113 - val_kl_loss: 0.0318
# Epoch 34/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0445 - mse_loss: 0.0126 - kl_loss: 0.0319 - val_loss: 0.0436 - val_mse_loss: 0.0120 - val_kl_loss: 0.0317
# Epoch 35/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0442 - mse_loss: 0.0124 - kl_loss: 0.0318 - val_loss: 0.0442 - val_mse_loss: 0.0118 - val_kl_loss: 0.0324
# Epoch 36/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0442 - mse_loss: 0.0123 - kl_loss: 0.0318 - val_loss: 0.0441 - val_mse_loss: 0.0122 - val_kl_loss: 0.0319
# Epoch 37/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0441 - mse_loss: 0.0123 - kl_loss: 0.0319 - val_loss: 0.0429 - val_mse_loss: 0.0110 - val_kl_loss: 0.0319
# Epoch 38/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0444 - mse_loss: 0.0126 - kl_loss: 0.0318 - val_loss: 0.0460 - val_mse_loss: 0.0143 - val_kl_loss: 0.0318
# Epoch 39/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0440 - mse_loss: 0.0122 - kl_loss: 0.0318 - val_loss: 0.0428 - val_mse_loss: 0.0109 - val_kl_loss: 0.0318
# Epoch 40/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0443 - mse_loss: 0.0124 - kl_loss: 0.0318 - val_loss: 0.0457 - val_mse_loss: 0.0139 - val_kl_loss: 0.0318
# Epoch 41/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0440 - mse_loss: 0.0122 - kl_loss: 0.0318 - val_loss: 0.0435 - val_mse_loss: 0.0113 - val_kl_loss: 0.0322
# Epoch 42/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0440 - mse_loss: 0.0122 - kl_loss: 0.0318 - val_loss: 0.0428 - val_mse_loss: 0.0110 - val_kl_loss: 0.0318
# Epoch 43/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0441 - mse_loss: 0.0123 - kl_loss: 0.0318 - val_loss: 0.0429 - val_mse_loss: 0.0115 - val_kl_loss: 0.0314
# Epoch 44/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0439 - mse_loss: 0.0122 - kl_loss: 0.0318 - val_loss: 0.0429 - val_mse_loss: 0.0109 - val_kl_loss: 0.0320
# Epoch 45/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0438 - mse_loss: 0.0121 - kl_loss: 0.0318 - val_loss: 0.0509 - val_mse_loss: 0.0192 - val_kl_loss: 0.0316
# Epoch 46/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0439 - mse_loss: 0.0121 - kl_loss: 0.0318 - val_loss: 0.0427 - val_mse_loss: 0.0110 - val_kl_loss: 0.0316
# Epoch 47/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0439 - mse_loss: 0.0120 - kl_loss: 0.0318 - val_loss: 0.0434 - val_mse_loss: 0.0115 - val_kl_loss: 0.0320
# Epoch 48/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0441 - mse_loss: 0.0123 - kl_loss: 0.0318 - val_loss: 0.0436 - val_mse_loss: 0.0120 - val_kl_loss: 0.0316
# Epoch 49/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0437 - mse_loss: 0.0119 - kl_loss: 0.0318 - val_loss: 0.0429 - val_mse_loss: 0.0112 - val_kl_loss: 0.0317
# Epoch 50/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0439 - mse_loss: 0.0121 - kl_loss: 0.0318 - val_loss: 0.0463 - val_mse_loss: 0.0138 - val_kl_loss: 0.0325
# Epoch 51/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0437 - mse_loss: 0.0119 - kl_loss: 0.0318 - val_loss: 0.0427 - val_mse_loss: 0.0112 - val_kl_loss: 0.0315
# Epoch 52/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0437 - mse_loss: 0.0120 - kl_loss: 0.0318 - val_loss: 0.0428 - val_mse_loss: 0.0105 - val_kl_loss: 0.0322
# Epoch 53/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0436 - mse_loss: 0.0119 - kl_loss: 0.0317 - val_loss: 0.0432 - val_mse_loss: 0.0116 - val_kl_loss: 0.0315
# Epoch 54/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0438 - mse_loss: 0.0120 - kl_loss: 0.0317 - val_loss: 0.0447 - val_mse_loss: 0.0127 - val_kl_loss: 0.0320
# Epoch 55/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0437 - mse_loss: 0.0119 - kl_loss: 0.0318 - val_loss: 0.0427 - val_mse_loss: 0.0108 - val_kl_loss: 0.0319
# Epoch 56/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0436 - mse_loss: 0.0118 - kl_loss: 0.0318 - val_loss: 0.0428 - val_mse_loss: 0.0111 - val_kl_loss: 0.0317
# Epoch 57/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0436 - mse_loss: 0.0119 - kl_loss: 0.0317 - val_loss: 0.0448 - val_mse_loss: 0.0134 - val_kl_loss: 0.0314
# Epoch 58/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0436 - mse_loss: 0.0119 - kl_loss: 0.0318 - val_loss: 0.0432 - val_mse_loss: 0.0116 - val_kl_loss: 0.0315
# Epoch 59/100
# 2400/2400 [==============================] - 25s 11ms/step - loss: 0.0436 - mse_loss: 0.0118 - kl_loss: 0.0318 - val_loss: 0.0434 - val_mse_loss: 0.0119 - val_kl_loss: 0.0315
# Epoch 60/100
# 2400/2400 [==============================] - 26s 11ms/step - loss: 0.0437 - mse_loss: 0.0120 - kl_loss: 0.0318 - val_loss: 0.0469 - val_mse_loss: 0.0150 - val_kl_loss: 0.0319
# Epoch 61/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0435 - mse_loss: 0.0118 - kl_loss: 0.0317 - val_loss: 0.0432 - val_mse_loss: 0.0111 - val_kl_loss: 0.0320
# Epoch 62/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0435 - mse_loss: 0.0118 - kl_loss: 0.0318 - val_loss: 0.0437 - val_mse_loss: 0.0122 - val_kl_loss: 0.0315
# Epoch 63/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0436 - mse_loss: 0.0118 - kl_loss: 0.0318 - val_loss: 0.0427 - val_mse_loss: 0.0112 - val_kl_loss: 0.0315
# Epoch 64/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0434 - mse_loss: 0.0117 - kl_loss: 0.0317 - val_loss: 0.0439 - val_mse_loss: 0.0123 - val_kl_loss: 0.0316
# Epoch 65/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0435 - mse_loss: 0.0118 - kl_loss: 0.0317 - val_loss: 0.0431 - val_mse_loss: 0.0118 - val_kl_loss: 0.0314
# Epoch 66/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0436 - mse_loss: 0.0118 - kl_loss: 0.0317 - val_loss: 0.0425 - val_mse_loss: 0.0107 - val_kl_loss: 0.0318
# Epoch 67/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0435 - mse_loss: 0.0117 - kl_loss: 0.0317 - val_loss: 0.0427 - val_mse_loss: 0.0108 - val_kl_loss: 0.0319
# Epoch 68/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0435 - mse_loss: 0.0118 - kl_loss: 0.0317 - val_loss: 0.0428 - val_mse_loss: 0.0112 - val_kl_loss: 0.0316
# Epoch 69/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0435 - mse_loss: 0.0118 - kl_loss: 0.0317 - val_loss: 0.0450 - val_mse_loss: 0.0131 - val_kl_loss: 0.0318
# Epoch 70/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0434 - mse_loss: 0.0116 - kl_loss: 0.0318 - val_loss: 0.0424 - val_mse_loss: 0.0108 - val_kl_loss: 0.0316
# Epoch 71/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0434 - mse_loss: 0.0117 - kl_loss: 0.0317 - val_loss: 0.0428 - val_mse_loss: 0.0114 - val_kl_loss: 0.0314
# Epoch 72/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.0435 - mse_loss: 0.0118 - kl_loss: 0.0317 - val_loss: 0.0427 - val_mse_loss: 0.0108 - val_kl_loss: 0.0318
# Epoch 73/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.0435 - mse_loss: 0.0117 - kl_loss: 0.0318 - val_loss: 0.0432 - val_mse_loss: 0.0114 - val_kl_loss: 0.0318
# Epoch 74/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0433 - mse_loss: 0.0116 - kl_loss: 0.0317 - val_loss: 0.0423 - val_mse_loss: 0.0110 - val_kl_loss: 0.0313
# Epoch 75/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0434 - mse_loss: 0.0117 - kl_loss: 0.0317 - val_loss: 0.0423 - val_mse_loss: 0.0106 - val_kl_loss: 0.0318
# Epoch 76/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0434 - mse_loss: 0.0117 - kl_loss: 0.0317 - val_loss: 0.0448 - val_mse_loss: 0.0130 - val_kl_loss: 0.0318
# Epoch 77/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0434 - mse_loss: 0.0116 - kl_loss: 0.0318 - val_loss: 0.0426 - val_mse_loss: 0.0111 - val_kl_loss: 0.0315
# Epoch 78/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0433 - mse_loss: 0.0115 - kl_loss: 0.0317 - val_loss: 0.0431 - val_mse_loss: 0.0114 - val_kl_loss: 0.0317
# Epoch 79/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0433 - mse_loss: 0.0116 - kl_loss: 0.0318 - val_loss: 0.0432 - val_mse_loss: 0.0115 - val_kl_loss: 0.0317
# Epoch 80/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0434 - mse_loss: 0.0116 - kl_loss: 0.0318 - val_loss: 0.0448 - val_mse_loss: 0.0131 - val_kl_loss: 0.0316
# Epoch 81/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0434 - mse_loss: 0.0116 - kl_loss: 0.0317 - val_loss: 0.0432 - val_mse_loss: 0.0117 - val_kl_loss: 0.0315
# Epoch 82/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0432 - mse_loss: 0.0115 - kl_loss: 0.0317 - val_loss: 0.0434 - val_mse_loss: 0.0117 - val_kl_loss: 0.0316
# Epoch 83/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0435 - mse_loss: 0.0117 - kl_loss: 0.0318 - val_loss: 0.0459 - val_mse_loss: 0.0147 - val_kl_loss: 0.0312
# Epoch 84/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0433 - mse_loss: 0.0116 - kl_loss: 0.0317 - val_loss: 0.0444 - val_mse_loss: 0.0124 - val_kl_loss: 0.0320
# Epoch 85/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0432 - mse_loss: 0.0114 - kl_loss: 0.0318 - val_loss: 0.0437 - val_mse_loss: 0.0118 - val_kl_loss: 0.0318
# Epoch 86/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0433 - mse_loss: 0.0115 - kl_loss: 0.0318 - val_loss: 0.0423 - val_mse_loss: 0.0103 - val_kl_loss: 0.0320
# Epoch 87/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0432 - mse_loss: 0.0114 - kl_loss: 0.0318 - val_loss: 0.0428 - val_mse_loss: 0.0112 - val_kl_loss: 0.0316
# Epoch 88/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0433 - mse_loss: 0.0115 - kl_loss: 0.0317 - val_loss: 0.0424 - val_mse_loss: 0.0106 - val_kl_loss: 0.0318
# Epoch 89/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.0432 - mse_loss: 0.0115 - kl_loss: 0.0317 - val_loss: 0.0433 - val_mse_loss: 0.0114 - val_kl_loss: 0.0319
# Epoch 90/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0431 - mse_loss: 0.0114 - kl_loss: 0.0317 - val_loss: 0.0425 - val_mse_loss: 0.0107 - val_kl_loss: 0.0318
# Epoch 91/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0433 - mse_loss: 0.0115 - kl_loss: 0.0317 - val_loss: 0.0446 - val_mse_loss: 0.0125 - val_kl_loss: 0.0321
# Epoch 92/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0431 - mse_loss: 0.0114 - kl_loss: 0.0317 - val_loss: 0.0430 - val_mse_loss: 0.0112 - val_kl_loss: 0.0318
# Epoch 93/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0433 - mse_loss: 0.0115 - kl_loss: 0.0318 - val_loss: 0.0438 - val_mse_loss: 0.0121 - val_kl_loss: 0.0316
# Epoch 94/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0432 - mse_loss: 0.0114 - kl_loss: 0.0318 - val_loss: 0.0424 - val_mse_loss: 0.0104 - val_kl_loss: 0.0320
# Epoch 95/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0432 - mse_loss: 0.0114 - kl_loss: 0.0318 - val_loss: 0.0446 - val_mse_loss: 0.0131 - val_kl_loss: 0.0315
# Epoch 96/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0432 - mse_loss: 0.0115 - kl_loss: 0.0318 - val_loss: 0.0429 - val_mse_loss: 0.0115 - val_kl_loss: 0.0314
# Epoch 97/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0431 - mse_loss: 0.0114 - kl_loss: 0.0317 - val_loss: 0.0424 - val_mse_loss: 0.0110 - val_kl_loss: 0.0314
# Epoch 98/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.0431 - mse_loss: 0.0114 - kl_loss: 0.0317 - val_loss: 0.0426 - val_mse_loss: 0.0106 - val_kl_loss: 0.0320
# Epoch 99/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0432 - mse_loss: 0.0114 - kl_loss: 0.0318 - val_loss: 0.0424 - val_mse_loss: 0.0106 - val_kl_loss: 0.0319
# Epoch 100/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.0431 - mse_loss: 0.0113 - kl_loss: 0.0317 - val_loss: 0.0428 - val_mse_loss: 0.0111 - val_kl_loss: 0.0317

# %%
histplot(history)

# %%
def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    input_img = inputs[idx]
    z = encode.predict(input_img)
    output_img = decode.predict([z])
    fig, ax = plt.subplots(3, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(input_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[0, i].set_title('Input Galaxy')
        ax[0, i].axis('off')
        ax[1, i].imshow(output_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[1, i].set_title(f'Reconstruction - SSIM: {ssim(output_img[i], input_img[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[1, i].axis('off')
        ax[2, i].imshow(abs(input_img[i] - output_img[i]), origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[2, i].set_title('Re Comp Difference')
        ax[2, i].axis('off')
        plt.tight_layout()
    return idx

# %%
chosen=summary_plot(n,test_components[0],decode)
# Out:
# [24 39 52 27 44]

# %%
#encoder2
inputs2=Input(shape=(height,width,1))

encoded2=encoder(inputs2)
shape=encoded2.get_shape()[1:]
encoded2=Flatten()(encoded2)

z_mean2=Dense(latent_dimensions)(encoded2)
z_log_sigma2=Dense(latent_dimensions)(encoded2)
z2=Lambda(sampling)([z_mean2,z_log_sigma2])

# %%
encode2=Model(inputs2,z2)
encode2.summary()

input_compc=Input(shape=(height,width,1))

for layer in decode.layers:
    layer.trainable=False

decode=Model([input_embed,input_compc],[output1])
decode.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 32)   320         ['input_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 64)   18496       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv2d_3[0][0]']
#
#  flatten_1 (Flatten)            (None, 4096)         0           ['max_pooling2d_1[0][0]']
#
#  dense_3 (Dense)                (None, 32)           131104      ['flatten_1[0][0]']
#
#  dense_4 (Dense)                (None, 32)           131104      ['flatten_1[0][0]']
#
#  lambda_1 (Lambda)              (None, 32)           0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
# ==================================================================================================
# Total params: 281,024
# Trainable params: 281,024
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32)]         0           []
#
#  dense_2 (Dense)                (None, 4096)         135168      ['input_2[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 64)     0           ['dense_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['reshape[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  36928       ['up_sampling2d[0][0]']
#  ose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  18464       ['conv2d_transpose[0][0]']
#  spose)
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 1)   289         ['conv2d_transpose_1[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 190,849
# Trainable params: 0
# Non-trainable params: 190,849
# __________________________________________________________________________________________________

# %%
encoding2=encode2(inputs2) #define the network
re2=decode([encoding2,input_compc])

vae=Model([inputs2,input_compc],[re2]) #adds methods of the network
vae.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_3 (Functional)           (None, 32)           281024      ['input_3[0][0]']
#
#  input_4 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  model_4 (Functional)           (None, 64, 64, 1)    190849      ['model_3[0][0]',
#                                                                   'input_4[0][0]']
#
# ==================================================================================================
# Total params: 471,873
# Trainable params: 281,024
# Non-trainable params: 190,849
# __________________________________________________________________________________________________

# %%
mse_loss=tf.reduce_mean(mse(input_compc,re2))*height*width
vae.add_loss(mse_loss)
vae.add_metric(mse_loss,'mse_loss')

kl_loss=tf.reduce_mean(-0.5*(1+z_log_sigma2-tf.square(z_mean2)-tf.exp(z_log_sigma2)))*beta
vae.add_loss(kl_loss)
vae.add_metric(kl_loss,'kl_loss')

train_together=[train_blends,train_components[0]]

test_together = [test_blends, test_components[0], test_components[1]]
#together_v=[blended_v,components_v[0]]

vae.compile(optimizer=Adam(learning_rate=0.001))

# %%
history2=vae.fit(train_together,verbose=1,epochs=100,batch_size=batch_size,validation_split=val_split_ratio)
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.9684 - mse_loss: 0.9332 - kl_loss: 0.0352 - val_loss: 0.7874 - val_mse_loss: 0.7522 - val_kl_loss: 0.0353
# Epoch 2/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.6850 - mse_loss: 0.6501 - kl_loss: 0.0349 - val_loss: 0.6121 - val_mse_loss: 0.5770 - val_kl_loss: 0.0351
# Epoch 3/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.5523 - mse_loss: 0.5180 - kl_loss: 0.0344 - val_loss: 0.5029 - val_mse_loss: 0.4704 - val_kl_loss: 0.0325
# Epoch 4/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.4766 - mse_loss: 0.4426 - kl_loss: 0.0340 - val_loss: 0.4338 - val_mse_loss: 0.3977 - val_kl_loss: 0.0361
# Epoch 5/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.4266 - mse_loss: 0.3927 - kl_loss: 0.0339 - val_loss: 0.3999 - val_mse_loss: 0.3657 - val_kl_loss: 0.0342
# Epoch 6/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3942 - mse_loss: 0.3607 - kl_loss: 0.0335 - val_loss: 0.3897 - val_mse_loss: 0.3564 - val_kl_loss: 0.0334
# Epoch 7/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3704 - mse_loss: 0.3372 - kl_loss: 0.0332 - val_loss: 0.4082 - val_mse_loss: 0.3741 - val_kl_loss: 0.0341
# Epoch 8/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.3572 - mse_loss: 0.3241 - kl_loss: 0.0332 - val_loss: 0.3554 - val_mse_loss: 0.3231 - val_kl_loss: 0.0323
# Epoch 9/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3415 - mse_loss: 0.3085 - kl_loss: 0.0330 - val_loss: 0.3502 - val_mse_loss: 0.3167 - val_kl_loss: 0.0335
# Epoch 10/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3306 - mse_loss: 0.2975 - kl_loss: 0.0331 - val_loss: 0.3402 - val_mse_loss: 0.3074 - val_kl_loss: 0.0328
# Epoch 11/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3210 - mse_loss: 0.2880 - kl_loss: 0.0330 - val_loss: 0.3669 - val_mse_loss: 0.3332 - val_kl_loss: 0.0336
# Epoch 12/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3138 - mse_loss: 0.2809 - kl_loss: 0.0330 - val_loss: 0.3146 - val_mse_loss: 0.2803 - val_kl_loss: 0.0343
# Epoch 13/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.3052 - mse_loss: 0.2724 - kl_loss: 0.0328 - val_loss: 0.3050 - val_mse_loss: 0.2720 - val_kl_loss: 0.0330
# Epoch 14/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2993 - mse_loss: 0.2665 - kl_loss: 0.0328 - val_loss: 0.2980 - val_mse_loss: 0.2656 - val_kl_loss: 0.0323
# Epoch 15/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2949 - mse_loss: 0.2622 - kl_loss: 0.0326 - val_loss: 0.3042 - val_mse_loss: 0.2716 - val_kl_loss: 0.0326
# Epoch 16/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.2901 - mse_loss: 0.2575 - kl_loss: 0.0326 - val_loss: 0.3072 - val_mse_loss: 0.2738 - val_kl_loss: 0.0334
# Epoch 17/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2850 - mse_loss: 0.2525 - kl_loss: 0.0326 - val_loss: 0.2906 - val_mse_loss: 0.2580 - val_kl_loss: 0.0326
# Epoch 18/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2803 - mse_loss: 0.2477 - kl_loss: 0.0326 - val_loss: 0.2907 - val_mse_loss: 0.2581 - val_kl_loss: 0.0326
# Epoch 19/100
# 2400/2400 [==============================] - 20s 8ms/step - loss: 0.2769 - mse_loss: 0.2445 - kl_loss: 0.0324 - val_loss: 0.2802 - val_mse_loss: 0.2474 - val_kl_loss: 0.0328
# Epoch 20/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2739 - mse_loss: 0.2415 - kl_loss: 0.0324 - val_loss: 0.2898 - val_mse_loss: 0.2563 - val_kl_loss: 0.0334
# Epoch 21/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2696 - mse_loss: 0.2371 - kl_loss: 0.0325 - val_loss: 0.2740 - val_mse_loss: 0.2421 - val_kl_loss: 0.0318
# Epoch 22/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2681 - mse_loss: 0.2355 - kl_loss: 0.0326 - val_loss: 0.2836 - val_mse_loss: 0.2505 - val_kl_loss: 0.0331
# Epoch 23/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2649 - mse_loss: 0.2325 - kl_loss: 0.0324 - val_loss: 0.2747 - val_mse_loss: 0.2408 - val_kl_loss: 0.0339
# Epoch 24/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2608 - mse_loss: 0.2285 - kl_loss: 0.0324 - val_loss: 0.2751 - val_mse_loss: 0.2433 - val_kl_loss: 0.0318
# Epoch 25/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2579 - mse_loss: 0.2255 - kl_loss: 0.0324 - val_loss: 0.2637 - val_mse_loss: 0.2335 - val_kl_loss: 0.0302
# Epoch 26/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2559 - mse_loss: 0.2236 - kl_loss: 0.0324 - val_loss: 0.2760 - val_mse_loss: 0.2441 - val_kl_loss: 0.0318
# Epoch 27/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2530 - mse_loss: 0.2205 - kl_loss: 0.0325 - val_loss: 0.2569 - val_mse_loss: 0.2251 - val_kl_loss: 0.0318
# Epoch 28/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2509 - mse_loss: 0.2185 - kl_loss: 0.0323 - val_loss: 0.2541 - val_mse_loss: 0.2230 - val_kl_loss: 0.0311
# Epoch 29/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2471 - mse_loss: 0.2148 - kl_loss: 0.0323 - val_loss: 0.2617 - val_mse_loss: 0.2304 - val_kl_loss: 0.0313
# Epoch 30/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2463 - mse_loss: 0.2138 - kl_loss: 0.0325 - val_loss: 0.2528 - val_mse_loss: 0.2208 - val_kl_loss: 0.0320
# Epoch 31/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2443 - mse_loss: 0.2119 - kl_loss: 0.0323 - val_loss: 0.2590 - val_mse_loss: 0.2255 - val_kl_loss: 0.0335
# Epoch 32/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.2428 - mse_loss: 0.2105 - kl_loss: 0.0323 - val_loss: 0.2577 - val_mse_loss: 0.2267 - val_kl_loss: 0.0310
# Epoch 33/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2415 - mse_loss: 0.2091 - kl_loss: 0.0323 - val_loss: 0.2550 - val_mse_loss: 0.2234 - val_kl_loss: 0.0316
# Epoch 34/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2395 - mse_loss: 0.2071 - kl_loss: 0.0324 - val_loss: 0.2518 - val_mse_loss: 0.2212 - val_kl_loss: 0.0306
# Epoch 35/100
# 2400/2400 [==============================] - 20s 8ms/step - loss: 0.2383 - mse_loss: 0.2059 - kl_loss: 0.0324 - val_loss: 0.2627 - val_mse_loss: 0.2286 - val_kl_loss: 0.0341
# Epoch 36/100
# 2400/2400 [==============================] - 20s 9ms/step - loss: 0.2363 - mse_loss: 0.2039 - kl_loss: 0.0324 - val_loss: 0.2514 - val_mse_loss: 0.2187 - val_kl_loss: 0.0327
# Epoch 37/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.2354 - mse_loss: 0.2031 - kl_loss: 0.0324 - val_loss: 0.2420 - val_mse_loss: 0.2092 - val_kl_loss: 0.0328
# Epoch 38/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2328 - mse_loss: 0.2005 - kl_loss: 0.0323 - val_loss: 0.2502 - val_mse_loss: 0.2178 - val_kl_loss: 0.0325
# Epoch 39/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2338 - mse_loss: 0.2014 - kl_loss: 0.0324 - val_loss: 0.2366 - val_mse_loss: 0.2043 - val_kl_loss: 0.0322
# Epoch 40/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2308 - mse_loss: 0.1987 - kl_loss: 0.0322 - val_loss: 0.2435 - val_mse_loss: 0.2102 - val_kl_loss: 0.0333
# Epoch 41/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2299 - mse_loss: 0.1975 - kl_loss: 0.0323 - val_loss: 0.2342 - val_mse_loss: 0.2008 - val_kl_loss: 0.0334
# Epoch 42/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2299 - mse_loss: 0.1977 - kl_loss: 0.0322 - val_loss: 0.2360 - val_mse_loss: 0.2046 - val_kl_loss: 0.0314
# Epoch 43/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2289 - mse_loss: 0.1965 - kl_loss: 0.0323 - val_loss: 0.2420 - val_mse_loss: 0.2079 - val_kl_loss: 0.0341
# Epoch 44/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2276 - mse_loss: 0.1953 - kl_loss: 0.0323 - val_loss: 0.2368 - val_mse_loss: 0.2024 - val_kl_loss: 0.0344
# Epoch 45/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2261 - mse_loss: 0.1938 - kl_loss: 0.0323 - val_loss: 0.2375 - val_mse_loss: 0.2057 - val_kl_loss: 0.0318
# Epoch 46/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2255 - mse_loss: 0.1933 - kl_loss: 0.0322 - val_loss: 0.2332 - val_mse_loss: 0.2005 - val_kl_loss: 0.0327
# Epoch 47/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2238 - mse_loss: 0.1915 - kl_loss: 0.0323 - val_loss: 0.2284 - val_mse_loss: 0.1949 - val_kl_loss: 0.0336
# Epoch 48/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2235 - mse_loss: 0.1913 - kl_loss: 0.0322 - val_loss: 0.2349 - val_mse_loss: 0.1999 - val_kl_loss: 0.0350
# Epoch 49/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.2226 - mse_loss: 0.1905 - kl_loss: 0.0321 - val_loss: 0.2347 - val_mse_loss: 0.2018 - val_kl_loss: 0.0329
# Epoch 50/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2224 - mse_loss: 0.1902 - kl_loss: 0.0323 - val_loss: 0.2454 - val_mse_loss: 0.2134 - val_kl_loss: 0.0320
# Epoch 51/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2216 - mse_loss: 0.1893 - kl_loss: 0.0324 - val_loss: 0.2406 - val_mse_loss: 0.2075 - val_kl_loss: 0.0330
# Epoch 52/100
# 2400/2400 [==============================] - 20s 8ms/step - loss: 0.2197 - mse_loss: 0.1875 - kl_loss: 0.0321 - val_loss: 0.2295 - val_mse_loss: 0.1968 - val_kl_loss: 0.0326
# Epoch 53/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2203 - mse_loss: 0.1880 - kl_loss: 0.0323 - val_loss: 0.2282 - val_mse_loss: 0.1944 - val_kl_loss: 0.0338
# Epoch 54/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2186 - mse_loss: 0.1863 - kl_loss: 0.0323 - val_loss: 0.2451 - val_mse_loss: 0.2134 - val_kl_loss: 0.0317
# Epoch 55/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2179 - mse_loss: 0.1857 - kl_loss: 0.0322 - val_loss: 0.2263 - val_mse_loss: 0.1943 - val_kl_loss: 0.0320
# Epoch 56/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2167 - mse_loss: 0.1846 - kl_loss: 0.0322 - val_loss: 0.2219 - val_mse_loss: 0.1900 - val_kl_loss: 0.0320
# Epoch 57/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2167 - mse_loss: 0.1844 - kl_loss: 0.0323 - val_loss: 0.2242 - val_mse_loss: 0.1917 - val_kl_loss: 0.0324
# Epoch 58/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2161 - mse_loss: 0.1839 - kl_loss: 0.0322 - val_loss: 0.2272 - val_mse_loss: 0.1964 - val_kl_loss: 0.0308
# Epoch 59/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2168 - mse_loss: 0.1845 - kl_loss: 0.0323 - val_loss: 0.2429 - val_mse_loss: 0.2106 - val_kl_loss: 0.0323
# Epoch 60/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2156 - mse_loss: 0.1834 - kl_loss: 0.0323 - val_loss: 0.2558 - val_mse_loss: 0.2224 - val_kl_loss: 0.0334
# Epoch 61/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2137 - mse_loss: 0.1816 - kl_loss: 0.0321 - val_loss: 0.2264 - val_mse_loss: 0.1926 - val_kl_loss: 0.0338
# Epoch 62/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2137 - mse_loss: 0.1815 - kl_loss: 0.0322 - val_loss: 0.2271 - val_mse_loss: 0.1950 - val_kl_loss: 0.0321
# Epoch 63/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2132 - mse_loss: 0.1810 - kl_loss: 0.0322 - val_loss: 0.2310 - val_mse_loss: 0.1987 - val_kl_loss: 0.0323
# Epoch 64/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2128 - mse_loss: 0.1805 - kl_loss: 0.0323 - val_loss: 0.2226 - val_mse_loss: 0.1910 - val_kl_loss: 0.0315
# Epoch 65/100
# 2400/2400 [==============================] - 22s 9ms/step - loss: 0.2121 - mse_loss: 0.1799 - kl_loss: 0.0322 - val_loss: 0.2247 - val_mse_loss: 0.1932 - val_kl_loss: 0.0316
# Epoch 66/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2120 - mse_loss: 0.1798 - kl_loss: 0.0322 - val_loss: 0.2258 - val_mse_loss: 0.1926 - val_kl_loss: 0.0332
# Epoch 67/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2117 - mse_loss: 0.1795 - kl_loss: 0.0323 - val_loss: 0.2278 - val_mse_loss: 0.1961 - val_kl_loss: 0.0317
# Epoch 68/100
# 2400/2400 [==============================] - 23s 9ms/step - loss: 0.2107 - mse_loss: 0.1784 - kl_loss: 0.0323 - val_loss: 0.2253 - val_mse_loss: 0.1929 - val_kl_loss: 0.0324
# Epoch 69/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2110 - mse_loss: 0.1788 - kl_loss: 0.0323 - val_loss: 0.2308 - val_mse_loss: 0.1982 - val_kl_loss: 0.0327
# Epoch 70/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2108 - mse_loss: 0.1785 - kl_loss: 0.0322 - val_loss: 0.2179 - val_mse_loss: 0.1855 - val_kl_loss: 0.0324
# Epoch 71/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2087 - mse_loss: 0.1766 - kl_loss: 0.0321 - val_loss: 0.2213 - val_mse_loss: 0.1892 - val_kl_loss: 0.0321
# Epoch 72/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2096 - mse_loss: 0.1774 - kl_loss: 0.0322 - val_loss: 0.2278 - val_mse_loss: 0.1957 - val_kl_loss: 0.0321
# Epoch 73/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2081 - mse_loss: 0.1761 - kl_loss: 0.0321 - val_loss: 0.2240 - val_mse_loss: 0.1914 - val_kl_loss: 0.0327
# Epoch 74/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2085 - mse_loss: 0.1763 - kl_loss: 0.0322 - val_loss: 0.2209 - val_mse_loss: 0.1887 - val_kl_loss: 0.0322
# Epoch 75/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2074 - mse_loss: 0.1751 - kl_loss: 0.0322 - val_loss: 0.2168 - val_mse_loss: 0.1842 - val_kl_loss: 0.0327
# Epoch 76/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2068 - mse_loss: 0.1746 - kl_loss: 0.0322 - val_loss: 0.2193 - val_mse_loss: 0.1864 - val_kl_loss: 0.0329
# Epoch 77/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2069 - mse_loss: 0.1747 - kl_loss: 0.0322 - val_loss: 0.2322 - val_mse_loss: 0.1987 - val_kl_loss: 0.0335
# Epoch 78/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2068 - mse_loss: 0.1746 - kl_loss: 0.0321 - val_loss: 0.2182 - val_mse_loss: 0.1859 - val_kl_loss: 0.0323
# Epoch 79/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2063 - mse_loss: 0.1741 - kl_loss: 0.0322 - val_loss: 0.2245 - val_mse_loss: 0.1930 - val_kl_loss: 0.0315
# Epoch 80/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2058 - mse_loss: 0.1736 - kl_loss: 0.0322 - val_loss: 0.2279 - val_mse_loss: 0.1946 - val_kl_loss: 0.0333
# Epoch 81/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2048 - mse_loss: 0.1726 - kl_loss: 0.0322 - val_loss: 0.2228 - val_mse_loss: 0.1900 - val_kl_loss: 0.0328
# Epoch 82/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2052 - mse_loss: 0.1730 - kl_loss: 0.0322 - val_loss: 0.2193 - val_mse_loss: 0.1873 - val_kl_loss: 0.0320
# Epoch 83/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2047 - mse_loss: 0.1726 - kl_loss: 0.0321 - val_loss: 0.2177 - val_mse_loss: 0.1860 - val_kl_loss: 0.0317
# Epoch 84/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2049 - mse_loss: 0.1726 - kl_loss: 0.0322 - val_loss: 0.2226 - val_mse_loss: 0.1885 - val_kl_loss: 0.0340
# Epoch 85/100
# 2400/2400 [==============================] - 23s 10ms/step - loss: 0.2049 - mse_loss: 0.1727 - kl_loss: 0.0322 - val_loss: 0.2144 - val_mse_loss: 0.1820 - val_kl_loss: 0.0324
# Epoch 86/100
# 2400/2400 [==============================] - 21s 9ms/step - loss: 0.2038 - mse_loss: 0.1716 - kl_loss: 0.0322 - val_loss: 0.2252 - val_mse_loss: 0.1922 - val_kl_loss: 0.0330
# Epoch 87/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.2034 - mse_loss: 0.1712 - kl_loss: 0.0322 - val_loss: 0.2191 - val_mse_loss: 0.1869 - val_kl_loss: 0.0322
# Epoch 88/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2034 - mse_loss: 0.1712 - kl_loss: 0.0322 - val_loss: 0.2147 - val_mse_loss: 0.1824 - val_kl_loss: 0.0323
# Epoch 89/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2028 - mse_loss: 0.1707 - kl_loss: 0.0321 - val_loss: 0.2251 - val_mse_loss: 0.1931 - val_kl_loss: 0.0320
# Epoch 90/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2032 - mse_loss: 0.1710 - kl_loss: 0.0322 - val_loss: 0.2214 - val_mse_loss: 0.1904 - val_kl_loss: 0.0310
# Epoch 91/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2025 - mse_loss: 0.1704 - kl_loss: 0.0321 - val_loss: 0.2224 - val_mse_loss: 0.1894 - val_kl_loss: 0.0329
# Epoch 92/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.2022 - mse_loss: 0.1700 - kl_loss: 0.0322 - val_loss: 0.2178 - val_mse_loss: 0.1862 - val_kl_loss: 0.0316
# Epoch 93/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2018 - mse_loss: 0.1696 - kl_loss: 0.0322 - val_loss: 0.2142 - val_mse_loss: 0.1820 - val_kl_loss: 0.0322
# Epoch 94/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2022 - mse_loss: 0.1700 - kl_loss: 0.0323 - val_loss: 0.2273 - val_mse_loss: 0.1943 - val_kl_loss: 0.0330
# Epoch 95/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.2012 - mse_loss: 0.1690 - kl_loss: 0.0321 - val_loss: 0.2135 - val_mse_loss: 0.1820 - val_kl_loss: 0.0315
# Epoch 96/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2011 - mse_loss: 0.1690 - kl_loss: 0.0321 - val_loss: 0.2158 - val_mse_loss: 0.1821 - val_kl_loss: 0.0337
# Epoch 97/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.2008 - mse_loss: 0.1686 - kl_loss: 0.0321 - val_loss: 0.2204 - val_mse_loss: 0.1869 - val_kl_loss: 0.0335
# Epoch 98/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.2002 - mse_loss: 0.1680 - kl_loss: 0.0322 - val_loss: 0.2186 - val_mse_loss: 0.1864 - val_kl_loss: 0.0322
# Epoch 99/100
# 2400/2400 [==============================] - 24s 10ms/step - loss: 0.2004 - mse_loss: 0.1682 - kl_loss: 0.0322 - val_loss: 0.2157 - val_mse_loss: 0.1825 - val_kl_loss: 0.0331
# Epoch 100/100
# 2400/2400 [==============================] - 25s 10ms/step - loss: 0.2004 - mse_loss: 0.1683 - kl_loss: 0.0321 - val_loss: 0.2162 - val_mse_loss: 0.1856 - val_kl_loss: 0.0307

# %%
histplot(history2)

# %%
"""
def summary_plot(n,inputs,decode,seed=1):
    np.random.seed(seed)
    #idx=np.array([0,1,2,3,4])
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    input_img = inputs[0][idx]
    compc=inputs[1][idx]
    z = encode2.predict(input_img)
    output_img = decode.predict([z,compc])
    fig, ax = plt.subplots(5, n, figsize=((3)*n,15))
    for i in range(n):
        encoding = ', '.join(f'{zi:.2f}' for zi in z[i][:3]) + ', ...'
        showimg(input_img[i], ax[0, i], f'blend {idx[i]}')
        showimg(compc[i], ax[1, i], f'comp1 {idx[i]}')
        showimg(output_img[i], ax[2, i], f'output\n{encoding}')
        showimg(output_img[i]-compc[i], ax[3, i], f'output difference')
        showimg(input_img[i]-output_img[i], ax[4, i], f'original difference')
    return idx
"""
# Out:
# "\ndef summary_plot(n,inputs,decode,seed=1):\n    np.random.seed(seed)\n    #idx=np.array([0,1,2,3,4])\n    idx = np.random.choice(len(inputs[0]), size=n, replace=False)\n    print(idx)\n    input_img = inputs[0][idx]\n    compc=inputs[1][idx]\n    z = encode2.predict(input_img)\n    output_img = decode.predict([z,compc])\n    fig, ax = plt.subplots(5, n, figsize=((3)*n,15))\n    for i in range(n):\n        encoding = ', '.join(f'{zi:.2f}' for zi in z[i][:3]) + ', ...'\n        showimg(input_img[i], ax[0, i], f'blend {idx[i]}')\n        showimg(compc[i], ax[1, i], f'comp1 {idx[i]}')\n        showimg(output_img[i], ax[2, i], f'output\n{encoding}')\n        showimg(output_img[i]-compc[i], ax[3, i], f'output difference')\n        showimg(input_img[i]-output_img[i], ax[4, i], f'original difference')\n    return idx\n"

# %%
def summary_plot2(n,inputs,decode,seed=1):
    np.random.seed(seed)
    idx = np.random.choice(len(inputs[0]), size=n, replace=False)
    print(idx)
    input_img = inputs[0][idx]
    #Comp 1 = Central Comp, Comp 2 = Residual
    comp1 = inputs[1][idx]
    comp2 = inputs[2][idx]
    z = encode2.predict(input_img)
    output_img = decode.predict([z,comp1])
    comp1.shape, output_img.shape
    fig, ax = plt.subplots(6, n, figsize=((3)*n,15))
    for i in range(n):
        ax[0, i].imshow(input_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75)
        ax[0, i].set_title('In Blend')
        ax[0, i].axis('off')
        ax[1, i].imshow(comp1[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[1, i].set_title('In Central Comp')
        ax[1, i].axis('off')
        ax[2, i].imshow(comp2[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[2, i].set_title('In Comp 2')
        ax[2, i].axis('off')
        ax[3, i].imshow(output_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[3, i].set_title(f'Re Central Comp - SSIM: {ssim(output_img[i], comp1[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[3, i].axis('off')
        ax[4, i].imshow(input_img[i] - output_img[i], origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[4, i].set_title(f'Re Residual Comp - SSIM: {ssim((input_img[i] - output_img[i]), comp2[i], channel_axis = 2, gaussian_weights = True, use_sample_covarience = False):.2f}')
        ax[4, i].axis('off')
        ax[5, i].imshow(abs(comp1[i] - output_img[i]), origin='lower', interpolation='nearest', vmin = 0, vmax = 0.75 )
        ax[5, i].set_title('Re Comp Difference')
        ax[5, i].axis('off')
        plt.tight_layout()
    return idx

# %%
n = 5
chosen=summary_plot2(n,test_together,decode)
# Out:
# [ 6414 13523  8374  5256  4405]

# %%
c = 'orangered'
outline = 'red'

# %%
losses=np.zeros(num)
for ite in range(0,num):
    input_img=test_blends[ite]
    compc=test_components[0,ite]

    input_img=input_img.reshape(1,height,width,1).astype('float32')
    compc=compc.reshape(1,height,width,1).astype('float32')

    evals=vae.evaluate([input_img,compc],verbose=0,batch_size=batch_size)
    losses[ite]=evals[0]
    #print(ite)
    
loss_max=np.amax(losses)
loss_min=np.amin(losses)
ax=plt.axes()
ax.hist(losses,bins=500, color = c, ec = outline, alpha = 0.3, lw = 2 )
ax.set_xlim(max(loss_min,0),min(loss_max,1)),ax.set_ylim(0)
ax.set_xlabel("Loss"),ax.set_ylabel("Frequency")
# Out:
# (Text(0.5, 0, 'Loss'), Text(0, 0.5, 'Frequency'))

# %%
#vae.save_weights("model_1.h5")
#decode.save_weights("decoder_1.h5")

# %%
#vae=Model.load_weights("model_1.h5")
#vae.summary()

# %%
def calc_ssim(inputs,decode):
    ssim_comp1 = np.zeros(test_ngals)
    ssim_comp2 = np.zeros(test_ngals)
    ssim_blends = np.zeros(test_ngals)
    input_img = inputs[0]
    #Comp 1 = Central Comp, Comp 2 = Residual
    comp1 = inputs[1]
    comp2 = inputs[2]
    z = encode2.predict(input_img)
    output_img1 = decode.predict([z, comp1])
    for i in range(test_ngals):
        ssim_comp1[i] = ssim(comp1[i], output_img1[i], channel_axis=2, gaussian_weights = True, use_sample_covarience = False)
        ssim_comp2[i] = ssim(comp2[i], (input_img[i] - output_img1[i]), channel_axis=2, gaussian_weights = True, use_sample_covarience = False)
 

    ssim_values = np.array([ssim_comp1, ssim_comp2])
    
    return ssim_values

# %%
ssim_values = calc_ssim(test_together, decode)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fa36c123af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#Plot violinplots of the SSIM

n_of_bins = 100
bins = np.linspace(0,1,n_of_bins+1)

fig, ax = plt.subplots(1, 2, figsize = (13,5))


vp1 = ax[0].hist(ssim_values[0], bins, color = c, ec = outline, alpha = 0.3, lw = 2)

ax[0].set_title('SSIMs of Central Component')
ax[0].set_xlabel('SSIM')
ax[0].set_ylabel('Density')

 

vp2 = ax[1].hist(ssim_values[1], bins,  color = c, ec = outline, alpha = 0.3, lw = 2)

ax[1].set_title('SSIMs of Residual Component')  
ax[1].set_xlabel('SSIM')
ax[1].set_ylabel('Density')
  
ax[0].set_xlim(0, 1) 
ax[1].set_xlim(0, 1) 
plt.tight_layout()

plt.show()

# %%
mean_ssim_comp1 = np.mean(ssim_values[0])
median_ssim_comp1 = np.median(ssim_values[0])
mean_ssim_comp2 = np.mean(ssim_values[1])
median_ssim_comp2 = np.median(ssim_values[1])

# %%
print(f' Mean SSIMs: Central Component: {mean_ssim_comp1:.4f}, Residual Component: {mean_ssim_comp2:.4f}')

print(f' Median SSIMs: Central Component: {median_ssim_comp1:.4f}, Residual Component: {median_ssim_comp2:.4f} ')
# Out:
#  Mean SSIMs: Central Component: 0.9845, Residual Component: 0.9686
#  Median SSIMs: Central Component: 0.9914, Residual Component: 0.9824

# %%
#This function calculates the properties of the input and output images. The ellipticity and flux are stored in arrays 

def calc_properties(inputs,decode):
    
    empty_array = np.zeros(test_ngals)
    
    flux_in_comp1 = np.zeros(test_ngals)
    
    flux_out_comp1 = np.zeros(test_ngals)
    
    elip_in_comp1 = np.zeros(test_ngals)
    
    elip_out_comp1 = np.zeros(test_ngals)
    
    flux_in_comp2 = np.zeros(test_ngals)
    
    flux_out_comp2 = np.zeros(test_ngals)
    
    elip_in_comp2 = np.zeros(test_ngals)

    elip_out_comp2 = np.zeros(test_ngals)
    
    input_img = inputs[0]
    input_img = input_img.reshape(test_ngals, height, width)
    comp1 = inputs[1]
    comp1 = comp1.reshape(test_ngals, height, width)
    comp2 = inputs[2]
    comp2 = comp2.reshape(test_ngals, height, width)
    
    z = encode2.predict(input_img)
    output_img1 = decode.predict([z, comp1])
    output_img1 = output_img1.reshape(test_ngals, height, width)
    
    for i in range(test_ngals):
        
        in_comp1_cat = photutils.morphology.data_properties(comp1[i], mask = None, background = 0)
        elip_in_comp1[i] = in_comp1_cat.ellipticity
        flux_in_comp1[i] = in_comp1_cat.segment_flux
            
        out_comp1_cat = photutils.morphology.data_properties(output_img1[i], mask = None, background = 0)
        elip_out_comp1[i] = out_comp1_cat.ellipticity
        flux_out_comp1[i] = out_comp1_cat.segment_flux
        
        in_comp2_cat = photutils.morphology.data_properties(comp2[i], mask = None, background = 0)
        elip_in_comp2[i] = in_comp2_cat.ellipticity
        flux_in_comp2[i] = in_comp2_cat.segment_flux
            
        out_comp2_cat = photutils.morphology.data_properties(input_img[i] - output_img1[i], mask = None, background = 0)
        elip_out_comp2[i] = out_comp2_cat.ellipticity
        flux_out_comp2[i] = out_comp2_cat.segment_flux
        
        parameters = [elip_in_comp1, elip_out_comp1, flux_in_comp1, flux_out_comp1, elip_in_comp2, elip_out_comp2, flux_in_comp2, flux_out_comp2]   
    return parameters

# %%
parameters = calc_properties(test_together, decode)

# %%
np.save("se_parameters.npy", parameters)
